# %% [markdown]
# ## Introduction
#
# We are going to be using [scikit learn](http://scikit-learn.org/stable/index.html)
#
# <img src='files/resources/scikit-learn-logo-small.png' align='left'><h2>Machine Learning in Python</h2>
#
# <br>
# * Simple and efficient tools for data mining and data analysis
# * Accessible to everybody, and reusable in various contexts
# * Built on NumPy, SciPy, and matplotlib
# * Open source, commercially usable - BSD license

# %%
import os 
import pandas as pd

# %%
data = pd.read_csv("data/fullDataset.tsv", sep="\t",header=0)
# Out:
# /home/csumb/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#       key                   query  \
# 0  215248    all star ticket 2015
# 1   42799            mga top bows
# 2   73041  cross document markers
# 3  138766      wall cabinet white
# 4  222660   2.5 jato cooling head
#
#                                                Title LeafCats  ItemID  \
# 0  6N/7D Disney World All Star Music~ All Inclusi...    29579   67884
# 1  MGTC/TD/TF, MGA, Morris Minor Top Wing Bolts s...    34206   21331
# 2  New Cross Vice Gel Ink Pen Gift Set & Document...   165631   36048
# 3  White PAPER TOWEL ROLL HOLDER Cabinet Wall Mou...    20643   49003
# 4  ENGINE COOLING HEAD TRAXXAS JATO TRX 2.5 NITRO...    34061   71436
#
#    X_unit_id     SCORE  label_relevanceGrade  label_relevanceBinary  \
# 0  793072069   -1:1:-1                     3                      0
# 1  687419458      3::2                     5                      0
# 2  687423583     3:3:3                     6                      1
# 3  780091360  -1:-2:-2                     1                      0
# 4  793073501     3:3:3                     6                      1
#
#      feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0  2676.618000          0  -9.020574  -5.221152  32.879559   0.000000
# 1  2676.618000          0  -7.435843  -5.986507  24.565182   0.036317
# 2  2676.618000          0  -8.030511  -4.509118  48.652847   0.000000
# 3  1557.416626          1  -8.218757  -6.132952  45.209755   0.000000
# 4  2676.618000          0  -8.599997  -5.317750  79.376099   0.805351
#
#    feature_7  feature_8  feature_9  feature_10
# 0        241   -1000000        139 -100.000000
# 1          0          0        208 -100.000000
# 2          0          0        226 -100.000000
# 3       1258   -1000000        158    1.670978
# 4          0          0        150    2.538091

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78500 entries, 0 to 78499
# Data columns (total 19 columns):
# key                      78500 non-null int64
# query                    78500 non-null object
# Title                    78494 non-null object
# LeafCats                 78500 non-null object
# ItemID                   78500 non-null int64
# X_unit_id                78500 non-null object
# SCORE                    78500 non-null object
# label_relevanceGrade     78500 non-null int64
# label_relevanceBinary    78500 non-null float64
# feature_1                78500 non-null float64
# feature_2                78500 non-null float64
# feature_3                78500 non-null float64
# feature_4                78500 non-null float64
# feature_5                78500 non-null float64
# feature_6                78500 non-null float64
# feature_7                78500 non-null float64
# feature_8                78500 non-null float64
# feature_9                78500 non-null int64
# feature_10               78499 non-null float64
# dtypes: float64(10), int64(4), object(5)
# memory usage: 12.0+ MB

# %%
data.describe()
# Out:
#                  key        ItemID  label_relevanceGrade  \
# count   78500.000000  7.850000e+04          78500.000000
# mean    98346.614064  4.869803e+04              5.254777
# std     70253.651231  2.890059e+06              1.334406
# min         1.000000  1.000000e+00              0.000000
# 25%     39209.750000  1.908475e+04              5.000000
# 50%     78577.500000  3.831350e+04              6.000000
# 75%    157546.250000  5.765925e+04              6.000000
# max    234520.000000  8.097468e+08              6.000000
#
#        label_relevanceBinary     feature_1     feature_2     feature_3  \
# count           78500.000000  78500.000000  78500.000000  78500.000000
# mean                0.713653   2821.519304      0.562437     -7.754530
# std                 8.446960    834.067146      0.497410      1.162798
# min                 0.000000  -1890.000000     -9.658937    -13.563713
# 25%                 0.000000   2676.618000      0.000000     -8.285197
# 50%                 1.000000   2676.618000      1.000000     -7.651813
# 75%                 1.000000   3237.216614      1.000000     -7.390667
# max              2363.750000   5286.000000      1.000000     -2.726150
#
#           feature_4     feature_5     feature_6       feature_7  \
# count  78500.000000  78500.000000  78500.000000    78500.000000
# mean      -4.280808     47.526718      0.439879    50746.223210
# std        0.772099     24.222248     18.439044   228258.768038
# min      -10.324562      0.000000      0.000000 -1000000.000000
# 25%       -4.736623     30.806008      0.101174        0.000000
# 50%       -4.327543     44.189650      0.365236      191.000000
# 75%       -3.766841     60.076828      0.613038     4707.250000
# max       42.595760    273.239624   5166.000000  3339990.000000
#
#             feature_8     feature_9    feature_10
# count    78500.000000  78500.000000  78499.000000
# mean   -240684.450178    171.255248    -62.985598
# std     527649.016958     41.412263     48.710378
# min   -1000000.000000   -100.000000   -100.000000
# 25%   -1000000.000000    144.000000   -100.000000
# 50%          0.000000    172.000000   -100.000000
# 75%      98130.000000    203.000000      0.620428
# max    1000000.000000    240.000000     10.940677

# %%
data = data.dropna()
data.describe()
# Out:
#                  key        ItemID  label_relevanceGrade  \
# count   78493.000000  78493.000000          78493.000000
# mean    98353.149287  38385.733390              5.254774
# std     70253.061135  22259.156287              1.334363
# min         1.000000      1.000000              0.000000
# 25%     39212.000000  19088.000000              5.000000
# 50%     78584.000000  38316.000000              6.000000
# 75%    157548.000000  57660.000000              6.000000
# max    234520.000000  77080.000000              6.000000
#
#        label_relevanceBinary     feature_1     feature_2     feature_3  \
# count           78493.000000  78493.000000  78493.000000  78493.000000
# mean                0.683526   2821.567172      0.562598     -7.754471
# std                 0.465103    834.042432      0.496069      1.162636
# min                 0.000000  -1890.000000      0.000000    -13.563713
# 25%                 0.000000   2676.618000      0.000000     -8.285108
# 50%                 1.000000   2676.618000      1.000000     -7.651790
# 75%                 1.000000   3237.285645      1.000000     -7.390667
# max                 1.000000   5286.000000      1.000000     -2.726150
#
#           feature_4     feature_5     feature_6       feature_7  \
# count  78493.000000  78493.000000  78493.000000    78493.000000
# mean      -4.281164     47.528829      0.374066    50762.626642
# std        0.753205     24.222072      0.280593   228237.868119
# min      -10.324562      0.000000      0.000000        0.000000
# 25%       -4.736623     30.808287      0.101141        0.000000
# 50%       -4.327510     44.190533      0.365175      191.000000
# 75%       -3.766839     60.078297      0.613038     4706.000000
# max       -1.106641    273.239624      1.000000  3339990.000000
#
#            feature_8     feature_9    feature_10
# count    78493.00000  78493.000000  78493.000000
# mean   -240647.46213    171.256023    -62.984023
# std     527631.90141     41.400772     48.710849
# min   -1000000.00000      0.000000   -100.000000
# 25%   -1000000.00000    144.000000   -100.000000
# 50%          0.00000    172.000000   -100.000000
# 75%      98130.00000    203.000000      0.620932
# max    1000000.00000    240.000000     10.940677

# %%
from bokeh.charts import defaults, Bar, output_notebook, show
defaults.plot_width = 500
defaults.plot_height = 300
output_notebook(hide_banner=True)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>

# %% [markdown]
# We can see that low relevance results are under represented:

# %%
p = Bar(data, 'label_relevanceGrade',  values='label_relevanceGrade', agg='count', title="Distribution of Relevance Grade")
show(p)
# Out:
#     <div class="plotdiv" id="4a915d27-0fc8-4b0a-8972-c206c21f9bf6"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4a915d27-0fc8-4b0a-8972-c206c21f9bf6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4a915d27-0fc8-4b0a-8972-c206c21f9bf6' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"dd3d5ba6-24cd-4761-bc14-ad794f7f5a88": {"version": "0.11.0", "roots": {"root_ids": ["b700911f-15fe-42a1-a845-52b8ed09d44a"], "references": [{"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "c0408234-2fc2-4d3f-89d3-89ee4b1a19b1"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "fd253dc9-b8f9-42dd-a786-0dab1aee6acd"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "6132cb30-3cbc-4be4-8fe3-a66f71acee98"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "b700911f-15fe-42a1-a845-52b8ed09d44a"}, "axis_label": "Count( Label_Relevancegrade )", "formatter": {"type": "BasicTickFormatter", "id": "278ee5fc-634c-4061-be6f-3df964921e66"}, "ticker": {"type": "BasicTicker", "id": "3849333f-5991-4d63-873c-f9c5bbf576bc"}}, "type": "LinearAxis", "id": "7e7df0dd-7834-4075-8bdf-6b843fb0429b"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "5a28467a-1919-47e8-918b-4e3064454603"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "6132cb30-3cbc-4be4-8fe3-a66f71acee98"}}, "type": "GlyphRenderer", "id": "2918299b-cabd-425b-abb7-69a3546aca8f"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "b700911f-15fe-42a1-a845-52b8ed09d44a"}}, "type": "PanTool", "id": "4e184564-e114-4916-8a38-34041023712d"}, {"attributes": {"callback": null, "factors": ["0", "1", "2", "3", "4", "5", "6"]}, "type": "FactorRange", "id": "56d41531-4b3f-4aa5-8084-6e1f8b58915d"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"label_relevanceGrade": 6}], "color": ["#f22c40"], "label_relevanceGrade": [6], "fill_alpha": [0.8], "height": [53652.0], "width": [0.8], "y": [26826.0], "x": ["6"]}}, "type": "ColumnDataSource", "id": "b2d52639-214b-43c4-8d15-b8b714d9a7d7"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "b700911f-15fe-42a1-a845-52b8ed09d44a"}}, "type": "WheelZoomTool", "id": "946bf5d2-c85a-443b-8385-a4dd79ee566a"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "b700911f-15fe-42a1-a845-52b8ed09d44a"}}, "type": "HelpTool", "id": "4950480d-d274-4073-b33a-553b84377a4a"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "739536c4-49b8-4876-8ec7-03f4e83b6899"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "effa2b59-c092-4d7d-a9ef-8358a1b3a466"}}, "type": "GlyphRenderer", "id": "b05da45e-1985-4028-b44e-5a6adc2cffbf"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "b2d52639-214b-43c4-8d15-b8b714d9a7d7"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "ec2d8663-ce71-4c59-a0c3-2bc24f9c6f9d"}}, "type": "GlyphRenderer", "id": "da07ff84-4092-4b07-83ed-7da6142c2d5b"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"label_relevanceGrade": 4}], "color": ["#f22c40"], "label_relevanceGrade": [4], "fill_alpha": [0.8], "height": [3883.0], "width": [0 ...

# %% [markdown]
# For machine learning a lazy algorithm could predict grade 6 for everything.  Predicting the rarer class 0 or 1 has less payoff.  To 'encourage' our algorithm to more discriminating classification we can turn the 6-level relevance score into a binary target.  Now it does not pay to classify everything as relevant.

# %%
p = Bar(data, 'label_relevanceBinary',  values='label_relevanceBinary', agg='count', title="Distribution of Relevance Grade")
show(p)
# Out:
#     <div class="plotdiv" id="5b0d787e-681d-4be2-865a-c137f64fc7f2"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5b0d787e-681d-4be2-865a-c137f64fc7f2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5b0d787e-681d-4be2-865a-c137f64fc7f2' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9139a5a2-ee2a-426a-a9e7-3107d788256a": {"version": "0.11.0", "roots": {"root_ids": ["b700911f-15fe-42a1-a845-52b8ed09d44a", "9f7c63fa-2736-4f63-85dc-d2ac3b914832"], "references": [{"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "c0408234-2fc2-4d3f-89d3-89ee4b1a19b1"}, {"attributes": {"x_range": {"type": "FactorRange", "id": "603ee792-847a-4392-a0ea-7fa6c6af56a5"}, "y_mapper_type": "auto", "title_text_font_size": {"value": "14pt"}, "title": "Distribution of Relevance Grade", "y_range": {"type": "Range1d", "id": "90b5353f-864a-4115-b71c-4212bfb28dad"}, "x_mapper_type": "auto", "yscale": "auto", "renderers": [{"type": "BoxAnnotation", "id": "c6f5d932-c642-48e0-ac9e-7539f9d25a0a"}, {"type": "GlyphRenderer", "id": "f3308c23-af29-48f5-8fb5-32076e9ca32a"}, {"type": "GlyphRenderer", "id": "efa3223d-b673-4761-a6f5-403bf7dc8ce2"}, {"type": "CategoricalAxis", "id": "69816547-66bb-405e-99df-5cbcb1cdb260"}, {"type": "LinearAxis", "id": "7da7e58b-a686-48b1-bac2-6a306512e75d"}, {"type": "Grid", "id": "0ff72282-7588-423f-b2e4-a615dad375e5"}], "plot_width": 500, "xgrid": false, "below": [{"type": "CategoricalAxis", "id": "69816547-66bb-405e-99df-5cbcb1cdb260"}], "tool_events": {"type": "ToolEvents", "id": "30f21015-f766-4b54-a049-1d25090261c4"}, "plot_height": 300, "xscale": "auto", "tools": [{"type": "PanTool", "id": "bfe91a17-d92e-46c2-9926-8112e58488c7"}, {"type": "WheelZoomTool", "id": "0e6a7be5-6edf-45d9-b82c-c1e5a5d2fd99"}, {"type": "BoxZoomTool", "id": "ec899919-c474-439c-ae30-8f9c9f695b41"}, {"type": "PreviewSaveTool", "id": "d4e6a4e9-a77e-4622-b69e-81f9298bd1b6"}, {"type": "ResizeTool", "id": "b84da330-b8d5-47ed-8718-90bcc968610c"}, {"type": "ResetTool", "id": "265d7b0f-ab7e-45e4-aeb1-1b57fc3b8317"}, {"type": "HelpTool", "id": "4b43288f-83bb-48eb-a6f5-41ad284dbdd8"}], "legend": null, "left": [{"type": "LinearAxis", "id": "7da7e58b-a686-48b1-bac2-6a306512e75d"}]}, "type": "Plot", "id": "9f7c63fa-2736-4f63-85dc-d2ac3b914832", "subtype": "Chart"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "1bf020f7-5e94-4ecc-aa77-928b235266ce"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "9f7c63fa-2736-4f63-85dc-d2ac3b914832"}}, "type": "HelpTool", "id": "4b43288f-83bb-48eb-a6f5-41ad284dbdd8"}, {"attributes": {}, "type": "CategoricalTicker", "id": "e427be0a-0f5e-46ad-9c0b-8e82a2d47a7d"}, {"attributes": {"callback": null, "factors": ["0.0", "1.0"]}, "type": "FactorRange", "id": "603ee792-847a-4392-a0ea-7fa6c6af56a5"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "b700911f-15fe-42a1-a845-52b8ed09d44a"}, "ticker": {"type": "BasicTicker", "id": "3849333f-5991-4d63-873c-f9c5bbf576bc"}, "dimension": 1}, "type": "Grid", "id": "8144498c-19a0-4ba4-9daa-633287209ead"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "6132cb30-3cbc-4be4-8fe3-a66f71acee98"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "b700911f-15fe-42a1-a845-52b8ed09d44a"}, "axis_label": "Count( Label_Relevancegrade )", "formatter": {"type": "BasicTickFormatter", "id": "278ee5fc-634c-4061-be6f-3df964921e66"}, "ticker": {"type": "BasicTicker", "id": "3849333f-5991-4d63-873c-f9c5bbf576bc"}}, "type": "LinearAxis", "id": "7e7df0dd-7834-4075-8bdf-6b843fb0429b"}, {"attributes": {"nonselection_glyph ...

# %% [markdown]
# Let's look at the relationship between this binary relevance target and the features.

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied (use --upgrade to upgrade): seaborn in /home/csumb/anaconda2/lib/python2.7/site-packages
# You are using pip version 8.0.2, however version 8.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# %matplotlib inline
# import seaborn as sns;
# sns.set(style="ticks", color_codes=True)
# sns.pairplot(data[["feature_1", "feature_2", "feature_3", "feature_4", "feature_5", "feature_6",
#                   "feature_7", "feature_8", "feature_9", "feature_10"]])

# %%
# boxplot feature_1 by relevance label
from bokeh.io import gridplot
from bokeh.charts import BoxPlot, output_file, show

defaults.plot_width = 400
defaults.plot_height = 300

def bplot(feature):
    return BoxPlot(data, values=feature, label="label_relevanceBinary", outliers=False)

p = gridplot ( [ 
        [ bplot("feature_1"), bplot("feature_2") ],
        [ bplot("feature_3"), bplot("feature_4") ],
        [ bplot("feature_5"), bplot("feature_6") ],
        [ bplot("feature_7"), bplot("feature_8") ],
        [ bplot("feature_9"), bplot("feature_10") ] ] ) 
show(p)
# Out:
#     <div class="plotdiv" id="3116751f-d7bb-4b19-8ecc-f6e3b8b2f9e2"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3116751f-d7bb-4b19-8ecc-f6e3b8b2f9e2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3116751f-d7bb-4b19-8ecc-f6e3b8b2f9e2' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1064c4a2-2eda-4710-a9e2-aaa7b2907820": {"version": "0.11.0", "roots": {"root_ids": ["b700911f-15fe-42a1-a845-52b8ed09d44a", "9f7c63fa-2736-4f63-85dc-d2ac3b914832", "51bdc123-5931-420a-8595-e8216b6e9bf1", "41706179-c4f8-4e45-956c-05714246e8b9", "f0b39f06-1a59-4cdb-95c6-e37390b74a3d", "7f50f19a-f99f-4ece-b4ec-3dd0bca0571c", "7e175caf-0b79-4937-8971-e9c06a09ce27"], "references": [{"attributes": {"callback": null, "column_names": ["x0s", "y0s", "x1s", "y1s"], "data": {"y0s": [-0.6912592104240174, -0.6912592104240174, 0.48226780694934496, 1.1863840173733624], "chart_index": [{"label_relevanceBinary": 0.0}, {"label_relevanceBinary": 0.0}, {"label_relevanceBinary": 0.0}, {"label_relevanceBinary": 0.0}], "x0s": ["0.0:0.5", "0.0:0.65", "0.0:0.5", "0.0:0.65"], "x1s": ["0.0:0.5", "0.0:0.35", "0.0:0.5", "0.0:0.35"], "label_relevanceBinary": [0.0, 0.0, 0.0, 0.0], "y1s": [0.012856999999999999, -0.6912592104240174, 1.1863840173733624, 1.1863840173733624]}}, "type": "ColumnDataSource", "id": "37b3dca7-596c-4875-84be-492d39c7cd75"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["black"], "line_alpha": [1.0], "chart_index": [{"label_relevanceBinary": 1.0}], "color": ["DimGrey"], "fill_alpha": [0.8], "height": [32.0], "width": [0.8], "y": [188.0], "x": ["1.0"], "label_relevanceBinary": [1.0]}}, "type": "ColumnDataSource", "id": "50c5d0c4-6268-4bf1-99c0-a8ae109f02bc"}, {"attributes": {"callback": null, "column_names": ["x0s", "y0s", "x1s", "y1s"], "data": {"y0s": [-0.5193078978062555, -0.5193078978062555, 0.6532865, 1.3568431386837534], "chart_index": [{"label_relevanceBinary": 1.0}, {"label_relevanceBinary": 1.0}, {"label_relevanceBinary": 1.0}, {"label_relevanceBinary": 1.0}], "x0s": ["1.0:0.5", "1.0:0.65", "1.0:0.5", "1.0:0.65"], "x1s": ["1.0:0.5", "1.0:0.35", "1.0:0.5", "1.0:0.35"], "label_relevanceBinary": [1.0, 1.0, 1.0, 1.0], "y1s": [0.18424874087749776, -0.5193078978062555, 1.3568431386837534, 1.3568431386837534]}}, "type": "ColumnDataSource", "id": "33b56770-be1d-44c3-8625-84a95173160d"}, {"attributes": {"callback": null, "column_names": ["x0s", "y0s", "x1s", "y1s"], "data": {"y0s": [-1.5, -1.5, 1.0, 2.5], "chart_index": [{"label_relevanceBinary": 0.0}, {"label_relevanceBinary": 0.0}, {"label_relevanceBinary": 0.0}, {"label_relevanceBinary": 0.0}], "x0s": ["0.0:0.5", "0.0:0.65", "0.0:0.5", "0.0:0.65"], "x1s": ["0.0:0.5", "0.0:0.35", "0.0:0.5", "0.0:0.35"], "label_relevanceBinary": [0.0, 0.0, 0.0, 0.0], "y1s": [0.0, -1.5, 2.5, 2.5]}}, "type": "ColumnDataSource", "id": "1ba56613-3495-4118-9140-85fecdf81df1"}, {"attributes": {"major_label_orientation": 0.7853981633974483, "plot": {"subtype": "Chart", "type": "Plot", "id": "7a02425f-a7fc-4f23-9cbe-1342d7f93a40"}, "axis_label": "Label_Relevancebinary", "formatter": {"type": "CategoricalTickFormatter", "id": "592fef21-9056-4caa-9dc6-4a00f4d697b2"}, "ticker": {"type": "CategoricalTicker", "id": "55e83721-bb12-4acb-afa4-d3fe058017a5"}}, "type": "CategoricalAxis", "id": "60ea5e33-8385-4218-b78f-420cf69e257f"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "017c73cd-b4d5-4b4d-88c0-688d316c96ba"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "c61a801a-4ab0-4756-984e-7aabbc527913"}}, "type": "GlyphRenderer", "id": "8ea17205-8a20-4ce1-be49-ac245e9691de"}, {"attributes": {}, "type": "BasicTicker", "id": "0f6da6eb-1ceb-4c0b-8f23-e3965f2fbe30"}, {"attributes": {}, "type": "BasicTicker", "id": "3fe2aff9-a4ea-4c96-862d-3b1406be60ae"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["black"], "line_alpha": [1.0], "chart_index": [{"label_relevanceBinary": 0.0}], "color": ["DimGrey"], "fill_alpha": [0.8], "height": [0.0], "width": [0.8], "y": [0.0], "x": ["0.0"], "label_relevanceBinary ...

# %% [markdown]
# ## Training / Test data
#
# When machine learning we train on one data set and measure performance on another - this ensures that our performance metrics are representative of the actual performance of the model - this helps avoid overfitting.

# %%
from sklearn.cross_validation import train_test_split

X = data[["feature_1", "feature_2", "feature_3", "feature_4", "feature_5", "feature_6",
          "feature_7", "feature_8", "feature_9", "feature_10"]]
y = data[["label_relevanceBinary"]]

X_train, y_train, X_test, y_test = train_test_split(X, y, test_size = 0.25, random_state=73)

print("X training : " + str(X_train.shape))
print("X test     : " + str(y_train.shape))
print("y training : " + str(X_test.shape))
print("y test     : " + str(y_test.shape))
# Out:
# X training : (58869, 10)
# X test     : (19624, 10)
# y training : (58869, 1)
# y test     : (19624, 1)

# %% [markdown]
# ## Naive Model
#
# Model 01 - just predict everything to be relevant and check performance - this is our baseline.
#
# We now need to define the metric we are going to use to evaluate and compare models.  There are many classification metrics - based on the cells in the confusion matrix - expand this.
#
# |                  || *Predicted*  | *Class*   ||
# |------------------||--------------------------|||
# |                  ||     -    |    +    | Total |
# |*True*   |   -     |   TN     |    FP   |  N    |
# |*Classs* |   +     |   FN     |    TP   |  P    |
# |         | Total   |   N*     |    P*   |       |
#
#
# Now we can define metrics based on the contingency table:
#
# | Name                      |   Definition  |   Synonyms                                  |
# |---------------------------|---------------|---------------------------------------------|
# | False Positive Rate       |   FP / N      | Type-I error, 1-Specificity                 |
# | True Positive Rate        |   TP / P      | 1-Type II error, power, sensitivity, recall |
# | Positive Predictive Value |   TP / P*     | Precision, 1-false discovery proportion     |
# | Negative Predictive Value |   TN / N*     |                                             |
#
#
# Visual for this at https://en.wikipedia.org/wiki/Precision_and_recall - be careful not to introduce confusion here.  For the course we could just optimise on F1?
#
# Sometimes we talk about the accuracy of a model as:
#
# $
# accuracy = \frac{(TP + TN)}{( N + P )}
# $
#
#
# Generally we are interested in precision and recall.
#
# * Precision
#     * The fraction of cases predicted to be positive that are actually positive
#     * High precision is acheived by ensuring that all the predicted positive cases are actually positive
#     * Quality
# * Recall
#     * The fraction of the positive cases predicted to be positive
#     * High recall is acheived by a model predicts as many of the positive cases as possible
#     * Quantity
#
# We can also define classification metrics that compbine both precision and recall.  The F1-score is one such metric that computes the geometric mean of precision and recall - applying equal emphasis to precision as recall:
#
# $
# F_1 = 2 \times \frac{ precision . recall}{precision + recall}
# $
#
# But we may choose to attach emphasis to recall:
#
# $
# F_2 = 5 \times \frac{ precision . recall}{ (4 . precision) + recall}
# $
#
# Or we may choose to place higher emphasis on precision:
#
# $
# F_{0.5} = 1.25 \times \frac{ precision . recall}{( 0.25 . precision) + recall}
# $

# %%
y_pred_01 = [1] * y_test.shape[0]

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
print(confusion_matrix(y_test, y_pred_01))
print(classification_report(y_test, y_pred_01))
print(accuracy_score(y_test, y_pred_01))
# Out:
# [[    0  6198]
#  [    0 13426]]
#              precision    recall  f1-score   support
#
#         0.0       0.00      0.00      0.00      6198
#         1.0       0.68      1.00      0.81     13426
#
# avg / total       0.47      0.68      0.56     19624
#
# 0.684162250306

# %% [markdown]
# We can see that recall is 100% - we predicted every value that was positive correctly - but precision is low - of those predicted to be positve only 68% were actually postive.  This yields and F1 score of 81%.  This is our baseline.

# %% [markdown]
# ## Support Vector Machine
#
# SVMs are the default go to classification algorithm.  They are fast, scalable and relatively simple despite the scary name!
#
# To fit an SVM, and in general when performing Machine Learning, we scale the data to have zero mean and unit standard deviation - this ensures that the algorithms do not over rely on features with large values.
