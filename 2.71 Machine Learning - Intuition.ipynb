# %% [markdown]
# ## 2.71 Machine Learning - Intuition
#
# Let's start by creating a simulated data set:

# %%
from sklearn import datasets
import numpy as np

n = 50
x, y, coef = datasets.make_regression(n_samples = n, n_features = 1, 
                                      n_informative = 1, noise = 10, 
                                      coef = True, random_state = 0)
x = x.flatten()

# %% [markdown]
# Let's plot the data:

# %%
from bokeh.plotting import figure, output_notebook, show
output_notebook(hide_banner=True)
p = figure(plot_width = 400, plot_height = 400)
p.circle(x, y, size=10, color="orange")
p.xaxis.axis_label='x'
p.yaxis.axis_label='y'
show(p)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div class="plotdiv" id="73af42a4-76e3-4565-8a54-05e7c854d90b"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("73af42a4-76e3-4565-8a54-05e7c854d90b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '73af42a4-76e3-4565-8a54-05e7c854d90b' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5a09e12e-3f8d-4ec9-a896-50594cc4920c": {"version": "0.11.0", "roots": {"root_ids": ["a09f1ffb-998c-474e-b959-0b4718bd231c"], "references": [{"attributes": {}, "type": "ToolEvents", "id": "b9f9d4fa-c699-4a78-83e4-7e9bf2b9ed52"}, {"attributes": {"x_range": {"type": "DataRange1d", "id": "5a1a7292-2d07-47a5-84f7-c7f0972c2355"}, "y_range": {"type": "DataRange1d", "id": "25491398-22c6-45bb-b67b-294333cd7bd0"}, "renderers": [{"type": "LinearAxis", "id": "578a9207-6a7f-4a95-ac3a-36dae6044410"}, {"type": "Grid", "id": "2c444286-d28c-4458-997d-8682a73b2597"}, {"type": "LinearAxis", "id": "2c44f95f-7459-4c8a-8898-d7b4d15629af"}, {"type": "Grid", "id": "d2de00f2-a71b-4861-b3f8-a2487240990e"}, {"type": "BoxAnnotation", "id": "39413940-bae7-4899-b806-b20caee3c608"}, {"type": "GlyphRenderer", "id": "ad7f694c-1d77-4f16-a95e-063e81ba3357"}], "plot_width": 400, "below": [{"type": "LinearAxis", "id": "578a9207-6a7f-4a95-ac3a-36dae6044410"}], "tool_events": {"type": "ToolEvents", "id": "b9f9d4fa-c699-4a78-83e4-7e9bf2b9ed52"}, "plot_height": 400, "tools": [{"type": "PanTool", "id": "20a7e2d4-cf54-41e2-aa2f-b3c9202fedb3"}, {"type": "WheelZoomTool", "id": "9dbd45de-a2f6-4e16-9076-b55d2f9994de"}, {"type": "BoxZoomTool", "id": "5cada815-05c3-4393-96ea-108c4fa123ea"}, {"type": "PreviewSaveTool", "id": "1455eb5f-296b-45c7-95b3-e897c4412e42"}, {"type": "ResizeTool", "id": "51fd7b78-03bc-4b42-8de3-7b7ff5b14750"}, {"type": "ResetTool", "id": "610247b6-e2ab-4411-92d7-7b18cf50169f"}, {"type": "HelpTool", "id": "658f3206-8ab2-4e75-82c0-d9828de791d8"}], "left": [{"type": "LinearAxis", "id": "2c44f95f-7459-4c8a-8898-d7b4d15629af"}]}, "type": "Plot", "id": "a09f1ffb-998c-474e-b959-0b4718bd231c", "subtype": "Figure"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "25491398-22c6-45bb-b67b-294333cd7bd0"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "a09f1ffb-998c-474e-b959-0b4718bd231c"}}, "type": "PreviewSaveTool", "id": "1455eb5f-296b-45c7-95b3-e897c4412e42"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "a09f1ffb-998c-474e-b959-0b4718bd231c"}, "ticker": {"type": "BasicTicker", "id": "7d4e755d-0cef-493d-9f93-ead03a63ffdc"}, "dimension": 1}, "type": "Grid", "id": "d2de00f2-a71b-4861-b3f8-a2487240990e"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "a09f1ffb-998c-474e-b959-0b4718bd231c"}}, "type": "HelpTool", "id": "658f3206-8ab2-4e75-82c0-d9828de791d8"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "b73158b8-8c2a-4174-9f8a-409212f072ad"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "a09f1ffb-998c-474e-b959-0b4718bd231c"}, "ticker": {"type": "BasicTicker", "id": "6295e5f7-4202-40bc-a9b5-5e1f6ee3c80a"}}, "type": "Grid", "id": "2c444286-d28c-4458-997d-8682a73b2597"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "5a1a7292-2d07-47a5-84f7-c7f0972c2355"}, {"attributes": {"line_color": {"value": "black"}, "line_alpha": {"value": 1.0}, "render_mode": "css", "bottom_units": "screen", "level": "overlay", "top_units": "screen", "fill_alpha": {"value": 0.5}, "plot": null, "left_units": "screen", "line_dash": [4, 4], "line_width": {"value": 2}, "right_units": "screen", "fill_color": {"value": "lightgrey"}}, "type": "BoxAnnotation", "id": "39413940-bae7-4899-b806-b20caee3c608"}, {"attributes": {"callback": null, "column_names": ["y", "x"], "data": {"y": [-30.834237922894395, 29.949323452563004, -19.986100768531568, 0.3058570148854507, 7.203146626795629, 40.885611234689996, 12.995068261249575, -17.74891775667451, -28.432194770844685, 11.677696838826343, 12.485308879314388, 14.650292234870447, 11.715700292501701, 1.634067609102365, 27.78240131214845, -6.913901754501939, -19.308353131576368, 13.119032535423669, -38.97818740395834, 31.156701729506093, -8.919215951322636, -20.11496997103196, -9.181611577211118, -4.891221208945573, 8.561906465706286, -1.3534884659172643, -3.364314969881868, 25.155779465665834, -1.435 ...

# %% [markdown]
# It looks like a linear model is most likely representative of the true unknown function that relates x to y.
#
# The equation of a line is:
#
# $y = \alpha + \beta x$
#
# By adjusting the two parameters $\alpha$ and $\beta$ we get an infinite number of possible lines.  For example we could set  $\alpha = 3.5$ and $\beta = 10$:

# %%
a = 3.5
b = 10
xl = np.arange(-3,3,0.1)
yl = a + b * xl
yp = a + b * x

output_notebook(hide_banner=True)

p = figure(plot_width = 400, plot_height = 400)
p.circle(x, y, size=10, color="orange")
p.line(xl, yl, line_width=5)
p.xaxis.axis_label='x'
p.yaxis.axis_label='y'
show(p)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div class="plotdiv" id="73b56718-354b-4c91-b1e0-1bd2aabd54d8"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("73b56718-354b-4c91-b1e0-1bd2aabd54d8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '73b56718-354b-4c91-b1e0-1bd2aabd54d8' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"81030fa4-d828-47a2-a610-732aebc22fc4": {"version": "0.11.0", "roots": {"root_ids": ["a09f1ffb-998c-474e-b959-0b4718bd231c", "bb031dfe-f2d8-49f2-a75f-b0d7af067cd7"], "references": [{"attributes": {}, "type": "ToolEvents", "id": "b9f9d4fa-c699-4a78-83e4-7e9bf2b9ed52"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "bb031dfe-f2d8-49f2-a75f-b0d7af067cd7"}}, "type": "ResetTool", "id": "7ea605ff-c297-46c0-a579-f6a7f4a7ae8b"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}, "size": {"units": "screen", "value": 10}}, "type": "Circle", "id": "56731ac6-8449-4836-90d9-78a1c5f25cf8"}, {"attributes": {"line_color": {"value": "orange"}, "x": {"field": "x"}, "y": {"field": "y"}, "fill_color": {"value": "orange"}, "size": {"units": "screen", "value": 10}}, "type": "Circle", "id": "56f80a66-417a-4d45-b99e-8b32fd07da62"}, {"attributes": {"x_range": {"type": "DataRange1d", "id": "5a1a7292-2d07-47a5-84f7-c7f0972c2355"}, "y_range": {"type": "DataRange1d", "id": "25491398-22c6-45bb-b67b-294333cd7bd0"}, "renderers": [{"type": "LinearAxis", "id": "578a9207-6a7f-4a95-ac3a-36dae6044410"}, {"type": "Grid", "id": "2c444286-d28c-4458-997d-8682a73b2597"}, {"type": "LinearAxis", "id": "2c44f95f-7459-4c8a-8898-d7b4d15629af"}, {"type": "Grid", "id": "d2de00f2-a71b-4861-b3f8-a2487240990e"}, {"type": "BoxAnnotation", "id": "39413940-bae7-4899-b806-b20caee3c608"}, {"type": "GlyphRenderer", "id": "ad7f694c-1d77-4f16-a95e-063e81ba3357"}], "plot_width": 400, "below": [{"type": "LinearAxis", "id": "578a9207-6a7f-4a95-ac3a-36dae6044410"}], "tool_events": {"type": "ToolEvents", "id": "b9f9d4fa-c699-4a78-83e4-7e9bf2b9ed52"}, "plot_height": 400, "tools": [{"type": "PanTool", "id": "20a7e2d4-cf54-41e2-aa2f-b3c9202fedb3"}, {"type": "WheelZoomTool", "id": "9dbd45de-a2f6-4e16-9076-b55d2f9994de"}, {"type": "BoxZoomTool", "id": "5cada815-05c3-4393-96ea-108c4fa123ea"}, {"type": "PreviewSaveTool", "id": "1455eb5f-296b-45c7-95b3-e897c4412e42"}, {"type": "ResizeTool", "id": "51fd7b78-03bc-4b42-8de3-7b7ff5b14750"}, {"type": "ResetTool", "id": "610247b6-e2ab-4411-92d7-7b18cf50169f"}, {"type": "HelpTool", "id": "658f3206-8ab2-4e75-82c0-d9828de791d8"}], "left": [{"type": "LinearAxis", "id": "2c44f95f-7459-4c8a-8898-d7b4d15629af"}]}, "type": "Plot", "id": "a09f1ffb-998c-474e-b959-0b4718bd231c", "subtype": "Figure"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "bb031dfe-f2d8-49f2-a75f-b0d7af067cd7"}, "ticker": {"type": "BasicTicker", "id": "8a81d50e-264e-4adb-97e6-e5d68972ba18"}, "dimension": 1}, "type": "Grid", "id": "6b3c408b-1351-4e54-9db7-89ddb9566e69"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "25491398-22c6-45bb-b67b-294333cd7bd0"}, {"attributes": {}, "type": "BasicTicker", "id": "8a81d50e-264e-4adb-97e6-e5d68972ba18"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "bb031dfe-f2d8-49f2-a75f-b0d7af067cd7"}}, "type": "ResizeTool", "id": "0ba975b8-09e5-46c9-88d2-cc3881e52679"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "bb031dfe-f2d8-49f2-a75f-b0d7af067cd7"}}, "type": "PanTool", "id": "304654ea-e431-495f-bc1a-e49d5edbf667"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "bb031dfe-f2d8-49f2-a75f-b0d7af067cd7"}}, "type": "WheelZoomTool", "id": "d871a1cb-ae8a-457d-bf2c-c79a5eb812a5"}, {"attributes": {"nonselection_glyph": {"type": "Line", "id": "93b01033-80f8-4fb8-ad02-9f3cf736e63a"}, "data_source": {"type": "ColumnDataSource", "id": "12e3070f-b955-4e3b-9f49-76e97919420f"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Line", "id": "64e9518c-927b-4c1f-bc4e-7d716b41e81e"}}, "type": "GlyphRenderer", "id": "21bfdc97-9f53-49ea-83d7-8e5c0ef87dda"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x" ...

# %% [markdown]
# For any line we can compute the difference between the $y$'s in our data and the $\hat{y}$'s predicted by the equation.  From this difference we can define a simple metric that measures how well the line explains the data:
#
# $MSE = \frac{1}{N}\sum{(y_i - \hat{y}_i) ^ 2}$
#
# For example with $\alpha = 3.5$ and $\beta = 10$ - we can plot the distance between the points ($y$) and the points predicted by the equation ($\hat{y}$):

# %%
lx = [ [x1, x1] for x1 in x]
ly = [ [y1, y2] for (y1, y2) in zip(y, yp)]
p = figure(plot_width = 400, plot_height = 400)
p.multi_line(xs=lx, ys=ly, line_width = 2, color="gray")
p.circle(x, y, size=10, color="orange")
p.line(xl, yl, line_width=5)
p.xaxis.axis_label='x'
p.yaxis.axis_label='y'
show(p)
# Out:
#     <div class="plotdiv" id="fdb53167-c8c2-4ab5-97f9-52eeb0a321c7"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fdb53167-c8c2-4ab5-97f9-52eeb0a321c7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fdb53167-c8c2-4ab5-97f9-52eeb0a321c7' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"367aa3b7-c7b8-4f92-8b6a-8564a1256f20": {"version": "0.11.0", "roots": {"root_ids": ["a09f1ffb-998c-474e-b959-0b4718bd231c", "bb031dfe-f2d8-49f2-a75f-b0d7af067cd7", "78f0e21f-2358-4467-b68d-9beb6c01ba2b"], "references": [{"attributes": {}, "type": "ToolEvents", "id": "b9f9d4fa-c699-4a78-83e4-7e9bf2b9ed52"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "bb031dfe-f2d8-49f2-a75f-b0d7af067cd7"}}, "type": "ResetTool", "id": "7ea605ff-c297-46c0-a579-f6a7f4a7ae8b"}, {"attributes": {"callback": null, "column_names": ["y", "x"], "data": {"y": [-30.834237922894395, 29.949323452563004, -19.986100768531568, 0.3058570148854507, 7.203146626795629, 40.885611234689996, 12.995068261249575, -17.74891775667451, -28.432194770844685, 11.677696838826343, 12.485308879314388, 14.650292234870447, 11.715700292501701, 1.634067609102365, 27.78240131214845, -6.913901754501939, -19.308353131576368, 13.119032535423669, -38.97818740395834, 31.156701729506093, -8.919215951322636, -20.11496997103196, -9.181611577211118, -4.891221208945573, 8.561906465706286, -1.3534884659172643, -3.364314969881868, 25.155779465665834, -1.435828314642782, 31.958146477582183, 21.758701623480608, 6.257079163269004, -19.59217687985094, 28.465314318741775, -1.3989221885463117, 10.849473027121014, 16.33075149631359, 3.3934786911339296, 6.686828600088303, 3.976564328388215, 27.698885099959213, -2.685831073181126, -5.473212035423796, -3.036227752536538, 1.8006943917119322, 19.357450000743864, 18.85230743598863, 4.323822233561039, -7.593606657630701, -16.23356659738172], "x": [-0.8540957393017248, 1.4940790731576061, -0.3479121493261526, 0.44386323274542566, -0.1871838500258336, 1.8675579901499675, 0.41059850193837233, -1.7062701906250126, -1.4200179371789752, 0.8644361988595057, 0.9787379841057392, -0.20515826376580087, 0.1549474256969163, -0.5096521817516535, 1.5327792143584575, -0.7421650204064419, -1.4543656745987648, -0.10321885179355784, -2.5529898158340787, 1.764052345967664, -1.2527953600499262, -0.977277879876411, 0.04575851730144607, -0.4380743016111864, 0.7610377251469934, 0.144043571160878, -0.2127402802139687, 1.2023798487844113, -0.3873268174079523, 2.240893199201458, 0.7774903558319101, 0.15634896910398005, -1.6138978475579515, 1.9507753952317897, 0.4001572083672233, 1.469358769900285, 1.454273506962975, -0.30230275057533557, 0.31306770165090136, 0.33367432737426683, 2.2697546239876076, -0.1513572082976979, 0.12167501649282841, 0.37816251960217356, 0.6536185954403606, 0.9500884175255894, 1.2302906807277207, -0.8877857476301128, -1.0485529650670926, -1.980796468223927]}}, "type": "ColumnDataSource", "id": "b9ba2bfd-3728-4f62-aec5-4733f0292605"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "5272a91d-2f78-442c-98af-5f4fd54f1202"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "78f0e21f-2358-4467-b68d-9beb6c01ba2b"}}, "type": "ResetTool", "id": "723d4073-ceca-420f-b843-9b4d945882f1"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}, "size": {"units": "screen", "value": 10}}, "type": "Circle", "id": "56731ac6-8449-4836-90d9-78a1c5f25cf8"}, {"attributes": {"line_color": {"value": "orange"}, "x": {"field": "x"}, "y": {"field": "y"}, "fill_color": {"value": "orange"}, "size": {"units": "screen", "value": 10}}, "type": "Circle", "id": "56f80a66-417a-4d45-b99e-8b32fd07da62"}, {"attributes": {"callback": null, "column_names": ["y", "x"], "data": {"y": [-26.5, -25.5, -24.5, -23.499999999999996, -22.499999999999996, -21.499999999999996, -20.499999999999993, -19.499999999999993, -18.499999999999993, -17.499999999999993, -16.499999999999993, -15.49999999999999, -14.49999999999999, -13.49999999999999, -12.499999999999988, -11.499999999999986, -10.499999999999986, -9.499999999999986, -8.499999999999984, -7.499999999999982, -6.499999999999982, -5.499999999999982, -4. ...

# %% [markdown]
# We can average the square of the line lengths which gives us the Mean Squared Error.
#
# As we vary $\alpha$ and $\beta$ we get a different MSE - the best fitting line is the one with the lowest MSE.

# %%
from bokeh.charts import Scatter
from bokeh.io import push_notebook
from bokeh.plotting import ColumnDataSource, figure

a = 0
b = 1
xl = np.arange(-3,3,0.1)
yl = a + b * xl
yp = a + b * x

mse = np.sum(np.power(np.subtract(y, yp), 2)) / n
title='MSE = {0:6.2f}'.format(mse)

output_notebook(hide_banner=True)

source_mse = ColumnDataSource(data=dict(text=[title]))
source_line = ColumnDataSource(data=dict(x=xl,y=yl))

p = figure(plot_width = 400, plot_height = 400)
p.circle(x, y, size=10, color="orange")
p.line(xl, yl, source=source_line, line_width=5)
p.xaxis.axis_label='x'
p.yaxis.axis_label='y'
p.text(-3,30, text=[title], source = source_mse)

def update(a, b):
    xl = np.arange(-3,3,0.1)
    yl = a + b * xl
    yp = a + b * x
    mse = np.sum(np.power(np.subtract(y, yp), 2)) / n
    title='MSE = {0:6.2f}'.format(mse)
    source_line.data['x'] = xl
    source_line.data['y'] = yl
    source_mse.data['text'] = [title]
    push_notebook()
    
show(p)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div class="plotdiv" id="00cd9750-2e19-457b-a9f6-06c4f12688c3"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("00cd9750-2e19-457b-a9f6-06c4f12688c3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '00cd9750-2e19-457b-a9f6-06c4f12688c3' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f67168b4-5af0-476d-9299-7f28ac638b7e": {"version": "0.11.0", "roots": {"root_ids": ["a09f1ffb-998c-474e-b959-0b4718bd231c", "bb031dfe-f2d8-49f2-a75f-b0d7af067cd7", "78f0e21f-2358-4467-b68d-9beb6c01ba2b", "bfbac9fe-d2e4-4487-bba8-4136142071bd"], "references": [{"attributes": {}, "type": "ToolEvents", "id": "b9f9d4fa-c699-4a78-83e4-7e9bf2b9ed52"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_width": {"value": 5}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Line", "id": "b4888ac5-5f29-4526-9aff-38b1dc9f72c2"}, {"attributes": {"x_range": {"type": "DataRange1d", "id": "5a1a7292-2d07-47a5-84f7-c7f0972c2355"}, "y_range": {"type": "DataRange1d", "id": "25491398-22c6-45bb-b67b-294333cd7bd0"}, "renderers": [{"type": "LinearAxis", "id": "578a9207-6a7f-4a95-ac3a-36dae6044410"}, {"type": "Grid", "id": "2c444286-d28c-4458-997d-8682a73b2597"}, {"type": "LinearAxis", "id": "2c44f95f-7459-4c8a-8898-d7b4d15629af"}, {"type": "Grid", "id": "d2de00f2-a71b-4861-b3f8-a2487240990e"}, {"type": "BoxAnnotation", "id": "39413940-bae7-4899-b806-b20caee3c608"}, {"type": "GlyphRenderer", "id": "ad7f694c-1d77-4f16-a95e-063e81ba3357"}], "plot_width": 400, "below": [{"type": "LinearAxis", "id": "578a9207-6a7f-4a95-ac3a-36dae6044410"}], "tool_events": {"type": "ToolEvents", "id": "b9f9d4fa-c699-4a78-83e4-7e9bf2b9ed52"}, "plot_height": 400, "tools": [{"type": "PanTool", "id": "20a7e2d4-cf54-41e2-aa2f-b3c9202fedb3"}, {"type": "WheelZoomTool", "id": "9dbd45de-a2f6-4e16-9076-b55d2f9994de"}, {"type": "BoxZoomTool", "id": "5cada815-05c3-4393-96ea-108c4fa123ea"}, {"type": "PreviewSaveTool", "id": "1455eb5f-296b-45c7-95b3-e897c4412e42"}, {"type": "ResizeTool", "id": "51fd7b78-03bc-4b42-8de3-7b7ff5b14750"}, {"type": "ResetTool", "id": "610247b6-e2ab-4411-92d7-7b18cf50169f"}, {"type": "HelpTool", "id": "658f3206-8ab2-4e75-82c0-d9828de791d8"}], "left": [{"type": "LinearAxis", "id": "2c44f95f-7459-4c8a-8898-d7b4d15629af"}]}, "type": "Plot", "id": "a09f1ffb-998c-474e-b959-0b4718bd231c", "subtype": "Figure"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "bb031dfe-f2d8-49f2-a75f-b0d7af067cd7"}, "ticker": {"type": "BasicTicker", "id": "8a81d50e-264e-4adb-97e6-e5d68972ba18"}, "dimension": 1}, "type": "Grid", "id": "6b3c408b-1351-4e54-9db7-89ddb9566e69"}, {"attributes": {}, "type": "BasicTicker", "id": "8a81d50e-264e-4adb-97e6-e5d68972ba18"}, {"attributes": {}, "type": "BasicTicker", "id": "1f4bc89b-e5ba-4af5-9c9b-c9a8e3651bce"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "78f0e21f-2358-4467-b68d-9beb6c01ba2b"}}, "type": "PreviewSaveTool", "id": "95d6f1fb-fbdd-4326-8160-8a541d4a4009"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "ys": {"field": "ys"}, "xs": {"field": "xs"}, "line_width": {"value": 2}}, "type": "MultiLine", "id": "a0ee0863-b9df-4d0b-8361-e2b320e9d880"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "a09f1ffb-998c-474e-b959-0b4718bd231c"}}, "type": "PreviewSaveTool", "id": "1455eb5f-296b-45c7-95b3-e897c4412e42"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "a09f1ffb-998c-474e-b959-0b4718bd231c"}, "ticker": {"type": "BasicTicker", "id": "7d4e755d-0cef-493d-9f93-ead03a63ffdc"}, "dimension": 1}, "type": "Grid", "id": "d2de00f2-a71b-4861-b3f8-a2487240990e"}, {"attributes": {}, "type": "ToolEvents", "id": "56e530c7-f562-4011-a8a9-e684cf85ee16"}, {"attributes": {}, "type": "BasicTicker", "id": "7d4e755d-0cef-493d-9f93-ead03a63ffdc"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "78f0e21f-2358-4467-b68d-9beb6c01ba2b"}, "axis_label": "y", "formatter": {"type": "BasicTickFormatter", "id": "e3e16cbc-940c-4e7a-9a9a-4290f7ee14e3"}, "ticker": {"type": "BasicTicker", "id": "1f4bc89b-e5ba-4af5-9c9b-c9a8e3651bce"}}, "type": "LinearAxis", "id": "18b3c895-ba8c-4cc0-8fe8-7876a6d02851"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "5a1a7292-2d07-47a5-84f7-c7f097 ...

# %%
from ipywidgets import interact
interact(update, a = (-40, 40, 0.5), b = (-20, 20, 0.5))

# %% [markdown]
# We can use 'machine learning' to avoid having to search through parameters:

# %%
from sklearn.linear_model import LinearRegression

xm = x.reshape(-1,1)
model = LinearRegression()
model.fit(xm,y)
print("a   = {0:4.2f}".format(float(model.intercept_)))
print("b   = {0:4.2f}".format(float(model.coef_)))

yp = model.predict(xm)
mse = np.sum(np.power(np.subtract(y, yp), 2)) / n
print('MSE = {0:4.2f}'.format(mse))
# Out:
# a   = 1.71
# b   = 13.92
# MSE = 64.11
