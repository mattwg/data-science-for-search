# %% [markdown]
# ## 2.71 Machine Learning - Intuition
#
# Let's start by creating a simulated data set:

# %%
from sklearn import datasets
import numpy as np

n = 50
x, y, coef = datasets.make_regression(n_samples = n, n_features = 1, 
                                      n_informative = 1, noise = 10, 
                                      coef = True, random_state = 0)
x = x.flatten()

# %% [markdown]
# Let's plot the data:

# %%
from bokeh.plotting import figure, output_notebook, show
output_notebook(hide_banner=True)
p = figure(plot_width = 400, plot_height = 400)
p.circle(x, y, size=10, color="orange")
p.xaxis.axis_label='x'
p.yaxis.axis_label='y'
show(p)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div class="plotdiv" id="3280b56e-f73f-4d13-9350-5c69d6f3caac"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3280b56e-f73f-4d13-9350-5c69d6f3caac");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3280b56e-f73f-4d13-9350-5c69d6f3caac' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"75a2c06f-58b0-4a39-903a-9722311d7b49": {"version": "0.11.0", "roots": {"root_ids": ["9ddfda77-5d6b-41ec-8058-595268e1e93d", "538a24ec-b8dd-4332-83da-a3c8c6d8134a", "621df27d-9c28-45b2-9ef8-8ff54b114c8b", "7c9b1add-4dec-4309-9a50-a0656b45ce97", "7227741b-6c03-4c35-96c4-d9a308068b0c"], "references": [{"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7227741b-6c03-4c35-96c4-d9a308068b0c"}}, "type": "PreviewSaveTool", "id": "d301e5fc-ffc7-45fb-883e-a060c99d4e1b"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7c9b1add-4dec-4309-9a50-a0656b45ce97"}}, "type": "PreviewSaveTool", "id": "11fb6a24-c545-4230-8450-a6558074f27c"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "538a24ec-b8dd-4332-83da-a3c8c6d8134a"}}, "type": "PreviewSaveTool", "id": "4cd09313-16cd-4b47-a7ca-d5f8f29048bd"}, {"attributes": {}, "type": "BasicTicker", "id": "2953051e-688a-45f9-a688-c2539f305ae5"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7c9b1add-4dec-4309-9a50-a0656b45ce97"}, "formatter": {"type": "BasicTickFormatter", "id": "fbfe9ab1-6cbd-45bd-8369-d0a18d9080a0"}, "ticker": {"type": "BasicTicker", "id": "aa0edd44-51e1-4cb5-be46-c78b2b65cc72"}}, "type": "LinearAxis", "id": "8a20701e-4f5e-4b4d-935a-c1883a5e8865"}, {"attributes": {}, "type": "BasicTicker", "id": "aa0edd44-51e1-4cb5-be46-c78b2b65cc72"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "9ddfda77-5d6b-41ec-8058-595268e1e93d"}}, "type": "ResetTool", "id": "b107cfcd-16ea-470f-94b0-f9c90093f228"}, {"attributes": {"y": {"value": 30}, "x": {"value": -3}, "text_alpha": {"value": 0.1}, "text_color": {"value": "black"}}, "type": "Text", "id": "b69024d5-9d06-4c5c-85a0-5e031ec54048"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7227741b-6c03-4c35-96c4-d9a308068b0c"}, "axis_label": "x", "formatter": {"type": "BasicTickFormatter", "id": "a8420a47-f9b2-44dc-9937-3785bab5fb80"}, "ticker": {"type": "BasicTicker", "id": "790f4185-6a69-451a-98a1-c729f1c4d5c9"}}, "type": "LinearAxis", "id": "283a095b-a07c-40c7-9406-5685bbde3b7e"}, {"attributes": {"nonselection_glyph": {"type": "Text", "id": "b69024d5-9d06-4c5c-85a0-5e031ec54048"}, "data_source": {"type": "ColumnDataSource", "id": "9e65863a-5b1f-4607-8573-aa9c857aeb05"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Text", "id": "d1e580f9-31bd-4c59-a374-bf0813cd2a02"}}, "type": "GlyphRenderer", "id": "c00d3c60-50c9-4b83-9c41-b78bdafd24ba"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "9ddfda77-5d6b-41ec-8058-595268e1e93d"}}, "type": "ResizeTool", "id": "bae04fa4-4fc4-4ba4-a753-2b43699b0611"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "538a24ec-b8dd-4332-83da-a3c8c6d8134a"}, "ticker": {"type": "BasicTicker", "id": "43fd340c-c719-4550-830e-4b1bae1db20e"}}, "type": "Grid", "id": "03931ea2-994c-436d-a8b4-9c7c00c3cae7"}, {"attributes": {"line_color": {"value": "orange"}, "x": {"field": "x"}, "y": {"field": "y"}, "fill_color": {"value": "orange"}, "size": {"units": "screen", "value": 10}}, "type": "Circle", "id": "93755db8-6422-46f0-8a23-76b390569577"}, {"attributes": {"x_range": {"type": "DataRange1d", "id": "11357a0b-e57e-4402-acee-c3b15fa84dfe"}, "y_range": {"type": "DataRange1d", "id": "14aa94b8-d7d7-4d4c-aef6-e444d70d43e2"}, "renderers": [{"type": "LinearAxis", "id": "866e0f1c-d99d-498f-ba63-418190f9b564"}, {"type": "Grid", "id": "ceb15b8d-38f5-4b32-8956-d15b21146821"}, {"type": "LinearAxis", "id": "1e573c57-0bf5-4ecb-98f1-70895fb00352"}, {"type": "Grid", "id": "f0f4b82f-2607-4244-b71e-e356ebab7ec9"}, {"type": "BoxAnnotation", "id": "6fef5bde-733e-402b-bf5d-8f4ae43a7c03"}, {"type": "GlyphRenderer", "id": "7f908563-4d7f-4051-8a7d-e152c7c59a71"}], "plot_width": 400, "below": [{"type": "LinearAxis", "id": "866e0f1c-d99d-498f-ba63-418190f9b564"}], "tool_events": {"type": "ToolEvents", "id": "4d201069-eb1b-4ede-bed1-8299659d2af7"}, "plot_hei ...

# %% [markdown]
# It looks like a linear model is most likely representative of the true unknown function that relates x to y.
#
# The equation of a line is:
#
# $y = \alpha + \beta x$
#
# By adjusting the two parameters $\alpha$ and $\beta$ we get an infinite number of possible lines.
#
# For any line we can compute the difference between the $y$'s in our data and the $\hat{y}$'s predicted by the equation.  From this difference we can define a simple metric that measures how well the line explains the data:
#
# $MSE = \frac{1}{N}\sum{(y_i - \hat{y}_i) ^ 2}$
#
# As we vary $\alpha$ and $\beta$ we get a different MSE - the best fitting line is the one with the lowest MSE.

# %%
from bokeh.charts import Scatter
from bokeh.io import push_notebook
from bokeh.plotting import ColumnDataSource, figure

a = 0
b = 1
xl = np.arange(-3,3,0.1)
yl = a + b * xl
yp = a + b * x

mse = np.sum(np.power(np.subtract(y, yp), 2)) / n
title='MSE = {0:6.2f}'.format(mse)

output_notebook(hide_banner=True)

source_mse = ColumnDataSource(data=dict(text=[title]))
source_line = ColumnDataSource(data=dict(x=xl,y=yl))

p = figure(plot_width = 400, plot_height = 400)
p.circle(x, y, size=10, color="orange")
p.line(xl, yl, source=source_line, line_width=5)
p.xaxis.axis_label='x'
p.yaxis.axis_label='y'
p.text(-3,30, text=[title], source = source_mse)

def update(a, b):
    xl = np.arange(-3,3,0.1)
    yl = a + b * xl
    yp = a + b * x
    mse = np.sum(np.power(np.subtract(y, yp), 2)) / n
    title='MSE = {0:6.2f}'.format(mse)
    source_line.data['x'] = xl
    source_line.data['y'] = yl
    source_mse.data['text'] = [title]
    push_notebook()
    
show(p)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div class="plotdiv" id="696bc5f4-05a7-4317-b17a-c5b835a648fb"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("696bc5f4-05a7-4317-b17a-c5b835a648fb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '696bc5f4-05a7-4317-b17a-c5b835a648fb' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"7bf2fd5d-9153-4bb5-a75e-2bf720e243f2": {"version": "0.11.0", "roots": {"root_ids": ["9ddfda77-5d6b-41ec-8058-595268e1e93d", "538a24ec-b8dd-4332-83da-a3c8c6d8134a", "621df27d-9c28-45b2-9ef8-8ff54b114c8b", "7c9b1add-4dec-4309-9a50-a0656b45ce97", "7227741b-6c03-4c35-96c4-d9a308068b0c", "d42274d0-ce47-4af2-98aa-a344c587a120"], "references": [{"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7227741b-6c03-4c35-96c4-d9a308068b0c"}}, "type": "PreviewSaveTool", "id": "d301e5fc-ffc7-45fb-883e-a060c99d4e1b"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7c9b1add-4dec-4309-9a50-a0656b45ce97"}}, "type": "PreviewSaveTool", "id": "11fb6a24-c545-4230-8450-a6558074f27c"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "538a24ec-b8dd-4332-83da-a3c8c6d8134a"}}, "type": "PreviewSaveTool", "id": "4cd09313-16cd-4b47-a7ca-d5f8f29048bd"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7227741b-6c03-4c35-96c4-d9a308068b0c"}}, "type": "ResetTool", "id": "8e7c9dac-4a76-4b76-8a08-0297451e95a5"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "7c9b1add-4dec-4309-9a50-a0656b45ce97"}, "formatter": {"type": "BasicTickFormatter", "id": "fbfe9ab1-6cbd-45bd-8369-d0a18d9080a0"}, "ticker": {"type": "BasicTicker", "id": "aa0edd44-51e1-4cb5-be46-c78b2b65cc72"}}, "type": "LinearAxis", "id": "8a20701e-4f5e-4b4d-935a-c1883a5e8865"}, {"attributes": {"callback": null, "column_names": ["y", "x", "y", "x"], "data": {"y": [-3.0, -2.9, -2.8, -2.6999999999999997, -2.5999999999999996, -2.4999999999999996, -2.3999999999999995, -2.2999999999999994, -2.1999999999999993, -2.099999999999999, -1.9999999999999991, -1.899999999999999, -1.799999999999999, -1.6999999999999988, -1.5999999999999988, -1.4999999999999987, -1.3999999999999986, -1.2999999999999985, -1.1999999999999984, -1.0999999999999983, -0.9999999999999982, -0.8999999999999981, -0.799999999999998, -0.699999999999998, -0.5999999999999979, -0.4999999999999978, -0.3999999999999977, -0.2999999999999976, -0.1999999999999975, -0.09999999999999742, 2.6645352591003757e-15, 0.10000000000000275, 0.20000000000000284, 0.30000000000000293, 0.400000000000003, 0.5000000000000031, 0.6000000000000032, 0.7000000000000033, 0.8000000000000034, 0.9000000000000035, 1.0000000000000036, 1.1000000000000032, 1.2000000000000037, 1.3000000000000043, 1.400000000000004, 1.5000000000000036, 1.600000000000004, 1.7000000000000046, 1.8000000000000043, 1.900000000000004, 2.0000000000000044, 2.100000000000005, 2.2000000000000046, 2.3000000000000043, 2.400000000000005, 2.5000000000000053, 2.600000000000005, 2.7000000000000046, 2.800000000000005, 2.9000000000000057], "x": [-3.0, -2.9, -2.8, -2.6999999999999997, -2.5999999999999996, -2.4999999999999996, -2.3999999999999995, -2.2999999999999994, -2.1999999999999993, -2.099999999999999, -1.9999999999999991, -1.899999999999999, -1.799999999999999, -1.6999999999999988, -1.5999999999999988, -1.4999999999999987, -1.3999999999999986, -1.2999999999999985, -1.1999999999999984, -1.0999999999999983, -0.9999999999999982, -0.8999999999999981, -0.799999999999998, -0.699999999999998, -0.5999999999999979, -0.4999999999999978, -0.3999999999999977, -0.2999999999999976, -0.1999999999999975, -0.09999999999999742, 2.6645352591003757e-15, 0.10000000000000275, 0.20000000000000284, 0.30000000000000293, 0.400000000000003, 0.5000000000000031, 0.6000000000000032, 0.7000000000000033, 0.8000000000000034, 0.9000000000000035, 1.0000000000000036, 1.1000000000000032, 1.2000000000000037, 1.3000000000000043, 1.400000000000004, 1.5000000000000036, 1.600000000000004, 1.7000000000000046, 1.8000000000000043, 1.900000000000004, 2.0000000000000044, 2.100000000000005, 2.2000000000000046, 2.3000000000000043, 2.400000000000005, 2.5000000000000053, 2.600000000000005, 2.7000000000000046, 2.800000000000005, 2.9000000000000057]}}, "type": "ColumnDataSource", "id": "d11b4db0-1e57-4a7b-8e4e-0791c6b77542"}, {"attributes": {} ...

# %%
from ipywidgets import interact
interact(update, a = (-40, 40, 0.5), b = (-20, 20, 0.5))

# %% [markdown]
# We can use 'machine learning' to avoid having to search through parameters:

# %%
from sklearn.linear_model import LinearRegression

x = x.reshape(-1,1)
model = LinearRegression()
model.fit(x,y)
print("a   = {0:4.2f}".format(float(model.coef_)))
print("b   = {0:4.2f}".format(float(model.intercept_)))

yp = model.predict(x)
mse = np.sum(np.power(np.subtract(y, yp), 2)) / n
print('MSE = {0:4.2f}'.format(mse))
# Out:
# a   = 13.92
# b   = 1.71
# MSE = 64.11
