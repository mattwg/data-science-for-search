# %% [markdown]
# ## 2.71 Machine Learning - Intuition
#
# Let's start by creating a simulated data set:

# %%
from sklearn import datasets
import numpy as np

n = 50
x, y, coef = datasets.make_regression(n_samples = n, n_features = 1, 
                                      n_informative = 1, noise = 10, 
                                      coef = True, random_state = 0)
x = x.flatten()

# %% [markdown]
# Let's plot the data:

# %%
from bokeh.plotting import figure, output_notebook, show
output_notebook(hide_banner=True)
p = figure(plot_width = 400, plot_height = 400)
p.circle(x, y, size=10, color="orange")
p.xaxis.axis_label='x'
p.yaxis.axis_label='y'
show(p)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div class="plotdiv" id="b4d85fc0-d799-464d-a2ef-2e041ee87945"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b4d85fc0-d799-464d-a2ef-2e041ee87945");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b4d85fc0-d799-464d-a2ef-2e041ee87945' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b4c994dc-1f1c-4717-941d-4aef0f226e50": {"version": "0.11.0", "roots": {"root_ids": ["9ddfda77-5d6b-41ec-8058-595268e1e93d", "538a24ec-b8dd-4332-83da-a3c8c6d8134a"], "references": [{"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "9ddfda77-5d6b-41ec-8058-595268e1e93d"}, "ticker": {"type": "BasicTicker", "id": "2953051e-688a-45f9-a688-c2539f305ae5"}, "dimension": 1}, "type": "Grid", "id": "f0f4b82f-2607-4244-b71e-e356ebab7ec9"}, {"attributes": {}, "type": "ToolEvents", "id": "7e088c20-da10-4763-9d52-dd8c9988dce5"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "538a24ec-b8dd-4332-83da-a3c8c6d8134a"}}, "type": "PreviewSaveTool", "id": "4cd09313-16cd-4b47-a7ca-d5f8f29048bd"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "9ddfda77-5d6b-41ec-8058-595268e1e93d"}, "ticker": {"type": "BasicTicker", "id": "deef5b23-d33a-4a2c-bfce-56aa8fd399dc"}}, "type": "Grid", "id": "ceb15b8d-38f5-4b32-8956-d15b21146821"}, {"attributes": {}, "type": "BasicTicker", "id": "2953051e-688a-45f9-a688-c2539f305ae5"}, {"attributes": {}, "type": "BasicTicker", "id": "43fd340c-c719-4550-830e-4b1bae1db20e"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "9ddfda77-5d6b-41ec-8058-595268e1e93d"}, "axis_label": "x", "formatter": {"type": "BasicTickFormatter", "id": "ad7d2f2e-8045-4d5a-a2fe-7ca8fc6d71de"}, "ticker": {"type": "BasicTicker", "id": "deef5b23-d33a-4a2c-bfce-56aa8fd399dc"}}, "type": "LinearAxis", "id": "866e0f1c-d99d-498f-ba63-418190f9b564"}, {"attributes": {"callback": null, "column_names": ["y", "x"], "data": {"y": [-30.834237922894395, 29.949323452563004, -19.986100768531568, 0.3058570148854507, 7.203146626795629, 40.885611234689996, 12.995068261249575, -17.74891775667451, -28.432194770844685, 11.677696838826343, 12.485308879314388, 14.650292234870447, 11.715700292501701, 1.634067609102365, 27.78240131214845, -6.913901754501939, -19.308353131576368, 13.119032535423669, -38.97818740395834, 31.156701729506093, -8.919215951322636, -20.11496997103196, -9.181611577211118, -4.891221208945573, 8.561906465706286, -1.3534884659172643, -3.364314969881868, 25.155779465665834, -1.435828314642782, 31.958146477582183, 21.758701623480608, 6.257079163269004, -19.59217687985094, 28.465314318741775, -1.3989221885463117, 10.849473027121014, 16.33075149631359, 3.3934786911339296, 6.686828600088303, 3.976564328388215, 27.698885099959213, -2.685831073181126, -5.473212035423796, -3.036227752536538, 1.8006943917119322, 19.357450000743864, 18.85230743598863, 4.323822233561039, -7.593606657630701, -16.23356659738172], "x": [-0.8540957393017248, 1.4940790731576061, -0.3479121493261526, 0.44386323274542566, -0.1871838500258336, 1.8675579901499675, 0.41059850193837233, -1.7062701906250126, -1.4200179371789752, 0.8644361988595057, 0.9787379841057392, -0.20515826376580087, 0.1549474256969163, -0.5096521817516535, 1.5327792143584575, -0.7421650204064419, -1.4543656745987648, -0.10321885179355784, -2.5529898158340787, 1.764052345967664, -1.2527953600499262, -0.977277879876411, 0.04575851730144607, -0.4380743016111864, 0.7610377251469934, 0.144043571160878, -0.2127402802139687, 1.2023798487844113, -0.3873268174079523, 2.240893199201458, 0.7774903558319101, 0.15634896910398005, -1.6138978475579515, 1.9507753952317897, 0.4001572083672233, 1.469358769900285, 1.454273506962975, -0.30230275057533557, 0.31306770165090136, 0.33367432737426683, 2.2697546239876076, -0.1513572082976979, 0.12167501649282841, 0.37816251960217356, 0.6536185954403606, 0.9500884175255894, 1.2302906807277207, -0.8877857476301128, -1.0485529650670926, -1.980796468223927]}}, "type": "ColumnDataSource", "id": "3a97984b-230d-49a1-ac47-964d191cb4d6"}, {"attributes": {"x_range": {"type": "DataRange1d", "id": "9fd97ad6-c4d0-4de9-8e5b-df295d7cf03f"}, "y_range": {"type": "DataRange1d", "id": "6443f3c6-e1f5-4162-92ae-e688b95e8095"}, "renderers": [{"type": "LinearAxis", "id": "8c53c931-052f-4b86-a7b1-3fd437fa724e"} ...

# %% [markdown]
# It looks like a linear model is most likely representative of the true unknown function that relates x to y.
#
# The equation of a line is:
#
# $y = \alpha + \beta x$
#
# By adjusting the two parameters $\alpha$ and $\beta$ we get an infinite number of possible lines.
#
# For any line we can compute the difference between the $y$'s in our data and the $\hat{y}$'s predicted by the equation.  From this difference we can define a simple metric that measures how well the line explains the data:
#
# $MSE = \frac{1}{N}\sum{(y_i - \hat{y}_i) ^ 2}$
#
# As we vary $\alpha$ and $\beta$ we get a different MSE - the best fitting line is the one with the lowest MSE.

# %%
from bokeh.charts import Scatter
from bokeh.io import push_notebook
from bokeh.plotting import ColumnDataSource, figure

a = 0
b = 1
xl = np.arange(-3,3,0.1)
yl = a + b * xl
yp = a + b * x

mse = np.sum(np.power(np.subtract(y, yp), 2)) / n
title='MSE = {0:6.2f}'.format(mse)

output_notebook(hide_banner=True)

source_mse = ColumnDataSource(data=dict(text=[title]))
source_line = ColumnDataSource(data=dict(x=xl,y=yl))

p = figure(plot_width = 400, plot_height = 400)
p.circle(x, y, size=10, color="orange")
p.line(xl, yl, source=source_line)
p.xaxis.axis_label='x'
p.yaxis.axis_label='y'
p.text(-3,30, text=[title], source = source_mse)

def update(a, b):
    xl = np.arange(-3,3,0.1)
    yl = a + b * xl
    yp = a + b * x
    mse = np.sum(np.power(np.subtract(y, yp), 2)) / n
    title='MSE = {0:6.2f}'.format(mse)
    source_line.data['x'] = xl
    source_line.data['y'] = yl
    source_mse.data['text'] = [title]
    push_notebook()
    
show(p)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div class="plotdiv" id="01ac46c2-9a56-44a8-8f7c-6810ca5c5385"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("01ac46c2-9a56-44a8-8f7c-6810ca5c5385");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '01ac46c2-9a56-44a8-8f7c-6810ca5c5385' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"bf96836f-3efb-4b13-8243-8ed631cf2759": {"version": "0.11.0", "roots": {"root_ids": ["9ddfda77-5d6b-41ec-8058-595268e1e93d", "538a24ec-b8dd-4332-83da-a3c8c6d8134a", "621df27d-9c28-45b2-9ef8-8ff54b114c8b"], "references": [{"attributes": {"callback": null, "column_names": ["text", "text"], "data": {"text": ["MSE = 288.02"]}}, "type": "ColumnDataSource", "id": "9e65863a-5b1f-4607-8573-aa9c857aeb05"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "9ddfda77-5d6b-41ec-8058-595268e1e93d"}, "ticker": {"type": "BasicTicker", "id": "2953051e-688a-45f9-a688-c2539f305ae5"}, "dimension": 1}, "type": "Grid", "id": "f0f4b82f-2607-4244-b71e-e356ebab7ec9"}, {"attributes": {}, "type": "ToolEvents", "id": "7e088c20-da10-4763-9d52-dd8c9988dce5"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "538a24ec-b8dd-4332-83da-a3c8c6d8134a"}}, "type": "PreviewSaveTool", "id": "4cd09313-16cd-4b47-a7ca-d5f8f29048bd"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}, "size": {"units": "screen", "value": 10}}, "type": "Circle", "id": "77bbe40c-7366-47dc-93d3-f20a3b775ff6"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "dcc7d8aa-bf9c-4b15-8de8-62a99bbf57e1"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "7a8974c6-0627-4c0f-b199-17b690e95788"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "ad7d2f2e-8045-4d5a-a2fe-7ca8fc6d71de"}, {"attributes": {}, "type": "BasicTicker", "id": "43fd340c-c719-4550-830e-4b1bae1db20e"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "9ddfda77-5d6b-41ec-8058-595268e1e93d"}, "axis_label": "x", "formatter": {"type": "BasicTickFormatter", "id": "ad7d2f2e-8045-4d5a-a2fe-7ca8fc6d71de"}, "ticker": {"type": "BasicTicker", "id": "deef5b23-d33a-4a2c-bfce-56aa8fd399dc"}}, "type": "LinearAxis", "id": "866e0f1c-d99d-498f-ba63-418190f9b564"}, {"attributes": {"callback": null, "column_names": ["y", "x"], "data": {"y": [-30.834237922894395, 29.949323452563004, -19.986100768531568, 0.3058570148854507, 7.203146626795629, 40.885611234689996, 12.995068261249575, -17.74891775667451, -28.432194770844685, 11.677696838826343, 12.485308879314388, 14.650292234870447, 11.715700292501701, 1.634067609102365, 27.78240131214845, -6.913901754501939, -19.308353131576368, 13.119032535423669, -38.97818740395834, 31.156701729506093, -8.919215951322636, -20.11496997103196, -9.181611577211118, -4.891221208945573, 8.561906465706286, -1.3534884659172643, -3.364314969881868, 25.155779465665834, -1.435828314642782, 31.958146477582183, 21.758701623480608, 6.257079163269004, -19.59217687985094, 28.465314318741775, -1.3989221885463117, 10.849473027121014, 16.33075149631359, 3.3934786911339296, 6.686828600088303, 3.976564328388215, 27.698885099959213, -2.685831073181126, -5.473212035423796, -3.036227752536538, 1.8006943917119322, 19.357450000743864, 18.85230743598863, 4.323822233561039, -7.593606657630701, -16.23356659738172], "x": [-0.8540957393017248, 1.4940790731576061, -0.3479121493261526, 0.44386323274542566, -0.1871838500258336, 1.8675579901499675, 0.41059850193837233, -1.7062701906250126, -1.4200179371789752, 0.8644361988595057, 0.9787379841057392, -0.20515826376580087, 0.1549474256969163, -0.5096521817516535, 1.5327792143584575, -0.7421650204064419, -1.4543656745987648, -0.10321885179355784, -2.5529898158340787, 1.764052345967664, -1.2527953600499262, -0.977277879876411, 0.04575851730144607, -0.4380743016111864, 0.7610377251469934, 0.144043571160878, -0.2127402802139687, 1.2023798487844113, -0.3873268174079523, 2.240893199201458, 0.7774903558319101, 0.15634896910398005, -1.6138978475579515, 1.9507753952317897, 0.4001572083672233, 1.469358769900285, 1.454273506962975, -0.30230275057533557, 0.31306770165090136, 0.33367432737426683, 2.2697546239876076, -0.1513572082976979, 0.12167501649282841, 0.37816251960217356, ...

# %%
from ipywidgets import interact
interact(update, a = (-40, 40, 0.5), b = (-20, 20, 0.5))

# %% [markdown]
# We can use 'machine learning' to avoid having to search through parameters:

# %%
from sklearn.linear_model import LinearRegression

x = x.reshape(-1,1)
model = LinearRegression()
model.fit(x,y)
print("a   = {0:4.2f}".format(float(model.coef_)))
print("b   = {0:4.2f}".format(float(model.intercept_)))

yp = model.predict(x)
mse = np.sum(np.power(np.subtract(y, yp), 2)) / n
print('MSE = {0:4.2f}'.format(mse))
# Out:
# a   = 13.92
# b   = 1.71
# MSE = 64.11
