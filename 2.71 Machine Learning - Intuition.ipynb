# %% [markdown]
# ## 2.71 Machine Learning - Intuition
#
# Let's start by creating a simulated data set:

# %%
from sklearn import datasets
import numpy as np

n = 50
x, y, coef = datasets.make_regression(n_samples = n, n_features = 1, 
                                      n_informative = 1, noise = 10, 
                                      coef = True, random_state = 0)
x = x.flatten()

# %% [markdown]
# Let's plot the data:

# %%
p = figure(plot_width = 400, plot_height = 400)
p.circle(x, y, size=10, color="orange")
p.xaxis.axis_label='x'
p.yaxis.axis_label='y'
show(p)
# Out:
#     <div class="plotdiv" id="45c62b51-5c82-4375-9667-deac18fe85ca"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("45c62b51-5c82-4375-9667-deac18fe85ca");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '45c62b51-5c82-4375-9667-deac18fe85ca' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e849b55e-be2f-4f53-bcb8-b318d4012502": {"version": "0.11.0", "roots": {"root_ids": ["5a0bdb23-3133-411a-b441-0d268642f0d8", "29c6385e-bcab-49c4-8bc4-1d07f4343483", "5cc53801-d803-4d79-b9b9-d6cca6f0bc1c", "32940412-e63b-4ce4-bedd-2c2e45d568ee", "d0a62646-9ed6-4f2b-a402-5559c7d75539", "23e099c8-3dc6-4962-a8e6-05526440ae54", "1f2710ea-7142-409e-8594-73d050279189", "768b66c7-d04c-4820-b77d-c40705c06d7a", "69f8711a-065b-4b33-bbc6-488e023907f2", "8c0a2c25-d5ed-44af-a580-c28a2da29995", "f9f641c7-f947-4811-a9e9-14df1208d134", "ad3d552b-725c-449c-a947-81aa6f0dbdc0", "c1c06932-e7ad-4520-95ca-156f107a3e40", "01ad15ef-64f9-4b0a-a094-df2da1687cce", "8ef88ea5-d0b6-4951-a454-7e2bd9f9a33e", "0cc51650-3d4e-490e-987a-cbdaa81fa186", "7eb5b891-d071-463e-8aa6-6a6306491552", "0fe4d952-903c-4dc6-b62d-02859df7eec7", "ad9b121a-137c-4f2c-a8d2-0bb8073d3cf2", "3b02171a-614a-4c7c-bffb-1d5a001b3091", "0b172ae5-bd83-49a7-a5a3-582686e504f4", "c66547c9-7053-43cf-a83b-2254053c6d7d", "c8d0401a-8c94-4373-85a1-9a8dc54ff396", "007b7572-6dd5-46d5-b304-f7f371d77c4d", "01a251cf-e5d6-4c55-9035-7041f5976128", "03f65e06-8624-4dc5-ad18-ab67e91f7a08", "013f8025-e4ce-4854-b709-de732b1e6d6e", "00570e86-6571-4594-9135-f82a0adbda2b", "ea344a10-4eaa-4cf6-98d6-afc5bb4e97ee", "507668a3-6a16-47ee-b83d-e8c5b818c38d", "136ee85e-675a-4390-a9e9-fdb96d6b8fa0", "a24bb8c0-920d-4259-a3f0-9694fedce266", "384e390e-4e5d-42ae-8d0b-049409f94d82", "f0a02abe-c424-4a37-b6ad-834de2ba38b5", "726fddf3-d35f-467c-85ae-897264a3b924", "c4999c0f-c4ea-43be-a6ee-1d7177939533", "4f527478-ad10-45c4-9a3c-0a18ef2d8d48", "6b3793c7-4a7f-4991-b7a6-922c47b89ef2", "df448a2e-a6a4-4e30-9bbf-effceecbffe0", "fc265627-677f-4f47-a983-be3bb2bd88e5", "181468f9-edae-4c3d-a23c-006b49e731b3", "f466d245-9548-4e8b-8f9c-25d26453176b", "5e8370df-7061-4bde-a3b9-181d0503d016"], "references": [{"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "00570e86-6571-4594-9135-f82a0adbda2b"}, "ticker": {"type": "BasicTicker", "id": "3f16d318-26e8-4bad-b887-0fbf5f63102a"}}, "type": "Grid", "id": "6fb456cf-c288-43f6-b506-21bdabc7e1eb"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}, "size": {"units": "screen", "value": 10}}, "type": "Circle", "id": "c3a2306a-792c-458c-af5a-618551e35af5"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "384e390e-4e5d-42ae-8d0b-049409f94d82"}}, "type": "ResizeTool", "id": "70eddc03-f34e-40ba-9be2-0ab496d77a76"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "31838245-c204-463a-b9fe-0fffe54201d4"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "ea344a10-4eaa-4cf6-98d6-afc5bb4e97ee"}}, "type": "PanTool", "id": "991b7b28-9aca-401f-929c-4a1ea0e9ada1"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "c8d0401a-8c94-4373-85a1-9a8dc54ff396"}, "formatter": {"type": "BasicTickFormatter", "id": "c0a9d763-560e-49d7-aa06-6143239eea25"}, "ticker": {"type": "BasicTicker", "id": "3fadc63b-8145-4ade-8cc1-79bea2a00371"}}, "type": "LinearAxis", "id": "5bae1c66-9a33-408c-a140-a59f8802d354"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "c1c06932-e7ad-4520-95ca-156f107a3e40"}, "formatter": {"type": "BasicTickFormatter", "id": "c25c4327-e0d1-46e8-b266-782218092c14"}, "ticker": {"type": "BasicTicker", "id": "18a12054-e489-4ed0-b762-75b64c239cdb"}}, "type": "LinearAxis", "id": "dde03db9-fea1-410d-84cc-9fda152abe0a"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "84db50d8-6659-471b-a89d-91d9584216ec"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "df448a2e-a6a4-4e30-9bbf-effceecbffe0"}}, "type": "PreviewSaveTool", "id": "4a25e016-43d1-4c0f-93f7-460e1ba16e68"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"f ...

# %% [markdown]
# It looks like a linear model is most likely representative of the true unknown function that relates x to y.
#
# The equation of a line is:
#
# $y = \alpha + \beta x$
#
# By adjusting the two parameters $\alpha$ and $\beta$ we get an infinite number of possible lines.
#
# For any line we can compute the difference between the $y$'s in our data and the $\hat{y}$'s predicted by the equation.  From this difference we can define a simple metric that measures how well the line explains the data:
#
# $MSE = \frac{1}{N}\sum{(y_i - \hat{y}_i) ^ 2}$
#
# As we vary $\alpha$ and $\beta$ we get a different MSE - the best fitting line is the one with the lowest MSE.

# %%
from bokeh.charts import output_notebook, Scatter, show
from bokeh.io import push_notebook
from bokeh.plotting import ColumnDataSource, figure

a = 0
b = 1
xl = np.arange(-3,3,0.1)
yl = a + b * xl
yp = a + b * x

mse = np.sum(np.power(np.subtract(y, yp), 2)) / n
title='MSE = {0:6.2f}'.format(mse)

output_notebook(hide_banner=True)

source_mse = ColumnDataSource(data=dict(text=[title]))
source_line = ColumnDataSource(data=dict(x=xl,y=yl))

p = figure(plot_width = 400, plot_height = 400)
p.circle(x, y, size=10, color="orange")
p.line(xl, yl, source=source_line)
p.xaxis.axis_label='x'
p.yaxis.axis_label='y'
p.text(-3,30, text=[title], source = source_mse)

def update(a, b):
    xl = np.arange(-3,3,0.1)
    yl = a + b * xl
    yp = a + b * x
    mse = np.sum(np.power(np.subtract(y, yp), 2)) / n
    title='MSE = {0:6.2f}'.format(mse)
    source_line.data['x'] = xl
    source_line.data['y'] = yl
    source_mse.data['text'] = [title]
    push_notebook()
    
show(p)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div class="plotdiv" id="05a64f9d-a532-4620-8cbc-c7b0b34f756a"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("05a64f9d-a532-4620-8cbc-c7b0b34f756a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '05a64f9d-a532-4620-8cbc-c7b0b34f756a' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f438a9aa-5405-4991-b1f5-43efe5ebf770": {"version": "0.11.0", "roots": {"root_ids": ["5a0bdb23-3133-411a-b441-0d268642f0d8", "29c6385e-bcab-49c4-8bc4-1d07f4343483", "5cc53801-d803-4d79-b9b9-d6cca6f0bc1c", "32940412-e63b-4ce4-bedd-2c2e45d568ee", "d0a62646-9ed6-4f2b-a402-5559c7d75539", "23e099c8-3dc6-4962-a8e6-05526440ae54", "1f2710ea-7142-409e-8594-73d050279189", "768b66c7-d04c-4820-b77d-c40705c06d7a", "69f8711a-065b-4b33-bbc6-488e023907f2", "8c0a2c25-d5ed-44af-a580-c28a2da29995", "f9f641c7-f947-4811-a9e9-14df1208d134", "ad3d552b-725c-449c-a947-81aa6f0dbdc0", "c1c06932-e7ad-4520-95ca-156f107a3e40", "01ad15ef-64f9-4b0a-a094-df2da1687cce", "8ef88ea5-d0b6-4951-a454-7e2bd9f9a33e", "0cc51650-3d4e-490e-987a-cbdaa81fa186", "7eb5b891-d071-463e-8aa6-6a6306491552", "0fe4d952-903c-4dc6-b62d-02859df7eec7", "ad9b121a-137c-4f2c-a8d2-0bb8073d3cf2", "3b02171a-614a-4c7c-bffb-1d5a001b3091", "0b172ae5-bd83-49a7-a5a3-582686e504f4", "c66547c9-7053-43cf-a83b-2254053c6d7d", "c8d0401a-8c94-4373-85a1-9a8dc54ff396", "007b7572-6dd5-46d5-b304-f7f371d77c4d", "01a251cf-e5d6-4c55-9035-7041f5976128", "03f65e06-8624-4dc5-ad18-ab67e91f7a08", "013f8025-e4ce-4854-b709-de732b1e6d6e", "00570e86-6571-4594-9135-f82a0adbda2b", "ea344a10-4eaa-4cf6-98d6-afc5bb4e97ee", "507668a3-6a16-47ee-b83d-e8c5b818c38d", "136ee85e-675a-4390-a9e9-fdb96d6b8fa0", "a24bb8c0-920d-4259-a3f0-9694fedce266", "384e390e-4e5d-42ae-8d0b-049409f94d82", "f0a02abe-c424-4a37-b6ad-834de2ba38b5", "726fddf3-d35f-467c-85ae-897264a3b924", "c4999c0f-c4ea-43be-a6ee-1d7177939533", "4f527478-ad10-45c4-9a3c-0a18ef2d8d48", "6b3793c7-4a7f-4991-b7a6-922c47b89ef2", "df448a2e-a6a4-4e30-9bbf-effceecbffe0", "fc265627-677f-4f47-a983-be3bb2bd88e5", "181468f9-edae-4c3d-a23c-006b49e731b3", "f466d245-9548-4e8b-8f9c-25d26453176b", "5e8370df-7061-4bde-a3b9-181d0503d016", "cf4d906e-e7a7-4ae9-b37a-bf0b61f971f1"], "references": [{"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "00570e86-6571-4594-9135-f82a0adbda2b"}, "ticker": {"type": "BasicTicker", "id": "3f16d318-26e8-4bad-b887-0fbf5f63102a"}}, "type": "Grid", "id": "6fb456cf-c288-43f6-b506-21bdabc7e1eb"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "df448a2e-a6a4-4e30-9bbf-effceecbffe0"}}, "type": "WheelZoomTool", "id": "86181a47-bc73-4f7c-a18d-8eb3c0389e0e"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "384e390e-4e5d-42ae-8d0b-049409f94d82"}}, "type": "ResizeTool", "id": "70eddc03-f34e-40ba-9be2-0ab496d77a76"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "31838245-c204-463a-b9fe-0fffe54201d4"}, {"attributes": {"nonselection_glyph": {"type": "Line", "id": "185d2751-009e-40f5-86eb-2fedcce50f3f"}, "data_source": {"type": "ColumnDataSource", "id": "1b1a30ad-bfe1-44e6-b926-4688423b15e3"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Line", "id": "25e8c13d-7e96-4c63-92c3-ed957968d80b"}}, "type": "GlyphRenderer", "id": "158ef2c3-08ec-4a90-974f-3e6105348972"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "c8d0401a-8c94-4373-85a1-9a8dc54ff396"}, "formatter": {"type": "BasicTickFormatter", "id": "c0a9d763-560e-49d7-aa06-6143239eea25"}, "ticker": {"type": "BasicTicker", "id": "3fadc63b-8145-4ade-8cc1-79bea2a00371"}}, "type": "LinearAxis", "id": "5bae1c66-9a33-408c-a140-a59f8802d354"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "84db50d8-6659-471b-a89d-91d9584216ec"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "abfffd37-4876-445c-bebf-526166ba4f27"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}, "size": {"units": "screen", "value": 10}}, "type": "Circle", "id": "522f989d-bc23-4733-a806-83824e6dcc06"}, {"attributes": {}, "type": "BasicTicker", "id": "bec25e33-489a-4154-bc49-fa9b270de27d"}, {"attributes": {}, "type": "ToolEvents", "id": "c58aa411-6e1b-46f1-8a70-fe1 ...

# %%
from ipywidgets import interact
interact(update, a = (-40, 40, 0.5), b = (-20, 20, 0.5))
# Out:
# <function __main__.update>

# %% [markdown]
# We can use 'machine learning' to avoid having to search through parameters:

# %%
from sklearn.linear_model import LinearRegression

x = x.reshape(-1,1)
model = LinearRegression()
model.fit(x,y)
print("a   = {0:4.2f}".format(float(model.coef_)))
print("b   = {0:4.2f}".format(float(model.intercept_)))

yp = model.predict(x)
mse = np.sum(np.power(np.subtract(y, yp), 2)) / n
print('MSE = {0:4.2f}'.format(mse))
# Out:
# a   = 13.92
# b   = 1.71
# MSE = 64.11
