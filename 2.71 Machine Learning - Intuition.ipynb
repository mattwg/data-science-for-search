# %% [markdown]
# ## 2.71 Machine Learning - Intuition
#
# Let's start by creating a simulated data set:

# %%
from sklearn import datasets
import numpy as np

n = 50
x, y, coef = datasets.make_regression(n_samples = n, n_features = 1, 
                                      n_informative = 1, noise = 10, 
                                      coef = True, random_state = 0)
x = x.flatten()

# %% [markdown]
# Let's plot the data:

# %%
from bokeh.plotting import figure, output_notebook, show
output_notebook(hide_banner=True)
p = figure(plot_width = 400, plot_height = 400)
p.circle(x, y, size=10, color="orange")
p.xaxis.axis_label='x'
p.yaxis.axis_label='y'
show(p)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div class="plotdiv" id="ad0a86b5-13ed-495c-ae4d-5fd3f4cf860c"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ad0a86b5-13ed-495c-ae4d-5fd3f4cf860c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ad0a86b5-13ed-495c-ae4d-5fd3f4cf860c' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a689f2a6-f57a-4e06-be6c-a3cd07e27dec": {"version": "0.11.0", "roots": {"root_ids": ["f25c5ca9-1a9e-4193-9829-440c3629bffc", "241a8321-e297-48d7-88d3-382fb31e0a40", "15f026d9-8e68-451f-9945-deff3f92c925", "79cfc76d-f347-4a1d-97d1-1e5da10cf278", "4519c361-2a6f-4152-b281-73dca3ff1e6f", "e4ee64a3-950d-4b25-aa98-ad3c74e52f7d", "a29be781-2097-4e21-8c0b-5fdca33dbcdd", "ecfbb4af-d4ff-4947-9818-2dec3f23f014", "700063b7-0c27-4f1e-8364-c39481caeecf", "19d47f81-8da8-4790-ab78-5ed4fdaac4a8", "ddf127d9-7e07-4f0f-98db-760312f6f7b9", "244c044b-0ae6-4edc-b9a9-e90bc2a7429d", "6bb2f2ad-9979-4ee3-8bef-1bee0e39e4d3", "ebaecb8b-f1e1-443f-9bf8-bbc755a07477", "2fdd1b1d-1216-456c-9c76-7baed2b77bc6", "3be01f97-f9f4-4c4f-a32c-8622ef08ce7b", "90df29b1-516e-4fe1-acd9-48c05ebe9202", "9b31cdd8-c11b-4a0e-9b31-828bddae4388", "051937d4-80c9-43c3-b115-744d3a0101d0", "a523afc7-5c5f-4560-bcec-c0a510256762", "bcc56a8a-ff79-4eae-a523-2ce469ed6526", "648bdca2-1ac9-4c38-a319-2dfe2966c515", "9bd07515-f2ff-4acf-be86-afff6be9b4a7", "b3e04016-9dbd-45e0-8d3c-7592c8c901ff", "7950d081-cc93-40c3-a3fa-7404d29171ad", "df5b0a13-ce8a-4114-a3ec-2e518246f93b", "0dbe6c9d-0023-4d75-b038-09ffb576e010", "997c97f3-41ed-4379-beb8-897e562f4459", "aaa6fabb-e4f4-47e6-bd37-01ce0da4f388", "ac685851-845d-481c-80b4-d8809f304781"], "references": [{"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}, "size": {"units": "screen", "value": 10}}, "type": "Circle", "id": "1b1f30d5-9fde-4e41-98b1-11b22af81cf8"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "90df29b1-516e-4fe1-acd9-48c05ebe9202"}, "ticker": {"type": "BasicTicker", "id": "094603e5-ba56-4629-96a0-62690ed82978"}}, "type": "Grid", "id": "fa67d726-a5b0-41a7-9612-b8a80bd12d36"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_width": {"value": 5}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Line", "id": "b227d0aa-ac8b-47f3-bf43-293a5f9631de"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}, "line_width": {"value": 3}}, "type": "Line", "id": "ef879d9b-2c45-4b61-acda-e4d290d31ba3"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "997c97f3-41ed-4379-beb8-897e562f4459"}}, "type": "PreviewSaveTool", "id": "1b49fa05-5e6d-49f9-8342-28a4a4ecd50b"}, {"attributes": {"line_color": {"value": "orange"}, "x": {"field": "x"}, "y": {"field": "y"}, "fill_color": {"value": "orange"}, "size": {"units": "screen", "value": 10}}, "type": "Circle", "id": "7368b025-7e57-4284-b494-cb318305fbd7"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "ecfbb4af-d4ff-4947-9818-2dec3f23f014"}}, "type": "WheelZoomTool", "id": "d5f0747e-1b84-4475-83b1-6f949f089f23"}, {"attributes": {"line_color": {"value": "black"}, "line_alpha": {"value": 1.0}, "render_mode": "css", "bottom_units": "screen", "level": "overlay", "top_units": "screen", "fill_alpha": {"value": 0.5}, "plot": null, "left_units": "screen", "line_dash": [4, 4], "line_width": {"value": 2}, "right_units": "screen", "fill_color": {"value": "lightgrey"}}, "type": "BoxAnnotation", "id": "b4deac82-0f1e-45b4-a110-b72028869511"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "e4ee64a3-950d-4b25-aa98-ad3c74e52f7d"}, "axis_label": "y", "formatter": {"type": "BasicTickFormatter", "id": "1fe17920-bfb3-42f6-b9a0-458df92ecd41"}, "ticker": {"type": "BasicTicker", "id": "f3fc762b-8b3b-4861-9d10-9a02121c7907"}}, "type": "LinearAxis", "id": "9f26ab69-f086-4b1d-a7d5-7b5d8d007226"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "c7120296-dc39-4bba-9a96-51c325f4eada"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}, "size": {"units": "screen ...

# %% [markdown]
# It looks like a linear model is most likely representative of the true unknown function that relates x to y.
#
# The equation of a line is:
#
# $y = \alpha + \beta x$
#
# By adjusting the two parameters $\alpha$ and $\beta$ we get an infinite number of possible lines.  For example we could set  $\alpha = 3.5$ and $\beta = 10$:

# %%
a = 3.5
b = 10
xl = np.arange(-3,3,0.1)
yl = a + b * xl
yp = a + b * x

output_notebook(hide_banner=True)

p = figure(plot_width = 400, plot_height = 400)
p.circle(x, y, size=10, color="orange")
p.line(xl, yl, line_width=5)
p.xaxis.axis_label='x'
p.yaxis.axis_label='y'
show(p)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div class="plotdiv" id="f52c47a1-08ad-4772-9918-edef4e051b96"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f52c47a1-08ad-4772-9918-edef4e051b96");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f52c47a1-08ad-4772-9918-edef4e051b96' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a8d375fe-3dd4-4a5a-9b36-3ac293049f62": {"version": "0.11.0", "roots": {"root_ids": ["f25c5ca9-1a9e-4193-9829-440c3629bffc", "241a8321-e297-48d7-88d3-382fb31e0a40", "15f026d9-8e68-451f-9945-deff3f92c925", "79cfc76d-f347-4a1d-97d1-1e5da10cf278", "4519c361-2a6f-4152-b281-73dca3ff1e6f", "e4ee64a3-950d-4b25-aa98-ad3c74e52f7d", "a29be781-2097-4e21-8c0b-5fdca33dbcdd", "ecfbb4af-d4ff-4947-9818-2dec3f23f014", "700063b7-0c27-4f1e-8364-c39481caeecf", "19d47f81-8da8-4790-ab78-5ed4fdaac4a8", "ddf127d9-7e07-4f0f-98db-760312f6f7b9", "244c044b-0ae6-4edc-b9a9-e90bc2a7429d", "6bb2f2ad-9979-4ee3-8bef-1bee0e39e4d3", "ebaecb8b-f1e1-443f-9bf8-bbc755a07477", "2fdd1b1d-1216-456c-9c76-7baed2b77bc6", "3be01f97-f9f4-4c4f-a32c-8622ef08ce7b", "90df29b1-516e-4fe1-acd9-48c05ebe9202", "9b31cdd8-c11b-4a0e-9b31-828bddae4388", "051937d4-80c9-43c3-b115-744d3a0101d0", "a523afc7-5c5f-4560-bcec-c0a510256762", "bcc56a8a-ff79-4eae-a523-2ce469ed6526", "648bdca2-1ac9-4c38-a319-2dfe2966c515", "9bd07515-f2ff-4acf-be86-afff6be9b4a7", "b3e04016-9dbd-45e0-8d3c-7592c8c901ff", "7950d081-cc93-40c3-a3fa-7404d29171ad", "df5b0a13-ce8a-4114-a3ec-2e518246f93b", "0dbe6c9d-0023-4d75-b038-09ffb576e010", "997c97f3-41ed-4379-beb8-897e562f4459", "aaa6fabb-e4f4-47e6-bd37-01ce0da4f388", "ac685851-845d-481c-80b4-d8809f304781", "07202ac5-19a8-4329-8657-75e154db91eb"], "references": [{"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}, "size": {"units": "screen", "value": 10}}, "type": "Circle", "id": "1b1f30d5-9fde-4e41-98b1-11b22af81cf8"}, {"attributes": {}, "type": "BasicTicker", "id": "e4e38306-5655-4a01-8abc-85358110ed16"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "90df29b1-516e-4fe1-acd9-48c05ebe9202"}, "ticker": {"type": "BasicTicker", "id": "094603e5-ba56-4629-96a0-62690ed82978"}}, "type": "Grid", "id": "fa67d726-a5b0-41a7-9612-b8a80bd12d36"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_width": {"value": 5}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Line", "id": "b227d0aa-ac8b-47f3-bf43-293a5f9631de"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}, "line_width": {"value": 3}}, "type": "Line", "id": "ef879d9b-2c45-4b61-acda-e4d290d31ba3"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "997c97f3-41ed-4379-beb8-897e562f4459"}}, "type": "PreviewSaveTool", "id": "1b49fa05-5e6d-49f9-8342-28a4a4ecd50b"}, {"attributes": {"line_color": {"value": "orange"}, "x": {"field": "x"}, "y": {"field": "y"}, "fill_color": {"value": "orange"}, "size": {"units": "screen", "value": 10}}, "type": "Circle", "id": "7368b025-7e57-4284-b494-cb318305fbd7"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "ecfbb4af-d4ff-4947-9818-2dec3f23f014"}}, "type": "WheelZoomTool", "id": "d5f0747e-1b84-4475-83b1-6f949f089f23"}, {"attributes": {"line_color": {"value": "black"}, "line_alpha": {"value": 1.0}, "render_mode": "css", "bottom_units": "screen", "level": "overlay", "top_units": "screen", "fill_alpha": {"value": 0.5}, "plot": null, "left_units": "screen", "line_dash": [4, 4], "line_width": {"value": 2}, "right_units": "screen", "fill_color": {"value": "lightgrey"}}, "type": "BoxAnnotation", "id": "b4deac82-0f1e-45b4-a110-b72028869511"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "15f026d9-8e68-451f-9945-deff3f92c925"}}, "type": "ResizeTool", "id": "c6490fe0-625c-4c58-9b17-1160012ad996"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "c7120296-dc39-4bba-9a96-51c325f4eada"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}, "size": {"units": "screen", "value": 10}}, "type": "Circle", "id": "c1c785d2-81b8-4c7b- ...

# %% [markdown]
# For any line we can compute the difference between the $y$'s in our data and the $\hat{y}$'s predicted by the equation.  From this difference we can define a simple metric that measures how well the line explains the data:
#
# $MSE = \frac{1}{N}\sum{(y_i - \hat{y}_i) ^ 2}$
#
# For example with $\alpha = 3.5$ and $\beta = 10$ - we can plot the distance between the points ($y$) and the points predicted by the equation ($\hat{y}$):

# %%
lx = [ [x1, x1] for x1 in x]
ly = [ [y1, y2] for (y1, y2) in zip(y, yp)]
p = figure(plot_width = 400, plot_height = 400)
p.multi_line(xs=lx, ys=ly, line_width = 2, color="gray")
p.circle(x, y, size=10, color="orange")
p.line(xl, yl, line_width=5)
p.xaxis.axis_label='x'
p.yaxis.axis_label='y'
show(p)
# Out:
#     <div class="plotdiv" id="215bdb8e-5dbe-446f-8de8-487433af6a0e"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("215bdb8e-5dbe-446f-8de8-487433af6a0e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '215bdb8e-5dbe-446f-8de8-487433af6a0e' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f139a62f-6511-4bb3-86d2-45180bee35e7": {"version": "0.11.0", "roots": {"root_ids": ["f25c5ca9-1a9e-4193-9829-440c3629bffc", "241a8321-e297-48d7-88d3-382fb31e0a40", "15f026d9-8e68-451f-9945-deff3f92c925", "79cfc76d-f347-4a1d-97d1-1e5da10cf278", "4519c361-2a6f-4152-b281-73dca3ff1e6f", "e4ee64a3-950d-4b25-aa98-ad3c74e52f7d", "a29be781-2097-4e21-8c0b-5fdca33dbcdd", "ecfbb4af-d4ff-4947-9818-2dec3f23f014", "700063b7-0c27-4f1e-8364-c39481caeecf", "19d47f81-8da8-4790-ab78-5ed4fdaac4a8", "ddf127d9-7e07-4f0f-98db-760312f6f7b9", "244c044b-0ae6-4edc-b9a9-e90bc2a7429d", "6bb2f2ad-9979-4ee3-8bef-1bee0e39e4d3", "ebaecb8b-f1e1-443f-9bf8-bbc755a07477", "2fdd1b1d-1216-456c-9c76-7baed2b77bc6", "3be01f97-f9f4-4c4f-a32c-8622ef08ce7b", "90df29b1-516e-4fe1-acd9-48c05ebe9202", "9b31cdd8-c11b-4a0e-9b31-828bddae4388", "051937d4-80c9-43c3-b115-744d3a0101d0", "a523afc7-5c5f-4560-bcec-c0a510256762", "bcc56a8a-ff79-4eae-a523-2ce469ed6526", "648bdca2-1ac9-4c38-a319-2dfe2966c515", "9bd07515-f2ff-4acf-be86-afff6be9b4a7", "b3e04016-9dbd-45e0-8d3c-7592c8c901ff", "7950d081-cc93-40c3-a3fa-7404d29171ad", "df5b0a13-ce8a-4114-a3ec-2e518246f93b", "0dbe6c9d-0023-4d75-b038-09ffb576e010", "997c97f3-41ed-4379-beb8-897e562f4459", "aaa6fabb-e4f4-47e6-bd37-01ce0da4f388", "ac685851-845d-481c-80b4-d8809f304781", "07202ac5-19a8-4329-8657-75e154db91eb", "86bba72d-06af-4ce0-bb86-1c1bd9130b58"], "references": [{"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}, "size": {"units": "screen", "value": 10}}, "type": "Circle", "id": "1b1f30d5-9fde-4e41-98b1-11b22af81cf8"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "90df29b1-516e-4fe1-acd9-48c05ebe9202"}, "ticker": {"type": "BasicTicker", "id": "094603e5-ba56-4629-96a0-62690ed82978"}}, "type": "Grid", "id": "fa67d726-a5b0-41a7-9612-b8a80bd12d36"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_width": {"value": 5}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Line", "id": "b227d0aa-ac8b-47f3-bf43-293a5f9631de"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}, "line_width": {"value": 3}}, "type": "Line", "id": "ef879d9b-2c45-4b61-acda-e4d290d31ba3"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "997c97f3-41ed-4379-beb8-897e562f4459"}}, "type": "PreviewSaveTool", "id": "1b49fa05-5e6d-49f9-8342-28a4a4ecd50b"}, {"attributes": {"line_color": {"value": "orange"}, "x": {"field": "x"}, "y": {"field": "y"}, "fill_color": {"value": "orange"}, "size": {"units": "screen", "value": 10}}, "type": "Circle", "id": "7368b025-7e57-4284-b494-cb318305fbd7"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "ecfbb4af-d4ff-4947-9818-2dec3f23f014"}}, "type": "WheelZoomTool", "id": "d5f0747e-1b84-4475-83b1-6f949f089f23"}, {"attributes": {"line_color": {"value": "black"}, "line_alpha": {"value": 1.0}, "render_mode": "css", "bottom_units": "screen", "level": "overlay", "top_units": "screen", "fill_alpha": {"value": 0.5}, "plot": null, "left_units": "screen", "line_dash": [4, 4], "line_width": {"value": 2}, "right_units": "screen", "fill_color": {"value": "lightgrey"}}, "type": "BoxAnnotation", "id": "b4deac82-0f1e-45b4-a110-b72028869511"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "15f026d9-8e68-451f-9945-deff3f92c925"}}, "type": "ResizeTool", "id": "c6490fe0-625c-4c58-9b17-1160012ad996"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "c7120296-dc39-4bba-9a96-51c325f4eada"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}, "size": {"units": "screen", "value": 10}}, "type": "Circle", "id": "c1c785d2-81b8-4c7b-a4e0-1480feb07094"}, {"attributes": {"nonselectio ...

# %% [markdown]
# We can average the square of the line lengths which gives us the Mean Squared Error.
#
# As we vary $\alpha$ and $\beta$ we get a different MSE - the best fitting line is the one with the lowest MSE.

# %%
from bokeh.charts import Scatter
from bokeh.io import push_notebook
from bokeh.plotting import ColumnDataSource, figure

a = 0
b = 1
xl = np.arange(-3,3,0.1)
yl = a + b * xl
yp = a + b * x

mse = np.sum(np.power(np.subtract(y, yp), 2)) / n
title='MSE = {0:6.2f}'.format(mse)

output_notebook(hide_banner=True)

source_mse = ColumnDataSource(data=dict(text=[title]))
source_line = ColumnDataSource(data=dict(x=xl,y=yl))

p = figure(plot_width = 400, plot_height = 400)
p.circle(x, y, size=10, color="orange")
p.line(xl, yl, source=source_line, line_width=5)
p.xaxis.axis_label='x'
p.yaxis.axis_label='y'
p.text(-3,30, text=[title], source = source_mse)

def update(a, b):
    xl = np.arange(-3,3,0.1)
    yl = a + b * xl
    yp = a + b * x
    mse = np.sum(np.power(np.subtract(y, yp), 2)) / n
    title='MSE = {0:6.2f}'.format(mse)
    source_line.data['x'] = xl
    source_line.data['y'] = yl
    source_mse.data['text'] = [title]
    push_notebook()
    
show(p)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div class="plotdiv" id="33b9e35b-6cda-4b46-8e40-9d10cbbba416"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("33b9e35b-6cda-4b46-8e40-9d10cbbba416");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '33b9e35b-6cda-4b46-8e40-9d10cbbba416' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"243cf676-0558-418f-855b-5b60c5e44ea6": {"version": "0.11.0", "roots": {"root_ids": ["f25c5ca9-1a9e-4193-9829-440c3629bffc", "241a8321-e297-48d7-88d3-382fb31e0a40", "15f026d9-8e68-451f-9945-deff3f92c925", "79cfc76d-f347-4a1d-97d1-1e5da10cf278", "4519c361-2a6f-4152-b281-73dca3ff1e6f", "e4ee64a3-950d-4b25-aa98-ad3c74e52f7d", "a29be781-2097-4e21-8c0b-5fdca33dbcdd", "ecfbb4af-d4ff-4947-9818-2dec3f23f014", "700063b7-0c27-4f1e-8364-c39481caeecf", "19d47f81-8da8-4790-ab78-5ed4fdaac4a8", "ddf127d9-7e07-4f0f-98db-760312f6f7b9", "244c044b-0ae6-4edc-b9a9-e90bc2a7429d", "6bb2f2ad-9979-4ee3-8bef-1bee0e39e4d3", "ebaecb8b-f1e1-443f-9bf8-bbc755a07477", "2fdd1b1d-1216-456c-9c76-7baed2b77bc6", "3be01f97-f9f4-4c4f-a32c-8622ef08ce7b", "90df29b1-516e-4fe1-acd9-48c05ebe9202", "9b31cdd8-c11b-4a0e-9b31-828bddae4388", "051937d4-80c9-43c3-b115-744d3a0101d0", "a523afc7-5c5f-4560-bcec-c0a510256762", "bcc56a8a-ff79-4eae-a523-2ce469ed6526", "648bdca2-1ac9-4c38-a319-2dfe2966c515", "9bd07515-f2ff-4acf-be86-afff6be9b4a7", "b3e04016-9dbd-45e0-8d3c-7592c8c901ff", "7950d081-cc93-40c3-a3fa-7404d29171ad", "df5b0a13-ce8a-4114-a3ec-2e518246f93b", "0dbe6c9d-0023-4d75-b038-09ffb576e010", "997c97f3-41ed-4379-beb8-897e562f4459", "aaa6fabb-e4f4-47e6-bd37-01ce0da4f388", "ac685851-845d-481c-80b4-d8809f304781", "07202ac5-19a8-4329-8657-75e154db91eb", "86bba72d-06af-4ce0-bb86-1c1bd9130b58", "04c935dc-d30b-4de5-9a7e-f3e156bb0fbd", "8013163c-afa6-40b1-a0b4-50995961c38d", "f7999d8e-caba-4e26-af7d-c0d097fbee6c", "1affd018-c63b-4522-8fa4-692475f7236b"], "references": [{"attributes": {"nonselection_glyph": {"type": "MultiLine", "id": "fd7fb333-b143-4277-b6c2-a86ecfd37d71"}, "data_source": {"type": "ColumnDataSource", "id": "d79e9e46-a2ba-4436-8f6e-87493b3cf6ed"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "MultiLine", "id": "ae77af7f-134e-431d-a797-c0ac3d05e388"}}, "type": "GlyphRenderer", "id": "84ba62da-9025-4e7e-83c1-65b22ec55104"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "fill_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}, "size": {"units": "screen", "value": 10}}, "type": "Circle", "id": "1b1f30d5-9fde-4e41-98b1-11b22af81cf8"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "90df29b1-516e-4fe1-acd9-48c05ebe9202"}, "ticker": {"type": "BasicTicker", "id": "094603e5-ba56-4629-96a0-62690ed82978"}}, "type": "Grid", "id": "fa67d726-a5b0-41a7-9612-b8a80bd12d36"}, {"attributes": {"nonselection_glyph": {"type": "Circle", "id": "4db2187c-b313-4acf-b0a6-17c3ccc276ba"}, "data_source": {"type": "ColumnDataSource", "id": "0ed21821-f15c-41ec-b7c9-ee3a046b328a"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Circle", "id": "9d12bdf3-7b15-49b6-9ab7-0b3f196743c0"}}, "type": "GlyphRenderer", "id": "250cb8aa-7686-4593-a6bf-b7d8058a5bda"}, {"attributes": {"line_color": {"value": "#1f77b4"}, "line_alpha": {"value": 0.1}, "y": {"field": "y"}, "x": {"field": "x"}, "line_width": {"value": 3}}, "type": "Line", "id": "ef879d9b-2c45-4b61-acda-e4d290d31ba3"}, {"attributes": {"y": {"value": 30}, "x": {"value": -3}, "text_color": {"value": "black"}}, "type": "Text", "id": "24aff80c-0dc7-4f0c-8938-9d149377a25c"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "997c97f3-41ed-4379-beb8-897e562f4459"}}, "type": "PreviewSaveTool", "id": "1b49fa05-5e6d-49f9-8342-28a4a4ecd50b"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "f7999d8e-caba-4e26-af7d-c0d097fbee6c"}}, "type": "WheelZoomTool", "id": "129a6152-2ac8-4c6c-960e-3c27e05274fb"}, {"attributes": {"line_color": {"value": "orange"}, "x": {"field": "x"}, "y": {"field": "y"}, "fill_color": {"value": "orange"}, "size": {"units": "screen", "value": 10}}, "type": "Circle", "id": "7368b025-7e57-4284-b494-cb318305fbd7"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "ecfbb4af-d4ff-4947-9818-2dec3f23f014"}}, "type": "Whe ...

# %%
from ipywidgets import interact
interact(update, a = (-40, 40, 0.5), b = (-20, 20, 0.5))

# %% [markdown]
# We can use 'machine learning' to avoid having to search through parameters:

# %%
from sklearn.linear_model import LinearRegression

xm = x.reshape(-1,1)
model = LinearRegression()
model.fit(xm,y)
print("a   = {0:4.2f}".format(float(model.intercept_)))
print("b   = {0:4.2f}".format(float(model.coef_)))

yp = model.predict(xm)
mse = np.sum(np.power(np.subtract(y, yp), 2)) / n
print('MSE = {0:4.2f}'.format(mse))
# Out:
# a   = 1.71
# b   = 13.92
# MSE = 64.11
