# %% [markdown]
# ## Many Options
#
# There are many options when it comes to producing data visualizations:
#
# * ggplot - R, python
# * matplotlib - python
# * bokeh - python, R, scala
#
# We are going to look at bokeh since it has an API for Python, R and Scala.  It is modern, based on grammar of graphics, designed for the web.  I think it has higher ROL(return on learning) and a lovely logo:
#
# ![Bokeh](http://bokeh.pydata.org/en/latest/_static/images/logo.png)
#
# Lots of resources for bokeh online - start [here](http://bokeh.pydata.org/en/latest/).
#
# Majority of content in this section is a mash up of the content on the Bokeh site.
#
#
# ## Bokeh Charts
#
# Bokeh has 3 levels of interface for different users:
#
# * a low-level [bokeh.models](http://bokeh.pydata.org/en/latest/docs/reference/models.html#bokeh-models) interface that provides the most flexibility to application developers.
# * an intermediate-level [bokeh.plotting](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh-plotting) interface centered around composing visual glyphs.
# * a high-level [bokeh.charts](http://bokeh.pydata.org/en/latest/docs/reference/charts.html#bokeh-charts) interface to build complex statistical plots quickly and simply.
#
# We are going to take a very quick look at bokeh.charts - creating a bar chart, histogram, line chart, scatter chart and a boxplot.  Note we are only scratching the surface - I recommend learning bokeh.plotting when you have time.
#
# For many more details on bokeh.charts read the great documentation [here](http://bokeh.pydata.org/en/latest/docs/user_guide/charts.html).
#
# ### Input Data
#
# Charts uses [Pandas DataFrame](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html#pandas.DataFrame) internally, so any inputs provided will be coerced into this format.
#
# The input types accepted are:
#
# Array-like: 1..* list, tuple, numpy.ndarray, pandas.Series
#
# Table-like:
#
#         records: a list(dict)
#         columns: a dict(list), pandas.DataFrame, or blaze resource
#
# Additional information - [10 Minute Intro to Panda's Data Frame](http://pandas.pydata.org/pandas-docs/stable/10min.html).

# %% [markdown]
# # Bar charts
#
# We are using bokeh.charts as well as a sample data set containing auto mpg data.
#
# We also set the chart size defaults and redirect plots to show up in the notebook:

# %%
from bokeh.charts import defaults, Bar, output_notebook, show
from bokeh.sampledata.autompg import autompg as df

defaults.plot_width = 500
defaults.plot_height = 300

output_notebook(hide_banner=True)
df.head()
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#    mpg  cyl  displ   hp  weight  accel  yr  origin                       name
# 0   18    8    307  130    3504   12.0  70       1  chevrolet chevelle malibu
# 1   15    8    350  165    3693   11.5  70       1          buick skylark 320
# 2   18    8    318  150    3436   11.0  70       1         plymouth satellite
# 3   16    8    304  150    3433   12.0  70       1              amc rebel sst
# 4   17    8    302  140    3449   10.5  70       1                ford torino

# %% [markdown]
# ### Simple Bar Chart

# %%
p = Bar(df, label = 'cyl', values='mpg', title="Total MPG by CYL")
show(p)
# Out:
#     <div class="plotdiv" id="4a359b08-a9c9-459d-9560-6734cd6beaf2"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4a359b08-a9c9-459d-9560-6734cd6beaf2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4a359b08-a9c9-459d-9560-6734cd6beaf2' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1aa51b55-c33e-41ec-9de9-ea2e532dfdd2": {"version": "0.11.0", "roots": {"root_ids": ["0befbfd8-e21e-467c-8226-ef211effe76f", "e65c5798-76c4-4947-986a-cf39f1e72367", "458ae6fc-9efd-464f-bd12-2cc9f0d56ab8", "f862808b-ac93-444f-af4c-2c827120e897", "7beb3a3b-0016-41b4-a20b-91d8b8a3675d"], "references": [{"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "f862808b-ac93-444f-af4c-2c827120e897"}}, "type": "ResizeTool", "id": "e2b28b53-08ec-4a37-9d9a-123f42d4018c"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "2354b65a-d97a-4d3b-9b1e-4118c7e47dc9"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "cb898640-bac5-4b1c-bad9-b8fc076e349d"}, {"attributes": {"x_range": {"type": "FactorRange", "id": "af5e297a-ab9b-47c8-88ab-e7cb2ef22aef"}, "y_mapper_type": "auto", "title_text_font_size": {"value": "14pt"}, "title": "Total MPG by CYL", "y_range": {"type": "Range1d", "id": "64b3bd38-0f4b-44ab-8cae-4212bba000ad"}, "x_mapper_type": "auto", "yscale": "auto", "renderers": [{"type": "BoxAnnotation", "id": "8cac9cdc-8c5b-4d11-9d1a-ae644c3f4ebd"}, {"type": "GlyphRenderer", "id": "e3389b2e-d490-40f6-8d9d-1b212612f764"}, {"type": "GlyphRenderer", "id": "e66b36bc-32e9-47d2-8517-ea7947322445"}, {"type": "GlyphRenderer", "id": "95b2e10f-4a8e-4302-bd5d-5597a60e9fa9"}, {"type": "GlyphRenderer", "id": "04e21358-1768-4322-be08-eec8cb1b92fc"}, {"type": "GlyphRenderer", "id": "72ea8cc5-e52d-4ab9-8f79-e33177f0a0db"}, {"type": "CategoricalAxis", "id": "6e45b6ce-ad21-4d97-9fa0-c19e0ff52df3"}, {"type": "LinearAxis", "id": "bf6503e7-c784-40dd-a51a-ef0ba626ee6e"}, {"type": "Grid", "id": "341bba2e-9094-4862-ba9c-7b947747cc52"}], "plot_width": 500, "xgrid": false, "below": [{"type": "CategoricalAxis", "id": "6e45b6ce-ad21-4d97-9fa0-c19e0ff52df3"}], "tool_events": {"type": "ToolEvents", "id": "c1375f10-bb73-4ce7-8f6e-cbecf383b280"}, "plot_height": 300, "xscale": "auto", "tools": [{"type": "PanTool", "id": "b4d9f140-fe47-4835-82c5-fa4b47009f72"}, {"type": "WheelZoomTool", "id": "b1908dc8-a920-424f-a888-1d49969c3320"}, {"type": "BoxZoomTool", "id": "5a4d251e-7925-43f6-b989-0ea716368a52"}, {"type": "PreviewSaveTool", "id": "73bf5376-a4ff-4788-a8e6-5ff353b6550c"}, {"type": "ResizeTool", "id": "8daff3f7-1af3-4dd9-9f56-8449f87f3079"}, {"type": "ResetTool", "id": "f1eda882-525f-4977-8d5f-1d746068ea33"}, {"type": "HelpTool", "id": "2162cfeb-6ec1-4876-8e71-2d91132066f8"}], "legend": null, "left": [{"type": "LinearAxis", "id": "bf6503e7-c784-40dd-a51a-ef0ba626ee6e"}]}, "type": "Plot", "id": "e65c5798-76c4-4947-986a-cf39f1e72367", "subtype": "Chart"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"cyl": 8}], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [1541.2000000000003], "width": [0.8], "y": [770.6000000000001], "x": ["8"], "cyl": [8]}}, "type": "ColumnDataSource", "id": "26016a17-c484-4fb2-8ec2-bbf25d8ebfb5"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "458ae6fc-9efd-464f-bd12-2cc9f0d56ab8"}, "axis_label": "Mean( Mpg )", "formatter": {"type": "BasicTickFormatter", "id": "6d543c2c-87fa-4ec5-8fc3-6d2addf99e72"}, "ticker": {"type": "BasicTicker", "id": "429fe811-3653-4c91-a54d-99167af26e76"}}, "type": "LinearAxis", "id": "f461d3f9-5260-4043-bfe5-e8126fe82de4"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "7beb3a3b-0016-41b4-a20b-91d8b8a3675d"}}, "type":  ...

# %% [markdown]
# Adding the MPG within each CYL group does not make much sense with this data.  We can provide a different function to aggregate data:

# %%
p = Bar(df, label = 'cyl', values='mpg', agg='mean',title="Average MPG by CYL")
show(p)
# Out:
#     <div class="plotdiv" id="7ef9a937-cf8f-4869-bc06-8ae84e021c3a"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7ef9a937-cf8f-4869-bc06-8ae84e021c3a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7ef9a937-cf8f-4869-bc06-8ae84e021c3a' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"518a3527-0a53-4f04-8d35-7c11f6e783c4": {"version": "0.11.0", "roots": {"root_ids": ["0befbfd8-e21e-467c-8226-ef211effe76f", "e65c5798-76c4-4947-986a-cf39f1e72367", "458ae6fc-9efd-464f-bd12-2cc9f0d56ab8", "f862808b-ac93-444f-af4c-2c827120e897"], "references": [{"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "f862808b-ac93-444f-af4c-2c827120e897"}}, "type": "ResizeTool", "id": "e2b28b53-08ec-4a37-9d9a-123f42d4018c"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "2354b65a-d97a-4d3b-9b1e-4118c7e47dc9"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "cb898640-bac5-4b1c-bad9-b8fc076e349d"}, {"attributes": {"x_range": {"type": "FactorRange", "id": "af5e297a-ab9b-47c8-88ab-e7cb2ef22aef"}, "y_mapper_type": "auto", "title_text_font_size": {"value": "14pt"}, "title": "Total MPG by CYL", "y_range": {"type": "Range1d", "id": "64b3bd38-0f4b-44ab-8cae-4212bba000ad"}, "x_mapper_type": "auto", "yscale": "auto", "renderers": [{"type": "BoxAnnotation", "id": "8cac9cdc-8c5b-4d11-9d1a-ae644c3f4ebd"}, {"type": "GlyphRenderer", "id": "e3389b2e-d490-40f6-8d9d-1b212612f764"}, {"type": "GlyphRenderer", "id": "e66b36bc-32e9-47d2-8517-ea7947322445"}, {"type": "GlyphRenderer", "id": "95b2e10f-4a8e-4302-bd5d-5597a60e9fa9"}, {"type": "GlyphRenderer", "id": "04e21358-1768-4322-be08-eec8cb1b92fc"}, {"type": "GlyphRenderer", "id": "72ea8cc5-e52d-4ab9-8f79-e33177f0a0db"}, {"type": "CategoricalAxis", "id": "6e45b6ce-ad21-4d97-9fa0-c19e0ff52df3"}, {"type": "LinearAxis", "id": "bf6503e7-c784-40dd-a51a-ef0ba626ee6e"}, {"type": "Grid", "id": "341bba2e-9094-4862-ba9c-7b947747cc52"}], "plot_width": 500, "xgrid": false, "below": [{"type": "CategoricalAxis", "id": "6e45b6ce-ad21-4d97-9fa0-c19e0ff52df3"}], "tool_events": {"type": "ToolEvents", "id": "c1375f10-bb73-4ce7-8f6e-cbecf383b280"}, "plot_height": 300, "xscale": "auto", "tools": [{"type": "PanTool", "id": "b4d9f140-fe47-4835-82c5-fa4b47009f72"}, {"type": "WheelZoomTool", "id": "b1908dc8-a920-424f-a888-1d49969c3320"}, {"type": "BoxZoomTool", "id": "5a4d251e-7925-43f6-b989-0ea716368a52"}, {"type": "PreviewSaveTool", "id": "73bf5376-a4ff-4788-a8e6-5ff353b6550c"}, {"type": "ResizeTool", "id": "8daff3f7-1af3-4dd9-9f56-8449f87f3079"}, {"type": "ResetTool", "id": "f1eda882-525f-4977-8d5f-1d746068ea33"}, {"type": "HelpTool", "id": "2162cfeb-6ec1-4876-8e71-2d91132066f8"}], "legend": null, "left": [{"type": "LinearAxis", "id": "bf6503e7-c784-40dd-a51a-ef0ba626ee6e"}]}, "type": "Plot", "id": "e65c5798-76c4-4947-986a-cf39f1e72367", "subtype": "Chart"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"cyl": 8}], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [1541.2000000000003], "width": [0.8], "y": [770.6000000000001], "x": ["8"], "cyl": [8]}}, "type": "ColumnDataSource", "id": "26016a17-c484-4fb2-8ec2-bbf25d8ebfb5"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "458ae6fc-9efd-464f-bd12-2cc9f0d56ab8"}, "axis_label": "Mean( Mpg )", "formatter": {"type": "BasicTickFormatter", "id": "6d543c2c-87fa-4ec5-8fc3-6d2addf99e72"}, "ticker": {"type": "BasicTicker", "id": "429fe811-3653-4c91-a54d-99167af26e76"}}, "type": "LinearAxis", "id": "f461d3f9-5260-4043-bfe5-e8126fe82de4"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": [" ...

# %% [markdown]
# <img src='files/resources/ic_assignment_black_24dp_2x.png' align='left'>Try changing the title of the plot.  Bring up the help and find out how to compute the Mean mpg rather than Sum.  Can you find a way to change the color of the bars to blue?

# %% [markdown]
# ### Grouped Bars

# %%
p = Bar(df, label='yr', values='mpg', agg='mean', group='origin',
        title="Mean MPG by YR, grouped by ORIGIN", legend='top_right')

show(p)
# Out:
#     <div class="plotdiv" id="0444b6bd-8aed-4478-a6a6-f0c5575c6da4"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0444b6bd-8aed-4478-a6a6-f0c5575c6da4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0444b6bd-8aed-4478-a6a6-f0c5575c6da4' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"2ef561ab-a551-4ad2-b499-f944d4f6e3c6": {"version": "0.11.0", "roots": {"root_ids": ["0befbfd8-e21e-467c-8226-ef211effe76f", "e65c5798-76c4-4947-986a-cf39f1e72367", "458ae6fc-9efd-464f-bd12-2cc9f0d56ab8", "f862808b-ac93-444f-af4c-2c827120e897", "7beb3a3b-0016-41b4-a20b-91d8b8a3675d", "11b51620-e7e6-4142-a923-7aa22091293c"], "references": [{"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "287f8799-01c6-4801-9b09-4a57e6d15e29"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "1f4842ac-82df-407c-8715-7066df2c7d55"}}, "type": "GlyphRenderer", "id": "9675dab9-2bf1-4235-9213-f16bfe36c59c"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "2354b65a-d97a-4d3b-9b1e-4118c7e47dc9"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "cb898640-bac5-4b1c-bad9-b8fc076e349d"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "11b51620-e7e6-4142-a923-7aa22091293c"}, "overlay": {"type": "BoxAnnotation", "id": "c7f2bb32-b5da-4ed7-a672-fe1ad014a0a5"}}, "type": "BoxZoomTool", "id": "5160617b-fa20-4535-af5c-733f1c553e03"}, {"attributes": {"x_range": {"type": "FactorRange", "id": "af5e297a-ab9b-47c8-88ab-e7cb2ef22aef"}, "y_mapper_type": "auto", "title_text_font_size": {"value": "14pt"}, "title": "Total MPG by CYL", "y_range": {"type": "Range1d", "id": "64b3bd38-0f4b-44ab-8cae-4212bba000ad"}, "x_mapper_type": "auto", "yscale": "auto", "renderers": [{"type": "BoxAnnotation", "id": "8cac9cdc-8c5b-4d11-9d1a-ae644c3f4ebd"}, {"type": "GlyphRenderer", "id": "e3389b2e-d490-40f6-8d9d-1b212612f764"}, {"type": "GlyphRenderer", "id": "e66b36bc-32e9-47d2-8517-ea7947322445"}, {"type": "GlyphRenderer", "id": "95b2e10f-4a8e-4302-bd5d-5597a60e9fa9"}, {"type": "GlyphRenderer", "id": "04e21358-1768-4322-be08-eec8cb1b92fc"}, {"type": "GlyphRenderer", "id": "72ea8cc5-e52d-4ab9-8f79-e33177f0a0db"}, {"type": "CategoricalAxis", "id": "6e45b6ce-ad21-4d97-9fa0-c19e0ff52df3"}, {"type": "LinearAxis", "id": "bf6503e7-c784-40dd-a51a-ef0ba626ee6e"}, {"type": "Grid", "id": "341bba2e-9094-4862-ba9c-7b947747cc52"}], "plot_width": 500, "xgrid": false, "below": [{"type": "CategoricalAxis", "id": "6e45b6ce-ad21-4d97-9fa0-c19e0ff52df3"}], "tool_events": {"type": "ToolEvents", "id": "c1375f10-bb73-4ce7-8f6e-cbecf383b280"}, "plot_height": 300, "xscale": "auto", "tools": [{"type": "PanTool", "id": "b4d9f140-fe47-4835-82c5-fa4b47009f72"}, {"type": "WheelZoomTool", "id": "b1908dc8-a920-424f-a888-1d49969c3320"}, {"type": "BoxZoomTool", "id": "5a4d251e-7925-43f6-b989-0ea716368a52"}, {"type": "PreviewSaveTool", "id": "73bf5376-a4ff-4788-a8e6-5ff353b6550c"}, {"type": "ResizeTool", "id": "8daff3f7-1af3-4dd9-9f56-8449f87f3079"}, {"type": "ResetTool", "id": "f1eda882-525f-4977-8d5f-1d746068ea33"}, {"type": "HelpTool", "id": "2162cfeb-6ec1-4876-8e71-2d91132066f8"}], "legend": null, "left": [{"type": "LinearAxis", "id": "bf6503e7-c784-40dd-a51a-ef0ba626ee6e"}]}, "type": "Plot", "id": "e65c5798-76c4-4947-986a-cf39f1e72367", "subtype": "Chart"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "f862808b-ac93-444f-af4c-2c827120e897"}}, "type": "ResizeTool", "id": "e2b28b53-08ec-4a37-9d9a-123f42d4018c"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"cyl": 8}], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [1541.2000000000003], "width":  ...

# %% [markdown]
# ### Stacked Bars

# %%
p = Bar(df, label='cyl', values='mpg', agg='count', stack='origin',
        title="Count of observations by CYL, stacked by ORIGIN", legend='top_right')
show(p)
# Out:
#     <div class="plotdiv" id="77f208a3-59cc-4199-82ce-0a168fff7de8"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("77f208a3-59cc-4199-82ce-0a168fff7de8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '77f208a3-59cc-4199-82ce-0a168fff7de8' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"615de271-c51a-41c8-b4ca-5fe95908e3cf": {"version": "0.11.0", "roots": {"root_ids": ["0befbfd8-e21e-467c-8226-ef211effe76f", "e65c5798-76c4-4947-986a-cf39f1e72367", "458ae6fc-9efd-464f-bd12-2cc9f0d56ab8", "f862808b-ac93-444f-af4c-2c827120e897", "7beb3a3b-0016-41b4-a20b-91d8b8a3675d", "11b51620-e7e6-4142-a923-7aa22091293c", "f13b2d47-f1f7-4ea7-9d25-898aeb61493a"], "references": [{"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "f862808b-ac93-444f-af4c-2c827120e897"}}, "type": "ResizeTool", "id": "e2b28b53-08ec-4a37-9d9a-123f42d4018c"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"origin": 1, "yr": 70}], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [15.272727272727273], "width": [0.2], "y": [7.636363636363637], "x": ["70:0.25"], "yr": [70], "origin": [1]}}, "type": "ColumnDataSource", "id": "67c84321-521d-440e-9c15-f9a2bb6a9790"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "11b51620-e7e6-4142-a923-7aa22091293c"}, "overlay": {"type": "BoxAnnotation", "id": "c7f2bb32-b5da-4ed7-a672-fe1ad014a0a5"}}, "type": "BoxZoomTool", "id": "5160617b-fa20-4535-af5c-733f1c553e03"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "4c01183b-d253-4581-9d29-8798a4dbf2bb"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "5630c569-a1e6-4c60-b119-415907955371"}}, "type": "GlyphRenderer", "id": "171a4c4f-ceea-4735-b017-75ef1a78aace"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "7beb3a3b-0016-41b4-a20b-91d8b8a3675d"}}, "type": "WheelZoomTool", "id": "0a07fd9e-d507-4596-ac96-926ac83edfd0"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "860ab482-eb2d-4dea-af11-9c266d3c7a01"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "e8ee6665-2fe3-4431-beff-cf365a3ae812"}}, "type": "GlyphRenderer", "id": "6df3382c-ddd3-4932-9a2f-66f4cc44bcab"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "f13b2d47-f1f7-4ea7-9d25-898aeb61493a"}, "overlay": {"type": "BoxAnnotation", "id": "b58dec72-9071-499e-b65a-55578d573f88"}}, "type": "BoxZoomTool", "id": "8274bd8f-73ae-4e5d-814c-7e801cb53936"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"origin": 2, "cyl": 6}], "color": ["#5ab738"], "fill_alpha": [0.8], "height": [4.0], "width": [0.8], "y": [81.0], "x": ["6"], "origin": [2], "cyl": [6]}}, "type": "ColumnDataSource", "id": "1d8e2617-04bd-4064-87f8-4e0ba0517df3"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "0befbfd8-e21e-467c-8226-ef211effe76f"}}, "type": "PanTool", "id": "1cfd0ce2-6a1d-448d-a8d0-c37ed7ce5d20"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"origin": 3, "yr": 77}], "color": ["#407ee7"], "fill_alpha": [0.8], "height": [27.416666666666668], "width": [0.2], "y": [13.708333333333334], "x": ["77:0.5"], "yr": [77], "origin": [3]}}, "type": "ColumnDataSource", "id": "fd72d9a6-52bf-4507-badd-e04ea20f28f3"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"cyl": 4}], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [29.283919597989957], "width": [0.8], "y": [14.641959798994979], "x": ["4"], "cyl": [4]}}, "type": "ColumnDataSource", "id": "287f8799-01c6-4801-9b09-4a57e6d15e29"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "0be ...

# %% [markdown]
# ### Line Chart
#
# Simple line chart - first we group by the yr and compute mean of each value.

# %%
from bokeh.charts import Line

df_mean = df.groupby("yr", as_index=False).mean()

line = Line(data=df_mean, x='yr', y='mpg')
show(line)
# Out:
#     <div class="plotdiv" id="efc4b478-0427-42a8-89bd-d14d88810eac"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("efc4b478-0427-42a8-89bd-d14d88810eac");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'efc4b478-0427-42a8-89bd-d14d88810eac' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9c6e46b3-aff0-41c0-b05c-f39ebdcf7b42": {"version": "0.11.0", "roots": {"root_ids": ["0befbfd8-e21e-467c-8226-ef211effe76f", "e65c5798-76c4-4947-986a-cf39f1e72367", "458ae6fc-9efd-464f-bd12-2cc9f0d56ab8", "f862808b-ac93-444f-af4c-2c827120e897", "7beb3a3b-0016-41b4-a20b-91d8b8a3675d", "11b51620-e7e6-4142-a923-7aa22091293c", "f13b2d47-f1f7-4ea7-9d25-898aeb61493a", "9410ebe8-6c37-4f02-a36d-9e959ce83b96"], "references": [{"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "f862808b-ac93-444f-af4c-2c827120e897"}}, "type": "ResizeTool", "id": "e2b28b53-08ec-4a37-9d9a-123f42d4018c"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"origin": 1, "yr": 70}], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [15.272727272727273], "width": [0.2], "y": [7.636363636363637], "x": ["70:0.25"], "yr": [70], "origin": [1]}}, "type": "ColumnDataSource", "id": "67c84321-521d-440e-9c15-f9a2bb6a9790"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "11b51620-e7e6-4142-a923-7aa22091293c"}, "overlay": {"type": "BoxAnnotation", "id": "c7f2bb32-b5da-4ed7-a672-fe1ad014a0a5"}}, "type": "BoxZoomTool", "id": "5160617b-fa20-4535-af5c-733f1c553e03"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "72344e49-a1d7-45cf-a920-137a91b2b968"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "4c01183b-d253-4581-9d29-8798a4dbf2bb"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "5630c569-a1e6-4c60-b119-415907955371"}}, "type": "GlyphRenderer", "id": "171a4c4f-ceea-4735-b017-75ef1a78aace"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "7beb3a3b-0016-41b4-a20b-91d8b8a3675d"}}, "type": "WheelZoomTool", "id": "0a07fd9e-d507-4596-ac96-926ac83edfd0"}, {"attributes": {"x_range": {"type": "FactorRange", "id": "af5e297a-ab9b-47c8-88ab-e7cb2ef22aef"}, "y_mapper_type": "auto", "title_text_font_size": {"value": "14pt"}, "title": "Total MPG by CYL", "y_range": {"type": "Range1d", "id": "64b3bd38-0f4b-44ab-8cae-4212bba000ad"}, "x_mapper_type": "auto", "yscale": "auto", "renderers": [{"type": "BoxAnnotation", "id": "8cac9cdc-8c5b-4d11-9d1a-ae644c3f4ebd"}, {"type": "GlyphRenderer", "id": "e3389b2e-d490-40f6-8d9d-1b212612f764"}, {"type": "GlyphRenderer", "id": "e66b36bc-32e9-47d2-8517-ea7947322445"}, {"type": "GlyphRenderer", "id": "95b2e10f-4a8e-4302-bd5d-5597a60e9fa9"}, {"type": "GlyphRenderer", "id": "04e21358-1768-4322-be08-eec8cb1b92fc"}, {"type": "GlyphRenderer", "id": "72ea8cc5-e52d-4ab9-8f79-e33177f0a0db"}, {"type": "CategoricalAxis", "id": "6e45b6ce-ad21-4d97-9fa0-c19e0ff52df3"}, {"type": "LinearAxis", "id": "bf6503e7-c784-40dd-a51a-ef0ba626ee6e"}, {"type": "Grid", "id": "341bba2e-9094-4862-ba9c-7b947747cc52"}], "plot_width": 500, "xgrid": false, "below": [{"type": "CategoricalAxis", "id": "6e45b6ce-ad21-4d97-9fa0-c19e0ff52df3"}], "tool_events": {"type": "ToolEvents", "id": "c1375f10-bb73-4ce7-8f6e-cbecf383b280"}, "plot_height": 300, "xscale": "auto", "tools": [{"type": "PanTool", "id": "b4d9f140-fe47-4835-82c5-fa4b47009f72"}, {"type": "WheelZoomTool", "id": "b1908dc8-a920-424f-a888-1d49969c3320"}, {"type": "BoxZoomTool", "id": "5a4d251e-7925-43f6-b989-0ea716368a52"}, {"type": "PreviewSaveTool", "id": "73bf5376-a4ff-4788-a8e6-5ff353b6550c"}, {"type": "ResizeTool", "id": "8daff3f7-1af3-4dd9-9f56-8449f87f3079"}, {"type": "ResetTool", "id": "f1eda882-525f-4977-8d5f-1d746068ea33"}, {"type": "HelpTool", "id": "2162cfeb-6ec1-4876-8e71-2d91132066f8"}], "legend": null, "left": [{"type": "LinearAxis", "id": "bf6503e7-c784-40dd-a51a-ef0ba626ee6e"}]}, "type": "Plot", "id": "e65c5798-76c4-4947-986a-cf39f1e72367", "subtype": "Chart"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "f13b2d47-f1f7-4ea7-9d25-898aeb61493a"}, "overlay": {"type": "Bo ...

# %% [markdown]
# <img src='files/resources/ic_assignment_black_24dp_2x.png' align='left'>Can you find out how to add a second line showing the mean number of cylinders to the plot? The data frame already includes the value - you just need a change to the bokeh Line() call.

# %% [markdown]
# ### Scatter Chart
#
# Simple, color mapped to category, shape mapped to category

# %%
from bokeh.charts import Scatter

scatter = Scatter(data=df, x='mpg',y='weight', color ='cyl', legend='top_left')
show(scatter)
# Out:
#     <div class="plotdiv" id="f2837ce9-addc-4c7e-8ccd-902b827be03f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f2837ce9-addc-4c7e-8ccd-902b827be03f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f2837ce9-addc-4c7e-8ccd-902b827be03f' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"715f097a-fb1b-4702-81f3-adea2ed7c705": {"version": "0.11.0", "roots": {"root_ids": ["0befbfd8-e21e-467c-8226-ef211effe76f", "e65c5798-76c4-4947-986a-cf39f1e72367", "458ae6fc-9efd-464f-bd12-2cc9f0d56ab8", "f862808b-ac93-444f-af4c-2c827120e897", "7beb3a3b-0016-41b4-a20b-91d8b8a3675d", "11b51620-e7e6-4142-a923-7aa22091293c", "f13b2d47-f1f7-4ea7-9d25-898aeb61493a", "9410ebe8-6c37-4f02-a36d-9e959ce83b96", "0724d2ce-ced8-4f68-a031-c2ff029f74ea"], "references": [{"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "f862808b-ac93-444f-af4c-2c827120e897"}}, "type": "ResizeTool", "id": "e2b28b53-08ec-4a37-9d9a-123f42d4018c"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"origin": 1, "yr": 70}], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [15.272727272727273], "width": [0.2], "y": [7.636363636363637], "x": ["70:0.25"], "yr": [70], "origin": [1]}}, "type": "ColumnDataSource", "id": "67c84321-521d-440e-9c15-f9a2bb6a9790"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "11b51620-e7e6-4142-a923-7aa22091293c"}, "overlay": {"type": "BoxAnnotation", "id": "c7f2bb32-b5da-4ed7-a672-fe1ad014a0a5"}}, "type": "BoxZoomTool", "id": "5160617b-fa20-4535-af5c-733f1c553e03"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "72344e49-a1d7-45cf-a920-137a91b2b968"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "4c01183b-d253-4581-9d29-8798a4dbf2bb"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "5630c569-a1e6-4c60-b119-415907955371"}}, "type": "GlyphRenderer", "id": "171a4c4f-ceea-4735-b017-75ef1a78aace"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "7beb3a3b-0016-41b4-a20b-91d8b8a3675d"}}, "type": "WheelZoomTool", "id": "0a07fd9e-d507-4596-ac96-926ac83edfd0"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "860ab482-eb2d-4dea-af11-9c266d3c7a01"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "e8ee6665-2fe3-4431-beff-cf365a3ae812"}}, "type": "GlyphRenderer", "id": "6df3382c-ddd3-4932-9a2f-66f4cc44bcab"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "f13b2d47-f1f7-4ea7-9d25-898aeb61493a"}, "overlay": {"type": "BoxAnnotation", "id": "b58dec72-9071-499e-b65a-55578d573f88"}}, "type": "BoxZoomTool", "id": "8274bd8f-73ae-4e5d-814c-7e801cb53936"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"origin": 2, "cyl": 6}], "color": ["#5ab738"], "fill_alpha": [0.8], "height": [4.0], "width": [0.8], "y": [81.0], "x": ["6"], "origin": [2], "cyl": [6]}}, "type": "ColumnDataSource", "id": "1d8e2617-04bd-4064-87f8-4e0ba0517df3"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "0befbfd8-e21e-467c-8226-ef211effe76f"}}, "type": "PanTool", "id": "1cfd0ce2-6a1d-448d-a8d0-c37ed7ce5d20"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"origin": 3, "yr": 77}], "color": ["#407ee7"], "fill_alpha": [0.8], "height": [27.416666666666668], "width": [0.2], "y": [13.708333333333334], "x": ["77:0.5"], "yr": [77], "origin": [3]}}, "type": "ColumnDataSource", "id": "fd72d9a6-52bf-4507-badd-e04ea20f28f3"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"cyl": 4}], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [29.283919597989957], "width": [0.8], "y": [14.64195979899497 ...

# %% [markdown]
# <img src='files/resources/ic_assignment_black_24dp_2x.png' align='left'>Can you fix the legend placement problem?

# %% [markdown]
# ### Boxplot
#
# Show the spread of the data.

# %%
from bokeh.charts import BoxPlot

boxplot = BoxPlot(df,label='cyl',values='mpg')

show(boxplot)
# Out:
#     <div class="plotdiv" id="a73ec3d2-dcb0-4a5d-b2a4-01f5d9d8339a"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a73ec3d2-dcb0-4a5d-b2a4-01f5d9d8339a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a73ec3d2-dcb0-4a5d-b2a4-01f5d9d8339a' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"26f3caba-ca17-4932-848a-3a83e4a25ffc": {"version": "0.11.0", "roots": {"root_ids": ["0befbfd8-e21e-467c-8226-ef211effe76f", "e65c5798-76c4-4947-986a-cf39f1e72367", "458ae6fc-9efd-464f-bd12-2cc9f0d56ab8", "f862808b-ac93-444f-af4c-2c827120e897", "7beb3a3b-0016-41b4-a20b-91d8b8a3675d", "11b51620-e7e6-4142-a923-7aa22091293c", "f13b2d47-f1f7-4ea7-9d25-898aeb61493a", "9410ebe8-6c37-4f02-a36d-9e959ce83b96", "0724d2ce-ced8-4f68-a031-c2ff029f74ea", "db0a77f3-53d7-4cbc-b491-768978123f1c"], "references": [{"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "f862808b-ac93-444f-af4c-2c827120e897"}}, "type": "ResizeTool", "id": "e2b28b53-08ec-4a37-9d9a-123f42d4018c"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"origin": 1, "yr": 70}], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [15.272727272727273], "width": [0.2], "y": [7.636363636363637], "x": ["70:0.25"], "yr": [70], "origin": [1]}}, "type": "ColumnDataSource", "id": "67c84321-521d-440e-9c15-f9a2bb6a9790"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "11b51620-e7e6-4142-a923-7aa22091293c"}, "overlay": {"type": "BoxAnnotation", "id": "c7f2bb32-b5da-4ed7-a672-fe1ad014a0a5"}}, "type": "BoxZoomTool", "id": "5160617b-fa20-4535-af5c-733f1c553e03"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "72344e49-a1d7-45cf-a920-137a91b2b968"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "db0a77f3-53d7-4cbc-b491-768978123f1c"}, "axis_label": "Mpg", "formatter": {"type": "BasicTickFormatter", "id": "d852552c-31d0-447b-8abc-3c4ff7d34217"}, "ticker": {"type": "BasicTicker", "id": "86a5bc09-b1bb-4fc6-9ea9-2951d6e08437"}}, "type": "LinearAxis", "id": "7c68cbe0-3c05-4d0b-8db1-5c82c0fbdec5"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["black"], "line_alpha": [1.0], "chart_index": [{"cyl": 6}], "color": ["DimGrey"], "fill_alpha": [0.8], "height": [2.0], "width": [0.8], "y": [20.0], "x": ["6"], "cyl": [6]}}, "type": "ColumnDataSource", "id": "3e719792-5e1c-43d0-8c5f-74bd9446c25f"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "4c01183b-d253-4581-9d29-8798a4dbf2bb"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "5630c569-a1e6-4c60-b119-415907955371"}}, "type": "GlyphRenderer", "id": "171a4c4f-ceea-4735-b017-75ef1a78aace"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "7beb3a3b-0016-41b4-a20b-91d8b8a3675d"}}, "type": "WheelZoomTool", "id": "0a07fd9e-d507-4596-ac96-926ac83edfd0"}, {"attributes": {"x_range": {"type": "FactorRange", "id": "af5e297a-ab9b-47c8-88ab-e7cb2ef22aef"}, "y_mapper_type": "auto", "title_text_font_size": {"value": "14pt"}, "title": "Total MPG by CYL", "y_range": {"type": "Range1d", "id": "64b3bd38-0f4b-44ab-8cae-4212bba000ad"}, "x_mapper_type": "auto", "yscale": "auto", "renderers": [{"type": "BoxAnnotation", "id": "8cac9cdc-8c5b-4d11-9d1a-ae644c3f4ebd"}, {"type": "GlyphRenderer", "id": "e3389b2e-d490-40f6-8d9d-1b212612f764"}, {"type": "GlyphRenderer", "id": "e66b36bc-32e9-47d2-8517-ea7947322445"}, {"type": "GlyphRenderer", "id": "95b2e10f-4a8e-4302-bd5d-5597a60e9fa9"}, {"type": "GlyphRenderer", "id": "04e21358-1768-4322-be08-eec8cb1b92fc"}, {"type": "GlyphRenderer", "id": "72ea8cc5-e52d-4ab9-8f79-e33177f0a0db"}, {"type": "CategoricalAxis", "id": "6e45b6ce-ad21-4d97-9fa0-c19e0ff52df3"}, {"type": "LinearAxis", "id": "bf6503e7-c784-40dd-a51a-ef0ba626ee6e"}, {"type": "Grid", "id": "341bba2e-9094-4862-ba9c-7b947747cc52"}], "plot_width": 500, "xgrid": false, "below": [{"type": "CategoricalAxis", "id": "6e45b6ce-ad21-4d97-9fa0-c19e0ff52df3"}], "tool_events": {"type": "ToolEvents", "id": "c1375f10-bb73-4ce7-8f6e-cbecf383b280 ...

# %% [markdown]
# <img src='files/resources/ic_assignment_black_24dp_2x.png' align='left'>Find a way to remove the outliers from the plot.
# Can you change the color of the box?

# %% [markdown]
# ### Where now?
#
# Going from here - browse over to the [bokeh docs](http://bokeh.pydata.org/en/latest/docs/user_guide.html) and start exploring some of the lower level bokeh.plotting libraries and the [gallery](http://bokeh.pydata.org/en/latest/docs/gallery.html) for inspiration.
#
# Remember - [Pandas](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html#pandas.DataFrame) is your friend.  Get that data into Pandas and Bokeh will play very nicely.  Plus Pandas is a great API for working with data frames.  It is worth exploring and learning.
#
# Most the time the default plots will suffice.  It can take many days to get publication ready plots - make sure you really need that tweak to the plot before losing days of your life!
