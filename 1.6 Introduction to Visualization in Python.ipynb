# %% [markdown]
# ## Many Options
#
# There are many options when it comes to producing data visualizations:
#
# * ggplot - R, python
# * matplotlib - python
# * bokeh - python, R, scala
#
# We are going to look at bokeh since it has an API for Python, R and Scala.  It is modern, based on grammar of graphics, designed for the web.  I think it has higher ROL(return on learning) and a lovely logo:
#
# ![Bokeh](http://bokeh.pydata.org/en/latest/_static/images/logo.png)
#
# Lots of resources for bokeh online - start [here](http://bokeh.pydata.org/en/latest/).
#
# Majority of content in this section is a mash up of the content on the Bokeh site.
#
#
# ## Bokeh Charts
#
# Bokeh has 3 levels of interface for different users:
#
# * a low-level [bokeh.models](http://bokeh.pydata.org/en/latest/docs/reference/models.html#bokeh-models) interface that provides the most flexibility to application developers.
# * an intermediate-level [bokeh.plotting](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh-plotting) interface centered around composing visual glyphs.
# * a high-level [bokeh.charts](http://bokeh.pydata.org/en/latest/docs/reference/charts.html#bokeh-charts) interface to build complex statistical plots quickly and simply.
#
# We are going to take a very quick look at bokeh.charts - creating a bar chart, histogram, line chart, scatter chart and a boxplot.  Note we are only scratching the surface - I recommend learning bokeh.plotting when you have time.
#
# For many more details on bokeh.charts read the great documentation [here](http://bokeh.pydata.org/en/latest/docs/user_guide/charts.html).
#
# ### Input Data
#
# Charts uses [Pandas DataFrame](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html#pandas.DataFrame) internally, so any inputs provided will be coerced into this format.
#
# The input types accepted are:
#
# Array-like: 1..* list, tuple, numpy.ndarray, pandas.Series
#
# Table-like:
#
#         records: a list(dict)
#         columns: a dict(list), pandas.DataFrame, or blaze resource
#
# Additional information - [10 Minute Intro to Panda's Data Frame](http://pandas.pydata.org/pandas-docs/stable/10min.html).

# %% [markdown]
# # Bar charts
#
# We are using bokeh.charts as well as a sample data set containing auto mpg data.
#
# We also set the chart size defaults and redirect plots to show up in the notebook:

# %%
from bokeh.charts import defaults, Bar, output_notebook, show
from bokeh.sampledata.autompg import autompg as df

defaults.plot_width = 500
defaults.plot_height = 300

output_notebook(hide_banner=True)

df.head()
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#    mpg  cyl  displ   hp  weight  accel  yr  origin                       name
# 0   18    8    307  130    3504   12.0  70       1  chevrolet chevelle malibu
# 1   15    8    350  165    3693   11.5  70       1          buick skylark 320
# 2   18    8    318  150    3436   11.0  70       1         plymouth satellite
# 3   16    8    304  150    3433   12.0  70       1              amc rebel sst
# 4   17    8    302  140    3449   10.5  70       1                ford torino

# %% [markdown]
# ### Simple Bar Chart

# %%
p = Bar(df, 'cyl', values='mpg', title="Total MPG by CYL")
show(p)
# Out:
#     <div class="plotdiv" id="60aa966a-2ab9-4cbd-8e56-f842cce988ca"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("60aa966a-2ab9-4cbd-8e56-f842cce988ca");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '60aa966a-2ab9-4cbd-8e56-f842cce988ca' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c2bd8089-8313-453a-924f-b87cc07f7da0": {"version": "0.11.0", "roots": {"root_ids": ["167391b1-0bf4-48d8-a831-32c8427bc387", "1d95b61a-5b61-463a-a8a3-e4eef3b62454", "9d8c2a21-3617-4d0b-af35-ff48480f9316", "6d304394-78c0-457c-93ac-021a7ce00084", "39de8b84-7fc4-44dd-8e86-13397172a7d1"], "references": [{"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "7f78d0f0-722e-4912-b63e-1bfb193fab40"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "d298da95-57a7-4942-a7b0-620822e55989"}}, "type": "GlyphRenderer", "id": "1cfb7ca5-c9cf-4188-9f57-fbd5b49c25e6"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "3dad26eb-f0ee-43c4-b6b4-990263cd2604"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "5450820a-c9c1-4bc6-883e-ab41eba5b9e9"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "0a0bf13d-87c7-4c1a-82f3-4446735af706"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "dd10e3f6-9d1b-40f1-a8a0-1c08eb2dd1b4"}}, "type": "GlyphRenderer", "id": "37c45882-39d0-48b2-aae7-0229e59418f3"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "cf5174e8-e856-43ab-86bf-1fbe76232f7f"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "7f781dbe-d398-4238-ad54-e1c3a2a1f75b"}}, "type": "GlyphRenderer", "id": "444e4bc1-e8cc-419d-a452-1666f3c39885"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "167391b1-0bf4-48d8-a831-32c8427bc387"}}, "type": "ResetTool", "id": "4389b289-84d3-451d-930d-a6f2f2b219d1"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "b049fe89-1d57-4701-87e6-440e2f302911"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "d2c0ab79-7fbe-4efb-954e-09c2b78a43d3"}}, "type": "GlyphRenderer", "id": "c6cdbbd0-a0b4-4d9a-825e-cfc3f02499c5"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"name": "ford gran torino (sw)"}], "name": ["ford gran torino (sw)"], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [27.0], "width": [0.8], "y": [13.5], "x": ["ford gran torino (sw)"]}}, "type": "ColumnDataSource", "id": "f1036b74-fcd4-4597-bc0c-c5c52a4daac3"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"cyl": 4}], "color": ["blue"], "fill_alpha": [0.8], "height": [5827.500000000002], "width": [0.8], "y": [2913.750000000001], "x": ["4"], "cyl": [4]}}, "type": "ColumnDataSource", "id": "fba317bb-6038-4d95-bb1c-a756eaa1b546"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "2c5974e9-307a-425c-82fe-8163892d8cd2"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "31bd8459-3 ...

# %% [markdown]
# <img src='files/resources/ic_assignment_black_24dp_2x.png' align='left'>Try changing the title of the plot.  Bring up the help and find out how to compute the Mean mpg rather than Sum.  Can you find a way to change the color of the bars to blue?

# %% [markdown]
# ### Grouped Bars

# %%
p = Bar(df, label='yr', values='mpg', agg='mean', group='origin',
        title="Mean MPG by YR, grouped by ORIGIN", legend='top_right')

show(p)
# Out:
#     <div class="plotdiv" id="5ce3a7aa-cf8d-4cca-9547-733454d19781"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5ce3a7aa-cf8d-4cca-9547-733454d19781");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5ce3a7aa-cf8d-4cca-9547-733454d19781' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a8a2e8c4-2d26-421e-97a3-cadcc691dc28": {"version": "0.11.0", "roots": {"root_ids": ["5379f63e-086d-4079-8b6b-33a921069665", "0890b372-0acc-40d2-9dc0-a114fd22a5e9", "fdc3e971-0f0e-4f36-b9f3-36f7a4d86247", "2fe5ac4d-083f-4c15-8e4b-2e4133e97dbd", "a3aea053-be1f-4abe-979c-8ef1dedd59b5", "70fc66d9-46eb-4f09-94db-9bfe8f57d396", "52dcda94-da63-4b02-b762-09ec7059986a", "3cf0fe5b-a286-4120-8e0c-1cfe19c68d82", "8828f2cd-389f-45ce-8fe4-2071ffdabdaf", "79190508-c266-4954-992a-986db8a92cd9", "991c2c37-e6ff-42ec-9014-b81d945102b9", "9962a0e0-b640-4e9b-a696-135cf1514c92", "398852b9-c81c-4d8c-9e5d-58b82d704e68", "21e6e416-d915-4932-989c-1f7038308b95", "7e0f4c86-81c3-47f8-943e-a53305ef7941", "24a9f410-90c8-4eda-af73-39dfed192403", "daa6f156-c9e0-4f28-bbf4-063bdf474da8", "1e08f384-761f-41f6-a3f0-36afec3c5c42", "15c16ecf-3142-4d32-ac64-c0e3f9afb78e", "e66562f6-225c-4153-9fdb-32c5f91d33e8", "e67f1ef8-9d59-4739-a674-e9bad5699c76", "306cee02-3479-4598-ac3a-093148856c17", "03a1a60b-fc94-4546-92a7-be02d5aee304", "a6b2d6fa-418a-4938-8d0c-af2740c81b1c", "16bd8bca-f903-4b7a-8183-6f1e4b180d2b", "33549f44-49c8-4571-95e0-5619d735aea4"], "references": [{"attributes": {}, "type": "CategoricalTickFormatter", "id": "450b9d5d-10a9-4f97-ae28-0aef0253b8fd"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "1c329fcd-dcb6-4a25-935a-ffe0b0a2b9a6"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "8ba39b07-1dd7-415e-b5da-f815b9e07cd1"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"cyl": 4}], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [5827.500000000002], "width": [0.8], "y": [2913.750000000001], "x": ["4"], "cyl": [4]}}, "type": "ColumnDataSource", "id": "49587a30-4b04-4e92-b687-c11bade0dff0"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "fdc3e971-0f0e-4f36-b9f3-36f7a4d86247"}}, "type": "PreviewSaveTool", "id": "16fbe146-a788-45a3-84c0-715ee26ec181"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "dc51f10a-d618-40de-9f5a-1a168b20f97d"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "9ab920f3-e7f6-4a41-b568-5eddaec6b74e"}}, "type": "GlyphRenderer", "id": "fd7a24a7-7591-4127-a441-37d6f16f4c16"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "0b8eca3e-2e7e-443d-b47b-cab4d3322c72"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"origin": 3, "yr": 73}], "color": ["#407ee7"], "fill_alpha": [0.8], "height": [20.0], "width": [0.2], "y": [10.0], "x": ["73:0.5"], "yr": [73], "origin": [3]}}, "type": "ColumnDataSource", "id": "36242d4c-7f06-4711-acbe-a094099c9fee"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"origin": 1, "yr": 70}], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [15.272727272727273], "width": [0.2], "y": [7.636363636363637], "x": ["70:0.25"], "yr": [70], "origin": [1]}}, "type": "ColumnDataSource", "id": "57329e38-04b8-4726-b6de-83b54228df7b"}, {"attributes": {}, "type": "BasicTicker", "id": "5434fcb2-f36f-43b6-8e12-f3127bb11d44"}, {"attributes": {"callback": null, "c ...

# %% [markdown]
# ### Stacked Bars

# %%
p = Bar(df, label='cyl', values='mpg', agg='count', stack='origin',
        title="Count of observations by CYL, stacked by ORIGIN", legend='top_right')
show(p)
# Out:
#     <div class="plotdiv" id="ee2521a6-9c32-4c18-a316-fceaf49a6efd"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ee2521a6-9c32-4c18-a316-fceaf49a6efd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ee2521a6-9c32-4c18-a316-fceaf49a6efd' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"4eb0d9ad-bc5b-4f31-9acc-2636b91563f5": {"version": "0.11.0", "roots": {"root_ids": ["5379f63e-086d-4079-8b6b-33a921069665", "0890b372-0acc-40d2-9dc0-a114fd22a5e9", "fdc3e971-0f0e-4f36-b9f3-36f7a4d86247", "2fe5ac4d-083f-4c15-8e4b-2e4133e97dbd", "a3aea053-be1f-4abe-979c-8ef1dedd59b5", "70fc66d9-46eb-4f09-94db-9bfe8f57d396", "52dcda94-da63-4b02-b762-09ec7059986a", "3cf0fe5b-a286-4120-8e0c-1cfe19c68d82", "8828f2cd-389f-45ce-8fe4-2071ffdabdaf", "79190508-c266-4954-992a-986db8a92cd9", "991c2c37-e6ff-42ec-9014-b81d945102b9", "9962a0e0-b640-4e9b-a696-135cf1514c92", "398852b9-c81c-4d8c-9e5d-58b82d704e68", "21e6e416-d915-4932-989c-1f7038308b95", "7e0f4c86-81c3-47f8-943e-a53305ef7941", "24a9f410-90c8-4eda-af73-39dfed192403", "daa6f156-c9e0-4f28-bbf4-063bdf474da8", "1e08f384-761f-41f6-a3f0-36afec3c5c42", "15c16ecf-3142-4d32-ac64-c0e3f9afb78e", "e66562f6-225c-4153-9fdb-32c5f91d33e8", "e67f1ef8-9d59-4739-a674-e9bad5699c76", "306cee02-3479-4598-ac3a-093148856c17", "03a1a60b-fc94-4546-92a7-be02d5aee304", "a6b2d6fa-418a-4938-8d0c-af2740c81b1c", "16bd8bca-f903-4b7a-8183-6f1e4b180d2b", "33549f44-49c8-4571-95e0-5619d735aea4", "8d78fdc7-5c76-4486-9ad3-e329fa52ccd8", "fd510781-e404-4fa0-b792-050a18bf94b2", "90908d0e-93e6-4740-982c-8065bf56c9b7", "00e8250a-629b-42f0-b65c-719e4dfc10f5", "10e0c018-0e87-4435-9d35-be94de468993", "08aaefe3-7627-41ea-b663-84d3310f709f", "cdfd350c-e4cd-4f0c-99b0-cb22c5d3f566"], "references": [{"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "daa6f156-c9e0-4f28-bbf4-063bdf474da8"}, "axis_label": "Sum( Mpg )", "formatter": {"type": "BasicTickFormatter", "id": "7ce3fc1d-762c-4b39-aa2b-0d7aad4dc739"}, "ticker": {"type": "BasicTicker", "id": "806642b8-ca7e-4c6e-bb9f-2592e6e1a4d5"}}, "type": "LinearAxis", "id": "e2b67cd3-40ff-40ff-99a8-5b418c332893"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "cdfd350c-e4cd-4f0c-99b0-cb22c5d3f566"}, "axis_label": "Count( Mpg )", "formatter": {"type": "BasicTickFormatter", "id": "97c21c82-f801-491e-8ab7-49e36958de29"}, "ticker": {"type": "BasicTicker", "id": "54ad9803-44dd-4869-a2af-c6320290867d"}}, "type": "LinearAxis", "id": "27519f68-52df-4696-93ee-0c0776214467"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"origin": 3, "yr": 73}], "color": ["#407ee7"], "fill_alpha": [0.8], "height": [20.0], "width": [0.2], "y": [10.0], "x": ["73:0.5"], "yr": [73], "origin": [3]}}, "type": "ColumnDataSource", "id": "36242d4c-7f06-4711-acbe-a094099c9fee"}, {"attributes": {}, "type": "BasicTicker", "id": "5434fcb2-f36f-43b6-8e12-f3127bb11d44"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "5379f63e-086d-4079-8b6b-33a921069665"}}, "type": "ResizeTool", "id": "4d4b1135-a4d9-43f4-b61e-7ec135c5bf43"}, {"attributes": {"major_label_orientation": 0.7853981633974483, "plot": {"subtype": "Chart", "type": "Plot", "id": "3cf0fe5b-a286-4120-8e0c-1cfe19c68d82"}, "axis_label": "Cyl", "formatter": {"type": "CategoricalTickFormatter", "id": "64efc0b9-4677-4931-865b-2d9137c33124"}, "ticker": {"type": "CategoricalTicker", "id": "6c9dc6c0-5070-44cc-a5a6-974ab8b1ed99"}}, "type": "CategoricalAxis", "id": "d98a1ff1-82b4-47d9-8cf2-1a36938c602d"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "03a1a60b-fc94-4546-92a7-be02d5aee304"}}, "type": "HelpTool", "id": "006b1a61-23fd-4bcb-8d82-e20e6a378518"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"cyl": 5}], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [82.1], "width": [0.8], "y": [41.05], "x": ["5"], "cyl": [5]}}, "type": "ColumnDataSource", "id": "07d6ae87-fbe3-4785-be35-075fe1031c32"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type" ...

# %% [markdown]
# ### Line Chart
#
# Simple line chart - first we group by the yr and compute mean of each value.

# %%
from bokeh.charts import Line

df_mean = df.groupby("yr", as_index=False).mean()

line = Line(data=df_mean, x='yr', y='mpg')
show(line)
# Out:
#     <div class="plotdiv" id="f3793ebc-9e44-4019-879e-e557da3723f8"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f3793ebc-9e44-4019-879e-e557da3723f8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f3793ebc-9e44-4019-879e-e557da3723f8' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"0af04122-f8e0-497c-b58f-4a26d92606ac": {"version": "0.11.0", "roots": {"root_ids": ["167391b1-0bf4-48d8-a831-32c8427bc387", "1d95b61a-5b61-463a-a8a3-e4eef3b62454", "9d8c2a21-3617-4d0b-af35-ff48480f9316", "6d304394-78c0-457c-93ac-021a7ce00084", "39de8b84-7fc4-44dd-8e86-13397172a7d1", "5e27ccad-428f-433b-a5ef-3debcfccf721", "d79397f5-fb31-4ef7-bc88-cc0df97cd786", "a05a9746-486f-4fc8-a619-d9a7dc9d5c8e", "6dab9486-d92b-4008-b584-c84ce7836560", "6681b8dd-a2b2-469f-a15e-5a08f53f8fa9"], "references": [{"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "7f78d0f0-722e-4912-b63e-1bfb193fab40"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "d298da95-57a7-4942-a7b0-620822e55989"}}, "type": "GlyphRenderer", "id": "1cfb7ca5-c9cf-4188-9f57-fbd5b49c25e6"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "3dad26eb-f0ee-43c4-b6b4-990263cd2604"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "5450820a-c9c1-4bc6-883e-ab41eba5b9e9"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"name": "ford mustang gl"}], "name": ["ford mustang gl"], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [27.0], "width": [0.8], "y": [13.5], "x": ["ford mustang gl"]}}, "type": "ColumnDataSource", "id": "b8996bd9-4ab1-4a8c-a38f-849b43199e07"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "0a0bf13d-87c7-4c1a-82f3-4446735af706"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "dd10e3f6-9d1b-40f1-a8a0-1c08eb2dd1b4"}}, "type": "GlyphRenderer", "id": "37c45882-39d0-48b2-aae7-0229e59418f3"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "a05a9746-486f-4fc8-a619-d9a7dc9d5c8e"}, "axis_label": "value", "formatter": {"type": "BasicTickFormatter", "id": "796abd7f-766a-419b-8274-36be12f94dba"}, "ticker": {"type": "BasicTicker", "id": "ab7847f8-79a9-496d-b7a5-bcebc2f3c642"}}, "type": "LinearAxis", "id": "f7a073fa-23f8-4790-808d-6591e9a9dbd9"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "167391b1-0bf4-48d8-a831-32c8427bc387"}}, "type": "ResetTool", "id": "4389b289-84d3-451d-930d-a6f2f2b219d1"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"name": "datsun 810"}], "name": ["datsun 810"], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [22.0], "width": [0.8], "y": [11.0], "x": ["datsun 810"]}}, "type": "ColumnDataSource", "id": "660c6a8b-f6ed-4a50-928b-1e3729d2b7e8"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "6dab9486-d92b-4008-b584-c84ce7836560"}, "ticker": {"type": "BasicTicker", "id": "2fc1b0be-6ca1-47be-a3d9-a491d9e98558"}, "dimension": 1}, "type": "Grid", "id": "26f8e2ee-75ef-4217-9c65-2c58a1b42908"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"name": "ford gran torino (sw)"}], "name": ["ford gran torino (sw)"], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [27.0], "width": [0.8], "y": [13.5], "x": ["ford gran torino (sw)"]}}, "type": "ColumnDataSource", "id": "f1036b74-fcd4 ...

# %% [markdown]
# <img src='files/resources/ic_assignment_black_24dp_2x.png' align='left'>Can you find out how to add a second line showing the mean number of cylinders to the plot? The data frame already includes the value - you just need a change to the bokeh Line() call.

# %% [markdown]
# ### Scatter Chart
#
# Simple, color mapped to category, shape mapped to category

# %%
from bokeh.charts import Scatter

scatter = Scatter(data=df, x='mpg',y='weight', color ='cyl', legend='top_left')
show(scatter)
# Out:
#     <div class="plotdiv" id="55da29a2-023d-4e6d-af1a-bccf0e45ed4b"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("55da29a2-023d-4e6d-af1a-bccf0e45ed4b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '55da29a2-023d-4e6d-af1a-bccf0e45ed4b' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d4011b72-b1be-4678-9376-21ca4e5e3fa8": {"version": "0.11.0", "roots": {"root_ids": ["167391b1-0bf4-48d8-a831-32c8427bc387", "1d95b61a-5b61-463a-a8a3-e4eef3b62454", "9d8c2a21-3617-4d0b-af35-ff48480f9316", "6d304394-78c0-457c-93ac-021a7ce00084", "39de8b84-7fc4-44dd-8e86-13397172a7d1", "5e27ccad-428f-433b-a5ef-3debcfccf721", "d79397f5-fb31-4ef7-bc88-cc0df97cd786", "a05a9746-486f-4fc8-a619-d9a7dc9d5c8e", "6dab9486-d92b-4008-b584-c84ce7836560", "6681b8dd-a2b2-469f-a15e-5a08f53f8fa9", "fd2717e5-0c09-48a1-9b56-633fdaf32850", "1b07fa22-915c-4da4-a130-0a33ee4ce5ab", "535e3236-9944-4c5f-9a56-70093d32830c", "8418033f-ea4a-40af-aae8-80e922d5afa4"], "references": [{"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "7f78d0f0-722e-4912-b63e-1bfb193fab40"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "d298da95-57a7-4942-a7b0-620822e55989"}}, "type": "GlyphRenderer", "id": "1cfb7ca5-c9cf-4188-9f57-fbd5b49c25e6"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "3dad26eb-f0ee-43c4-b6b4-990263cd2604"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "5450820a-c9c1-4bc6-883e-ab41eba5b9e9"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "0a0bf13d-87c7-4c1a-82f3-4446735af706"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "dd10e3f6-9d1b-40f1-a8a0-1c08eb2dd1b4"}}, "type": "GlyphRenderer", "id": "37c45882-39d0-48b2-aae7-0229e59418f3"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "a05a9746-486f-4fc8-a619-d9a7dc9d5c8e"}, "axis_label": "value", "formatter": {"type": "BasicTickFormatter", "id": "796abd7f-766a-419b-8274-36be12f94dba"}, "ticker": {"type": "BasicTicker", "id": "ab7847f8-79a9-496d-b7a5-bcebc2f3c642"}}, "type": "LinearAxis", "id": "f7a073fa-23f8-4790-808d-6591e9a9dbd9"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "167391b1-0bf4-48d8-a831-32c8427bc387"}}, "type": "ResetTool", "id": "4389b289-84d3-451d-930d-a6f2f2b219d1"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "a05a9746-486f-4fc8-a619-d9a7dc9d5c8e"}}, "type": "WheelZoomTool", "id": "29807b14-ad9e-472b-8dd4-983f02e4953b"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "6dab9486-d92b-4008-b584-c84ce7836560"}, "ticker": {"type": "BasicTicker", "id": "2fc1b0be-6ca1-47be-a3d9-a491d9e98558"}, "dimension": 1}, "type": "Grid", "id": "26f8e2ee-75ef-4217-9c65-2c58a1b42908"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "ba5bff63-e6a5-4817-9fd8-8b5dbb1045d4"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"name": "ford gran torino (sw)"}], "name": ["ford gran torino (sw)"], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [27.0], "width": [0.8], "y": [13.5], "x": ["ford gran torino (sw)"]}}, "type": "ColumnDataSource", "id": "f1036b74-fcd4-4597-bc0c-c5c52a4daac3"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"cyl": 4}], "color": ["blue"], "fill_alpha": [0.8], "height": [5827.500000000002], "width": [0.8], "y": [2913.750000000001], "x": ["4"], "cyl": [4]}}, "type": "ColumnDataSource", "id": "fba317bb-6038-4d95-bb1c-a756eaa1b546"}, { ...

# %% [markdown]
# <img src='files/resources/ic_assignment_black_24dp_2x.png' align='left'>Can you fix the legend placement problem?

# %% [markdown]
# ### Boxplot
#
# Show the spread of the data.

# %%
from bokeh.charts import BoxPlot

boxplot = BoxPlot(df,label='cyl',values='mpg')

show(boxplot)
# Out:
#     <div class="plotdiv" id="90bd5ccb-8c54-4f5e-a3f2-0c3da5c6f716"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("90bd5ccb-8c54-4f5e-a3f2-0c3da5c6f716");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '90bd5ccb-8c54-4f5e-a3f2-0c3da5c6f716' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1d643fa4-0daf-4d66-98fb-69fd4e9693f9": {"version": "0.11.0", "roots": {"root_ids": ["167391b1-0bf4-48d8-a831-32c8427bc387", "1d95b61a-5b61-463a-a8a3-e4eef3b62454", "9d8c2a21-3617-4d0b-af35-ff48480f9316", "6d304394-78c0-457c-93ac-021a7ce00084", "39de8b84-7fc4-44dd-8e86-13397172a7d1", "5e27ccad-428f-433b-a5ef-3debcfccf721", "d79397f5-fb31-4ef7-bc88-cc0df97cd786", "a05a9746-486f-4fc8-a619-d9a7dc9d5c8e", "6dab9486-d92b-4008-b584-c84ce7836560", "6681b8dd-a2b2-469f-a15e-5a08f53f8fa9", "fd2717e5-0c09-48a1-9b56-633fdaf32850", "1b07fa22-915c-4da4-a130-0a33ee4ce5ab", "535e3236-9944-4c5f-9a56-70093d32830c", "8418033f-ea4a-40af-aae8-80e922d5afa4", "69dcac38-6685-4640-b972-3d91b28f4ca0", "7393c530-73af-48f1-9506-31dd4e62062e", "6ec56da7-31c0-4813-810e-d16b6e3800f3"], "references": [{"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "3dad26eb-f0ee-43c4-b6b4-990263cd2604"}, {"attributes": {"line_color": {"value": "red"}, "fill_color": {"value": "red"}, "fill_alpha": {"value": 0.7}, "y": {"field": "y_values"}, "x": {"field": "x_values"}, "size": {"units": "screen", "value": 5}}, "type": "Circle", "id": "7ddfdd7e-382a-4126-9964-c7db9134a87e"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "a05a9746-486f-4fc8-a619-d9a7dc9d5c8e"}, "axis_label": "value", "formatter": {"type": "BasicTickFormatter", "id": "796abd7f-766a-419b-8274-36be12f94dba"}, "ticker": {"type": "BasicTicker", "id": "ab7847f8-79a9-496d-b7a5-bcebc2f3c642"}}, "type": "LinearAxis", "id": "f7a073fa-23f8-4790-808d-6591e9a9dbd9"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "58e6e5ba-5f2c-42c8-977b-0f34a524099f"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "bd468b26-660b-4de6-af4d-ba84397ee428"}}, "type": "GlyphRenderer", "id": "7b081d92-7885-43dc-873c-f20ca1c61635"}, {"attributes": {}, "type": "ToolEvents", "id": "9278407b-5bca-4b69-af7b-57a28f492cb0"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "eae8b1c6-3c3d-44f5-9f46-6875ca0e1f99"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "6b2b16c4-7067-45d9-9b88-5c9ddfd7680b"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Circle", "id": "f1882411-7b0b-468c-9fbf-dc4603840ca4"}}, "type": "GlyphRenderer", "id": "7c82259d-5d65-40d1-9b2b-15da818c3035"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"name": "mazda rx-4"}], "name": ["mazda rx-4"], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [21.5], "width": [0.8], "y": [10.75], "x": ["mazda rx-4"]}}, "type": "ColumnDataSource", "id": "600b1553-7505-4e4a-8896-d2a92de44757"}, {"attributes": {"callback": null, "column_names": ["x_values", "y_values"], "data": {"x_values": [20.3, 25.4, 36.4], "chart_index": [{"cyl": 5}, {"cyl": 5}, {"cyl": 5}], "y_values": [2830, 3530, 2950], "cyl": [5, 5, 5]}}, "type": "ColumnDataSource", "id": "57cdbec3-20dc-4c4e-9c62-9d3fed776208"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["black"], "line_alpha": [1.0], "chart_index": [{"cyl": 5}], "color": ["DimGrey"], "fill_alpha": [0.8], "height": [5.5], "width": [0.8], "y": [28.15], "x": ["5"], "cyl": [5]}}, "type": "ColumnDataSource", "id": "202e6306-e574-4cda-964a-af06f7605b54"}, ...

# %% [markdown]
# <img src='files/resources/ic_assignment_black_24dp_2x.png' align='left'>Find a way to remove the outliers from the plot.
# Can you change the color of the box?

# %% [markdown]
# ### Where now?
#
# Going from here - browse over to the [bokeh docs](http://bokeh.pydata.org/en/latest/docs/user_guide.html) and start exploring some of the lower level bokeh.plotting libraries and the [gallery](http://bokeh.pydata.org/en/latest/docs/gallery.html) for inspiration.
#
# Remember - [Pandas](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html#pandas.DataFrame) is your friend.  Get that data into Pandas and Bokeh will play very nicely.  Plus Pandas is a great API for working with data frames.  It is worth exploring and learning.
#
# Most the time the default plots will suffice.  It can take many days to get publication ready plots - make sure you really need that tweak to the plot before losing days of your life!
