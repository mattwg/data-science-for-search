# %% [markdown]
# ## Many Options
#
# There are many options when it comes to producing data visualizations:
#
# * ggplot - R, python
# * matplotlib - python
# * bokeh - python, R, scala
#
# We are going to look at bokeh since it has an API for Python, R and Scala.  It is modern, based on grammar of graphics, designed for the web.  I think it has higher ROL(return on learning) and a lovely logo:
#
# ![Bokeh](http://bokeh.pydata.org/en/latest/_static/images/logo.png)
#
# Lots of resources for bokeh online - start [here](http://bokeh.pydata.org/en/latest/).
#
# Majority of content in this section is a mash up of the content on the Bokeh site.
#
#
# ## Bokeh Charts
#
# Bokeh has 3 levels of interface for different users:
#
# * a low-level [bokeh.models](http://bokeh.pydata.org/en/latest/docs/reference/models.html#bokeh-models) interface that provides the most flexibility to application developers.
# * an intermediate-level [bokeh.plotting](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh-plotting) interface centered around composing visual glyphs.
# * a high-level [bokeh.charts](http://bokeh.pydata.org/en/latest/docs/reference/charts.html#bokeh-charts) interface to build complex statistical plots quickly and simply.
#
# We are going to take a very quick look at bokeh.charts - creating a bar chart, histogram, line chart, scatter chart and a boxplot.  Note we are only scratching the surface - I recommend learning bokeh.plotting when you have time.
#
# For many more details on bokeh.charts read the great documentation [here](http://bokeh.pydata.org/en/latest/docs/user_guide/charts.html).
#
# ### Input Data
#
# Charts uses [Pandas DataFrame](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html#pandas.DataFrame) internally, so any inputs provided will be coerced into this format.
#
# The input types accepted are:
#
# Array-like: 1..* list, tuple, numpy.ndarray, pandas.Series
#
# Table-like:
#
#         records: a list(dict)
#         columns: a dict(list), pandas.DataFrame, or blaze resource
#
# Additional information - [10 Minute Intro to Panda's Data Frame](http://pandas.pydata.org/pandas-docs/stable/10min.html).

# %% [markdown]
# # Bar charts
#
# We are using bokeh.charts as well as a sample data set containing auto mpg data.
#
# We also set the chart size defaults and redirect plots to show up in the notebook:

# %%
from bokeh.charts import defaults, Bar, output_notebook, show
from bokeh.sampledata.autompg import autompg as df

defaults.plot_width = 500
defaults.plot_height = 300

output_notebook(hide_banner=True)
df.head()
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#    mpg  cyl  displ   hp  weight  accel  yr  origin                       name
# 0   18    8    307  130    3504   12.0  70       1  chevrolet chevelle malibu
# 1   15    8    350  165    3693   11.5  70       1          buick skylark 320
# 2   18    8    318  150    3436   11.0  70       1         plymouth satellite
# 3   16    8    304  150    3433   12.0  70       1              amc rebel sst
# 4   17    8    302  140    3449   10.5  70       1                ford torino

# %% [markdown]
# ### Simple Bar Chart

# %%
p = Bar(df, label = 'cyl', values='mpg', title="Total MPG by CYL")
show(p)
# Out:
#     <div class="plotdiv" id="4a359b08-a9c9-459d-9560-6734cd6beaf2"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4a359b08-a9c9-459d-9560-6734cd6beaf2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4a359b08-a9c9-459d-9560-6734cd6beaf2' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1aa51b55-c33e-41ec-9de9-ea2e532dfdd2": {"version": "0.11.0", "roots": {"root_ids": ["0befbfd8-e21e-467c-8226-ef211effe76f", "e65c5798-76c4-4947-986a-cf39f1e72367", "458ae6fc-9efd-464f-bd12-2cc9f0d56ab8", "f862808b-ac93-444f-af4c-2c827120e897", "7beb3a3b-0016-41b4-a20b-91d8b8a3675d"], "references": [{"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "f862808b-ac93-444f-af4c-2c827120e897"}}, "type": "ResizeTool", "id": "e2b28b53-08ec-4a37-9d9a-123f42d4018c"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "2354b65a-d97a-4d3b-9b1e-4118c7e47dc9"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "cb898640-bac5-4b1c-bad9-b8fc076e349d"}, {"attributes": {"x_range": {"type": "FactorRange", "id": "af5e297a-ab9b-47c8-88ab-e7cb2ef22aef"}, "y_mapper_type": "auto", "title_text_font_size": {"value": "14pt"}, "title": "Total MPG by CYL", "y_range": {"type": "Range1d", "id": "64b3bd38-0f4b-44ab-8cae-4212bba000ad"}, "x_mapper_type": "auto", "yscale": "auto", "renderers": [{"type": "BoxAnnotation", "id": "8cac9cdc-8c5b-4d11-9d1a-ae644c3f4ebd"}, {"type": "GlyphRenderer", "id": "e3389b2e-d490-40f6-8d9d-1b212612f764"}, {"type": "GlyphRenderer", "id": "e66b36bc-32e9-47d2-8517-ea7947322445"}, {"type": "GlyphRenderer", "id": "95b2e10f-4a8e-4302-bd5d-5597a60e9fa9"}, {"type": "GlyphRenderer", "id": "04e21358-1768-4322-be08-eec8cb1b92fc"}, {"type": "GlyphRenderer", "id": "72ea8cc5-e52d-4ab9-8f79-e33177f0a0db"}, {"type": "CategoricalAxis", "id": "6e45b6ce-ad21-4d97-9fa0-c19e0ff52df3"}, {"type": "LinearAxis", "id": "bf6503e7-c784-40dd-a51a-ef0ba626ee6e"}, {"type": "Grid", "id": "341bba2e-9094-4862-ba9c-7b947747cc52"}], "plot_width": 500, "xgrid": false, "below": [{"type": "CategoricalAxis", "id": "6e45b6ce-ad21-4d97-9fa0-c19e0ff52df3"}], "tool_events": {"type": "ToolEvents", "id": "c1375f10-bb73-4ce7-8f6e-cbecf383b280"}, "plot_height": 300, "xscale": "auto", "tools": [{"type": "PanTool", "id": "b4d9f140-fe47-4835-82c5-fa4b47009f72"}, {"type": "WheelZoomTool", "id": "b1908dc8-a920-424f-a888-1d49969c3320"}, {"type": "BoxZoomTool", "id": "5a4d251e-7925-43f6-b989-0ea716368a52"}, {"type": "PreviewSaveTool", "id": "73bf5376-a4ff-4788-a8e6-5ff353b6550c"}, {"type": "ResizeTool", "id": "8daff3f7-1af3-4dd9-9f56-8449f87f3079"}, {"type": "ResetTool", "id": "f1eda882-525f-4977-8d5f-1d746068ea33"}, {"type": "HelpTool", "id": "2162cfeb-6ec1-4876-8e71-2d91132066f8"}], "legend": null, "left": [{"type": "LinearAxis", "id": "bf6503e7-c784-40dd-a51a-ef0ba626ee6e"}]}, "type": "Plot", "id": "e65c5798-76c4-4947-986a-cf39f1e72367", "subtype": "Chart"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"cyl": 8}], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [1541.2000000000003], "width": [0.8], "y": [770.6000000000001], "x": ["8"], "cyl": [8]}}, "type": "ColumnDataSource", "id": "26016a17-c484-4fb2-8ec2-bbf25d8ebfb5"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "458ae6fc-9efd-464f-bd12-2cc9f0d56ab8"}, "axis_label": "Mean( Mpg )", "formatter": {"type": "BasicTickFormatter", "id": "6d543c2c-87fa-4ec5-8fc3-6d2addf99e72"}, "ticker": {"type": "BasicTicker", "id": "429fe811-3653-4c91-a54d-99167af26e76"}}, "type": "LinearAxis", "id": "f461d3f9-5260-4043-bfe5-e8126fe82de4"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "7beb3a3b-0016-41b4-a20b-91d8b8a3675d"}}, "type":  ...

# %% [markdown]
# Adding the MPG within each CYL group does not make much sense with this data.  It does make sense if we want to plot a h  We can provide a different function to aggregate data:

# %%
p = Bar(df, label = 'cyl', values='mpg', agg='mean',title="Average MPG by CYL")
show(p)
# Out:
#     <div class="plotdiv" id="7ef9a937-cf8f-4869-bc06-8ae84e021c3a"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7ef9a937-cf8f-4869-bc06-8ae84e021c3a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7ef9a937-cf8f-4869-bc06-8ae84e021c3a' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"518a3527-0a53-4f04-8d35-7c11f6e783c4": {"version": "0.11.0", "roots": {"root_ids": ["0befbfd8-e21e-467c-8226-ef211effe76f", "e65c5798-76c4-4947-986a-cf39f1e72367", "458ae6fc-9efd-464f-bd12-2cc9f0d56ab8", "f862808b-ac93-444f-af4c-2c827120e897"], "references": [{"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "f862808b-ac93-444f-af4c-2c827120e897"}}, "type": "ResizeTool", "id": "e2b28b53-08ec-4a37-9d9a-123f42d4018c"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "2354b65a-d97a-4d3b-9b1e-4118c7e47dc9"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "cb898640-bac5-4b1c-bad9-b8fc076e349d"}, {"attributes": {"x_range": {"type": "FactorRange", "id": "af5e297a-ab9b-47c8-88ab-e7cb2ef22aef"}, "y_mapper_type": "auto", "title_text_font_size": {"value": "14pt"}, "title": "Total MPG by CYL", "y_range": {"type": "Range1d", "id": "64b3bd38-0f4b-44ab-8cae-4212bba000ad"}, "x_mapper_type": "auto", "yscale": "auto", "renderers": [{"type": "BoxAnnotation", "id": "8cac9cdc-8c5b-4d11-9d1a-ae644c3f4ebd"}, {"type": "GlyphRenderer", "id": "e3389b2e-d490-40f6-8d9d-1b212612f764"}, {"type": "GlyphRenderer", "id": "e66b36bc-32e9-47d2-8517-ea7947322445"}, {"type": "GlyphRenderer", "id": "95b2e10f-4a8e-4302-bd5d-5597a60e9fa9"}, {"type": "GlyphRenderer", "id": "04e21358-1768-4322-be08-eec8cb1b92fc"}, {"type": "GlyphRenderer", "id": "72ea8cc5-e52d-4ab9-8f79-e33177f0a0db"}, {"type": "CategoricalAxis", "id": "6e45b6ce-ad21-4d97-9fa0-c19e0ff52df3"}, {"type": "LinearAxis", "id": "bf6503e7-c784-40dd-a51a-ef0ba626ee6e"}, {"type": "Grid", "id": "341bba2e-9094-4862-ba9c-7b947747cc52"}], "plot_width": 500, "xgrid": false, "below": [{"type": "CategoricalAxis", "id": "6e45b6ce-ad21-4d97-9fa0-c19e0ff52df3"}], "tool_events": {"type": "ToolEvents", "id": "c1375f10-bb73-4ce7-8f6e-cbecf383b280"}, "plot_height": 300, "xscale": "auto", "tools": [{"type": "PanTool", "id": "b4d9f140-fe47-4835-82c5-fa4b47009f72"}, {"type": "WheelZoomTool", "id": "b1908dc8-a920-424f-a888-1d49969c3320"}, {"type": "BoxZoomTool", "id": "5a4d251e-7925-43f6-b989-0ea716368a52"}, {"type": "PreviewSaveTool", "id": "73bf5376-a4ff-4788-a8e6-5ff353b6550c"}, {"type": "ResizeTool", "id": "8daff3f7-1af3-4dd9-9f56-8449f87f3079"}, {"type": "ResetTool", "id": "f1eda882-525f-4977-8d5f-1d746068ea33"}, {"type": "HelpTool", "id": "2162cfeb-6ec1-4876-8e71-2d91132066f8"}], "legend": null, "left": [{"type": "LinearAxis", "id": "bf6503e7-c784-40dd-a51a-ef0ba626ee6e"}]}, "type": "Plot", "id": "e65c5798-76c4-4947-986a-cf39f1e72367", "subtype": "Chart"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"cyl": 8}], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [1541.2000000000003], "width": [0.8], "y": [770.6000000000001], "x": ["8"], "cyl": [8]}}, "type": "ColumnDataSource", "id": "26016a17-c484-4fb2-8ec2-bbf25d8ebfb5"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "458ae6fc-9efd-464f-bd12-2cc9f0d56ab8"}, "axis_label": "Mean( Mpg )", "formatter": {"type": "BasicTickFormatter", "id": "6d543c2c-87fa-4ec5-8fc3-6d2addf99e72"}, "ticker": {"type": "BasicTicker", "id": "429fe811-3653-4c91-a54d-99167af26e76"}}, "type": "LinearAxis", "id": "f461d3f9-5260-4043-bfe5-e8126fe82de4"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": [" ...

# %% [markdown]
# <img src='files/resources/ic_assignment_black_24dp_2x.png' align='left'>Try changing the title of the plot.  Bring up the help and find out how to compute the Mean mpg rather than Sum.  Can you find a way to change the color of the bars to blue?

# %% [markdown]
# ### Grouped Bars

# %%
p = Bar(df, label='yr', values='mpg', agg='mean', group='origin',
        title="Mean MPG by YR, grouped by ORIGIN", legend='top_right')

show(p)
# Out:
#     <div class="plotdiv" id="a4f568bc-7cf7-4d3f-9a71-509f6537b38f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a4f568bc-7cf7-4d3f-9a71-509f6537b38f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a4f568bc-7cf7-4d3f-9a71-509f6537b38f' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"22d5d1d4-e768-4de3-aa3c-77038dce1939": {"version": "0.11.0", "roots": {"root_ids": ["149792b5-4beb-49e8-a56b-69ca39e6b877", "6b90269b-0416-49dc-98d7-f0b78aa71cad"], "references": [{"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "0e019a23-d21f-4603-a4ed-fd69874f54d4"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "7140c75d-e0a6-4596-a830-bf1189da7522"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "b767ca34-2289-4153-ace1-e006466ee8a1"}}, "type": "GlyphRenderer", "id": "b0f00f78-81cf-4573-abb5-21c9780226c5"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "fddabf80-ff0c-46a9-972e-3d613a2df332"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "d8484581-e5cf-4ef4-8d4e-886072a28582"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "dc8365f6-6e97-4268-bc5c-c7b1ee0beaa1"}}, "type": "GlyphRenderer", "id": "4eeaa36a-af21-4b76-a086-e8098a584a67"}, {"attributes": {"major_label_orientation": 0.7853981633974483, "plot": {"subtype": "Chart", "type": "Plot", "id": "6b90269b-0416-49dc-98d7-f0b78aa71cad"}, "axis_label": "Yr", "formatter": {"type": "CategoricalTickFormatter", "id": "54da478d-6293-4f30-aa96-eb8d24911282"}, "ticker": {"type": "CategoricalTicker", "id": "8d858a37-0acc-419c-89d7-cc8b0296c1b9"}}, "type": "CategoricalAxis", "id": "ae92ff71-c429-40b5-9dc1-b53f408d5803"}, {"attributes": {"x_range": {"type": "FactorRange", "id": "85510178-b03c-41c7-8577-999b95ccd3f4"}, "y_mapper_type": "auto", "title_text_font_size": {"value": "14pt"}, "title": "Total MPG by CYL", "y_range": {"type": "Range1d", "id": "e4215163-0764-458b-b636-3aab5f6d84ee"}, "x_mapper_type": "auto", "yscale": "auto", "renderers": [{"type": "BoxAnnotation", "id": "7329a782-3133-455b-96d4-0dcb87cae71b"}, {"type": "GlyphRenderer", "id": "f7da5948-82a1-40b0-afda-734474534932"}, {"type": "GlyphRenderer", "id": "26be7cca-57a2-43ae-a9e2-92773d2fa1a6"}, {"type": "GlyphRenderer", "id": "91b0cd03-c87c-41c4-9e92-a0cf30bad73c"}, {"type": "GlyphRenderer", "id": "b432cc60-4cf3-4c25-8aad-4173c228659b"}, {"type": "GlyphRenderer", "id": "23557940-99e8-4b63-b579-be2977221715"}, {"type": "CategoricalAxis", "id": "76a0863f-78be-47f9-b9cf-41107a434148"}, {"type": "LinearAxis", "id": "9e7e0005-2182-4e31-950a-d837bfa05f79"}, {"type": "Grid", "id": "68b83582-0682-4d39-8d74-cb6c99f808eb"}], "plot_width": 500, "xgrid": false, "below": [{"type": "CategoricalAxis", "id": "76a0863f-78be-47f9-b9cf-41107a434148"}], "tool_events": {"type": "ToolEvents", "id": "ab078d6f-1e91-4b20-9d50-dd69cf5abdc2"}, "plot_height": 300, "xscale": "auto", "tools": [{"type": "PanTool", "id": "23108e32-57bc-45c0-9ed1-47ba5fada557"}, {"type": "WheelZoomTool", "id": "6b056ede-ee58-4aa1-80eb-c53a776eab8c"}, {"type": "BoxZoomTool", "id": "51e6c78e-6e6c-4261-ab37-2edfa37cfbf5"}, {"type": "PreviewSaveTool", "id": "66b0b9a1-644f-4e94-aa5b-c1653f84035d"}, {"type": "ResizeTool", "id": "0b25620a-c3c4-4b4c-a0b2-69ab1a10a97b"}, {"type": "ResetTool", "id": "4d2b9249-b17e-4883-a093-0459d9386d3a"}, {"type": "HelpTool", "id": "27642ec7-ce82-4497-b5fc-202aa62f29ed"}], "legend": null, "left": [{"type": "LinearAxis", "id": "9e7e0005-2182-4e31-950a-d837bfa05f79"}]}, "type": "Plot", "id": "149792b5-4beb-49e8-a56b-69ca39e6b877", "subtype": "Chart"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "08c2f82b-4689-44f9-b356-cacdeee57e0f"}, {"attributes": {"line_color": {"field": "lin ...

# %% [markdown]
# ### Stacked Bars

# %%
p = Bar(df, label='cyl', values='mpg', agg='count', stack='origin',
        title="Count of observations by CYL, stacked by ORIGIN", legend='top_right')
show(p)
# Out:
#     <div class="plotdiv" id="acb24596-ce71-4dc1-a3d1-53a4fbbcadaf"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("acb24596-ce71-4dc1-a3d1-53a4fbbcadaf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'acb24596-ce71-4dc1-a3d1-53a4fbbcadaf' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ad71ccda-d443-4cc3-8516-5707ce67fcc9": {"version": "0.11.0", "roots": {"root_ids": ["149792b5-4beb-49e8-a56b-69ca39e6b877", "6b90269b-0416-49dc-98d7-f0b78aa71cad", "21cbb82d-c32b-4da5-a8b2-7bfdff3504df"], "references": [{"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "0e019a23-d21f-4603-a4ed-fd69874f54d4"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "6b90269b-0416-49dc-98d7-f0b78aa71cad"}, "axis_label": "Mean( Mpg )", "formatter": {"type": "BasicTickFormatter", "id": "08c2f82b-4689-44f9-b356-cacdeee57e0f"}, "ticker": {"type": "BasicTicker", "id": "b0009577-b0dc-4f96-9c9e-6c0c67ac3641"}}, "type": "LinearAxis", "id": "0aba057a-fc2a-4225-83ef-e29fd91f75cb"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "7140c75d-e0a6-4596-a830-bf1189da7522"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "b767ca34-2289-4153-ace1-e006466ee8a1"}}, "type": "GlyphRenderer", "id": "b0f00f78-81cf-4573-abb5-21c9780226c5"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "fddabf80-ff0c-46a9-972e-3d613a2df332"}, {"attributes": {}, "type": "BasicTicker", "id": "59cb6ec7-b137-4c01-95a3-4ace3e55f99b"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "d8484581-e5cf-4ef4-8d4e-886072a28582"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "dc8365f6-6e97-4268-bc5c-c7b1ee0beaa1"}}, "type": "GlyphRenderer", "id": "4eeaa36a-af21-4b76-a086-e8098a584a67"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "2c6657ec-ff4b-49b4-b16c-1dcf048fc49c"}, {"attributes": {"major_label_orientation": 0.7853981633974483, "plot": {"subtype": "Chart", "type": "Plot", "id": "6b90269b-0416-49dc-98d7-f0b78aa71cad"}, "axis_label": "Yr", "formatter": {"type": "CategoricalTickFormatter", "id": "54da478d-6293-4f30-aa96-eb8d24911282"}, "ticker": {"type": "CategoricalTicker", "id": "8d858a37-0acc-419c-89d7-cc8b0296c1b9"}}, "type": "CategoricalAxis", "id": "ae92ff71-c429-40b5-9dc1-b53f408d5803"}, {"attributes": {"x_range": {"type": "FactorRange", "id": "85510178-b03c-41c7-8577-999b95ccd3f4"}, "y_mapper_type": "auto", "title_text_font_size": {"value": "14pt"}, "title": "Total MPG by CYL", "y_range": {"type": "Range1d", "id": "e4215163-0764-458b-b636-3aab5f6d84ee"}, "x_mapper_type": "auto", "yscale": "auto", "renderers": [{"type": "BoxAnnotation", "id": "7329a782-3133-455b-96d4-0dcb87cae71b"}, {"type": "GlyphRenderer", "id": "f7da5948-82a1-40b0-afda-734474534932"}, {"type": "GlyphRenderer", "id": "26be7cca-57a2-43ae-a9e2-92773d2fa1a6"}, {"type": "GlyphRenderer", "id": "91b0cd03-c87c-41c4-9e92-a0cf30bad73c"}, {"type": "GlyphRenderer", "id": "b432cc60-4cf3-4c25-8aad-4173c228659b"}, {"type": "GlyphRenderer", "id": "23557940-99e8-4b63-b579-be2977221715"}, {"type": "CategoricalAxis", "id": "76a0863f-78be-47f9-b9cf-41107a434148"}, {"type": "LinearAxis", "id": "9e7e0005-2182-4e31-950a-d837bfa05f79"}, {"type": "Grid", "id": "68b83582-0682-4d39-8d74-cb6c99f808eb"}], "plot_width": 500, "xgrid": false, "below": [{"type": "CategoricalAxis", "id": "76a0863f-78be-47f9-b9cf-41107a434148"}], "tool_events": {"type": "ToolEvents", "id": "ab078d6f-1e91-4b20-9d50-dd69cf5abdc2"}, "plot_height": 300, "xscale": "auto", "tools": [{"type": "PanTool", "id": "23108e32-57bc-45c0-9ed1-47ba5fada557"}, {"type": "WheelZoomTool", "id": "6b056ede-ee58-4aa1-80eb-c53a776eab8c"}, {"type": "BoxZoomTool", "id": "51e6c78e-6e6c-4261-ab37-2edfa37cfbf5"}, ...

# %% [markdown]
# ### Line Chart
#
# Simple line chart - first we group by the yr and compute mean of each value.

# %%
from bokeh.charts import Line

df_mean = df.groupby("yr", as_index=False).mean()

line = Line(data=df_mean, x='yr', y='mpg')
show(line)
# Out:
#     <div class="plotdiv" id="186a09bc-1747-413b-8a07-d8ca7c34ac0e"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("186a09bc-1747-413b-8a07-d8ca7c34ac0e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '186a09bc-1747-413b-8a07-d8ca7c34ac0e' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"02ef50f5-521c-416c-ba12-fb3911707159": {"version": "0.11.0", "roots": {"root_ids": ["149792b5-4beb-49e8-a56b-69ca39e6b877", "6b90269b-0416-49dc-98d7-f0b78aa71cad", "21cbb82d-c32b-4da5-a8b2-7bfdff3504df", "cbf884f2-00fe-47e5-ae31-174b10884d2f"], "references": [{"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "0e019a23-d21f-4603-a4ed-fd69874f54d4"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"origin": 3, "yr": 80}], "color": ["#407ee7"], "fill_alpha": [0.8], "height": [35.4], "width": [0.2], "y": [17.7], "x": ["80:0.5"], "yr": [80], "origin": [3]}}, "type": "ColumnDataSource", "id": "032b34fa-5885-4430-a4aa-57f746e30ff2"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "fddabf80-ff0c-46a9-972e-3d613a2df332"}, {"attributes": {}, "type": "BasicTicker", "id": "59cb6ec7-b137-4c01-95a3-4ace3e55f99b"}, {"attributes": {"callback": null, "end": 83.2, "start": 68.8}, "type": "Range1d", "id": "4f93eb11-f8b9-41ec-8c45-9fe1d78d1d41"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "d8484581-e5cf-4ef4-8d4e-886072a28582"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "dc8365f6-6e97-4268-bc5c-c7b1ee0beaa1"}}, "type": "GlyphRenderer", "id": "4eeaa36a-af21-4b76-a086-e8098a584a67"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "2c6657ec-ff4b-49b4-b16c-1dcf048fc49c"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "d37019a0-790a-4428-a8d2-2ac570c90e14"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "d92f8367-b782-4ae7-a921-9d2eba7807fc"}}, "type": "GlyphRenderer", "id": "6e876256-c386-4c5c-bd07-639428a4093a"}, {"attributes": {"x_range": {"type": "FactorRange", "id": "85510178-b03c-41c7-8577-999b95ccd3f4"}, "y_mapper_type": "auto", "title_text_font_size": {"value": "14pt"}, "title": "Total MPG by CYL", "y_range": {"type": "Range1d", "id": "e4215163-0764-458b-b636-3aab5f6d84ee"}, "x_mapper_type": "auto", "yscale": "auto", "renderers": [{"type": "BoxAnnotation", "id": "7329a782-3133-455b-96d4-0dcb87cae71b"}, {"type": "GlyphRenderer", "id": "f7da5948-82a1-40b0-afda-734474534932"}, {"type": "GlyphRenderer", "id": "26be7cca-57a2-43ae-a9e2-92773d2fa1a6"}, {"type": "GlyphRenderer", "id": "91b0cd03-c87c-41c4-9e92-a0cf30bad73c"}, {"type": "GlyphRenderer", "id": "b432cc60-4cf3-4c25-8aad-4173c228659b"}, {"type": "GlyphRenderer", "id": "23557940-99e8-4b63-b579-be2977221715"}, {"type": "CategoricalAxis", "id": "76a0863f-78be-47f9-b9cf-41107a434148"}, {"type": "LinearAxis", "id": "9e7e0005-2182-4e31-950a-d837bfa05f79"}, {"type": "Grid", "id": "68b83582-0682-4d39-8d74-cb6c99f808eb"}], "plot_width": 500, "xgrid": false, "below": [{"type": "CategoricalAxis", "id": "76a0863f-78be-47f9-b9cf-41107a434148"}], "tool_events": {"type": "ToolEvents", "id": "ab078d6f-1e91-4b20-9d50-dd69cf5abdc2"}, "plot_height": 300, "xscale": "auto", "tools": [{"type": "PanTool", "id": "23108e32-57bc-45c0-9ed1-47ba5fada557"}, {"type": "WheelZoomTool", "id": "6b056ede-ee58-4aa1-80eb-c53a776eab8c"}, {"type": "BoxZoomTool", "id": "51e6c78e-6e6c-4261-ab37-2edfa37cfbf5"}, {"type": "PreviewSaveTool", "id": "66b0b9a1-644f-4e94-aa5b-c1653f84035d"}, {"type": "ResizeTool", "id": "0b25620a-c3c4-4b4c-a0b2-69ab1a10a97b"}, {"type": "ResetTool", "id": "4d2b9249-b17e-4883-a093-0459d ...

# %% [markdown]
# <img src='files/resources/ic_assignment_black_24dp_2x.png' align='left'>Can you find out how to add a second line showing the mean number of cylinders to the plot? The data frame already includes the value - you just need a change to the bokeh Line() call.

# %% [markdown]
# ### Scatter Chart
#
# Simple, color mapped to category, shape mapped to category

# %%
from bokeh.charts import Scatter

scatter = Scatter(data=df, x='mpg',y='weight', color ='cyl', legend='top_left')
show(scatter)
# Out:
#     <div class="plotdiv" id="75a5d909-564d-43f9-bdd1-51c0cae0e300"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("75a5d909-564d-43f9-bdd1-51c0cae0e300");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '75a5d909-564d-43f9-bdd1-51c0cae0e300' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"515bc1bb-b5db-47f8-a5bf-1d885e08af67": {"version": "0.11.0", "roots": {"root_ids": ["149792b5-4beb-49e8-a56b-69ca39e6b877", "6b90269b-0416-49dc-98d7-f0b78aa71cad", "21cbb82d-c32b-4da5-a8b2-7bfdff3504df", "cbf884f2-00fe-47e5-ae31-174b10884d2f", "cbf5d92c-d35f-43a6-8fe0-73969f242186"], "references": [{"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "0e019a23-d21f-4603-a4ed-fd69874f54d4"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "21cbb82d-c32b-4da5-a8b2-7bfdff3504df"}}, "type": "HelpTool", "id": "bce00042-c6b2-4df6-bb56-4134f3f9fa27"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "7140c75d-e0a6-4596-a830-bf1189da7522"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "b767ca34-2289-4153-ace1-e006466ee8a1"}}, "type": "GlyphRenderer", "id": "b0f00f78-81cf-4573-abb5-21c9780226c5"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "fddabf80-ff0c-46a9-972e-3d613a2df332"}, {"attributes": {}, "type": "BasicTicker", "id": "59cb6ec7-b137-4c01-95a3-4ace3e55f99b"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "52b058b5-cc43-462a-8fcf-d5f6dadd1ebe"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Circle", "id": "4c4999e9-38b2-4ce3-9532-c63f6a8d0371"}}, "type": "GlyphRenderer", "id": "d279106c-85cd-4f63-bfc5-af1591327d5d"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "d8484581-e5cf-4ef4-8d4e-886072a28582"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "dc8365f6-6e97-4268-bc5c-c7b1ee0beaa1"}}, "type": "GlyphRenderer", "id": "4eeaa36a-af21-4b76-a086-e8098a584a67"}, {"attributes": {}, "type": "BasicTickFormatter", "id": "2c6657ec-ff4b-49b4-b16c-1dcf048fc49c"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "d37019a0-790a-4428-a8d2-2ac570c90e14"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "d92f8367-b782-4ae7-a921-9d2eba7807fc"}}, "type": "GlyphRenderer", "id": "6e876256-c386-4c5c-bd07-639428a4093a"}, {"attributes": {"x_range": {"type": "FactorRange", "id": "85510178-b03c-41c7-8577-999b95ccd3f4"}, "y_mapper_type": "auto", "title_text_font_size": {"value": "14pt"}, "title": "Total MPG by CYL", "y_range": {"type": "Range1d", "id": "e4215163-0764-458b-b636-3aab5f6d84ee"}, "x_mapper_type": "auto", "yscale": "auto", "renderers": [{"type": "BoxAnnotation", "id": "7329a782-3133-455b-96d4-0dcb87cae71b"}, {"type": "GlyphRenderer", "id": "f7da5948-82a1-40b0-afda-734474534932"}, {"type": "GlyphRenderer", "id": "26be7cca-57a2-43ae-a9e2-92773d2fa1a6"}, {"type": "GlyphRenderer", "id": "91b0cd03-c87c-41c4-9e92-a0cf30bad73c"}, {"type": "GlyphRenderer", "id": "b432cc60-4cf3-4c25-8aad-4173c228659b"}, {"type": "GlyphRenderer", "id": "23557940-99e8-4b63-b579-be2977221715"}, {"type": "CategoricalAxis", "id": "76a0863f-78be-47f9-b9cf-41107a434148"}, {"type": "LinearAxis", "id": "9e7e0005-2182-4e31-950a-d837bfa05f79"}, {"type": "Grid", "id": "68b83582-0682-4d39-8d74-cb6c99f808eb"}], "plot_width": 500, "xgrid": false, "below": [{"type": "CategoricalAxis", "id": "76a0863f-78be-47f9-b9cf-41107a434148"}], "tool_events": {"type": "ToolEvents", "id": "ab078d6f-1e91-4b20-9d50-dd69cf5abdc2"}, "plot_height": 300, "xscale": "auto", "tools": [{"type": "PanTool", "id": "23108e32-57bc-45c0-9ed1-47ba5fada557"}, {"type": "WheelZoomTool", "id": "6b056ede-ee ...

# %% [markdown]
# <img src='files/resources/ic_assignment_black_24dp_2x.png' align='left'>Can you fix the legend placement problem?

# %% [markdown]
# ### Boxplot
#
# Show the spread of the data.

# %%
from bokeh.charts import BoxPlot

boxplot = BoxPlot(df,label='cyl',values='mpg')

show(boxplot)
# Out:
#     <div class="plotdiv" id="c47d8e8f-06ee-4746-bc02-0319c9de05ee"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c47d8e8f-06ee-4746-bc02-0319c9de05ee");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c47d8e8f-06ee-4746-bc02-0319c9de05ee' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"63dec48a-6670-46e4-9acd-1c13aeb79e7e": {"version": "0.11.0", "roots": {"root_ids": ["149792b5-4beb-49e8-a56b-69ca39e6b877", "6b90269b-0416-49dc-98d7-f0b78aa71cad", "21cbb82d-c32b-4da5-a8b2-7bfdff3504df", "cbf884f2-00fe-47e5-ae31-174b10884d2f", "cbf5d92c-d35f-43a6-8fe0-73969f242186", "cf91fed7-788e-49fc-ad54-8bd2792c9e9c"], "references": [{"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"origin": 3, "yr": 80}], "color": ["#407ee7"], "fill_alpha": [0.8], "height": [35.4], "width": [0.2], "y": [17.7], "x": ["80:0.5"], "yr": [80], "origin": [3]}}, "type": "ColumnDataSource", "id": "032b34fa-5885-4430-a4aa-57f746e30ff2"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "fddabf80-ff0c-46a9-972e-3d613a2df332"}, {"attributes": {"callback": null, "end": 83.2, "start": 68.8}, "type": "Range1d", "id": "4f93eb11-f8b9-41ec-8c45-9fe1d78d1d41"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "21cbb82d-c32b-4da5-a8b2-7bfdff3504df"}}, "type": "ResizeTool", "id": "ac64a763-7c36-44dc-8b2c-1efde3ff01d4"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "928b3f3f-b4bd-412c-a50c-e61afcbb1a8d"}, {"attributes": {"y1": {"field": "y1s"}, "line_width": {"value": 2}, "x0": {"field": "x0s"}, "x1": {"field": "x1s"}, "y0": {"field": "y0s"}}, "type": "Segment", "id": "4e90c38b-126d-4678-8db4-392a2bec1bef"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "f8b14ddc-8b10-4e02-85e8-814a578162fd"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "14cc3195-2360-4740-8ad4-cf41706f2fc2"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "bb98d2e1-7d50-4fe0-be56-92ecfb50c878"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "5eeac627-6662-46a9-9c43-b19d785b6e7d"}}, "type": "GlyphRenderer", "id": "9f9c9d0a-a1d3-48bc-8cd8-baf4247f0b10"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "2e3f7c5b-70b4-4e71-85c2-a1f4f209d6c4"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "8f1139c1-2706-43f1-a9b4-488739b7fba3"}}, "type": "GlyphRenderer", "id": "89692fe1-2397-4154-9d72-4c3d91fe213a"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "eebf7cb8-685d-4ced-bd7e-2c1a31749c8c"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Circle", "id": "c4435381-2273-46c7-a192-1f32f50e6fa3"}}, "type": "GlyphRenderer", "id": "24701003-1eef-4b56-ba73-bc18f3697452"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "d9dca46d-cb80-41ae-bd6a-962d7ff454ed"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "e3665199-d6a7-47fa-aae9-06de09d2c42d"}}, "type": "GlyphRenderer", "id": "08da3c58-4f09-4232-aa54-f166067590dc"}, {"attributes": {"plot": {"subtype": "Chart", "type": " ...

# %% [markdown]
# <img src='files/resources/ic_assignment_black_24dp_2x.png' align='left'>Find a way to remove the outliers from the plot.
# Can you change the color of the box?

# %% [markdown]
# ### Where now?
#
# Going from here - browse over to the [bokeh docs](http://bokeh.pydata.org/en/latest/docs/user_guide.html) and start exploring some of the lower level bokeh.plotting libraries and the [gallery](http://bokeh.pydata.org/en/latest/docs/gallery.html) for inspiration.
#
# Remember - [Pandas](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html#pandas.DataFrame) is your friend.  Get that data into Pandas and Bokeh will play very nicely.  Plus Pandas is a great API for working with data frames.  It is worth exploring and learning.
#
# Most the time the default plots will suffice.  It can take many days to get publication ready plots - make sure you really need that tweak to the plot before losing days of your life!
